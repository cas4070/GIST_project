# %%
import pandas as pd
import numpy as np
from datetime import datetime
import time

# %%
gold_asso = pd.read_excel("/DAS_Storage1/aschoi/data/Drug_Repositioning/7_new_association/PREDICT_S1 Drug indications gold standard.xls")
omim_umls = pd.read_excel("/DAS_Storage1/aschoi/data/Drug_Repositioning/7_new_association/PREDICT_S6 Mapping between OMIM disease and UMLS concepts.xls")

# %%
gold_asso.rename(columns={'Drug name' : 'Drug_name', 'Disease name' : 'Disease_name'}, inplace = True)

# %%
omim_umls.rename(columns={'OMIM ID' : 'OMIM_ID', 'OMIM disease name' : 'OMIM_disease_name',
                          'UMLS concept ID':'UMLS_concep_ID', 'UMLS concept name':'UMLS_concept_name'}, inplace = True)

# %%
di = gold_asso.Disease_name.drop_duplicates()

# %%
filtered = omim_umls[omim_umls.OMIM_disease_name.isin(di)]

# %%
print len(filtered)
print len(filtered.drop_duplicates('OMIM_disease_name'))
print len(filtered.drop_duplicates('OMIM_ID'))
# Out:
# 614
# 312
# 312

# %%
print len(omim_umls)
print len(omim_umls.drop_duplicates())
print len(omim_umls.drop_duplicates('OMIM_ID'))
print len(omim_umls.drop_duplicates('OMIM_disease_name'))
# Out:
# 617
# 617
# 313
# 313

# %%
omim_umls
# Out:
#      OMIM_ID                                  OMIM_disease_name  \
# 0     102100  Acromegaloid Changes, Cutis Verticis Gyrata, A...
# 1     102100  Acromegaloid Changes, Cutis Verticis Gyrata, A...
# 2     102300  Restless Legs Syndrome, Susceptibility To, 1; ...
# 3     102300  Restless Legs Syndrome, Susceptibility To, 1; ...
# 4     102400                                     Acroosteolysis
# 5     102500  Acroosteolysis With Osteoporosis And Changes I...
# 6     102500  Acroosteolysis With Osteoporosis And Changes I...
# 7     102500  Acroosteolysis With Osteoporosis And Changes I...
# 8     102500  Acroosteolysis With Osteoporosis And Changes I...
# 9     103100                                         Adie Pupil
# 10    103100                                         Adie Pupil
# 11    103780                                 Alcohol Dependence
# 12    104130  Alopecia, Psychomotor Epilepsy, Pyorrhea, And ...
# 13    104130  Alopecia, Psychomotor Epilepsy, Pyorrhea, And ...
# ...
