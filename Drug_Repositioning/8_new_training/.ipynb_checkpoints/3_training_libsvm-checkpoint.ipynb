# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

# %%
association_data = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/7_new_association/9_gold_learning_association.tsv")
descriptor_data = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_1_descriptor_combined.tsv", header=None)
x_whole_data = descriptor_data.values
y_whole_data = association_data["association"].values

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

def libsvm_10_fold(x_whole_data, y_whole_data, user_c):
    print("{}----------------------------------------------------".format(user_c))
    skf = StratifiedKFold(n_splits=10, shuffle=True) # n_splits = 10 (10 fold라서.) data가 nega : pos = 76 : 1이기 때문에 validation 뽑을때 그 비율 지켜서 stratified로 한다.
    whole_accuracy = list()
    whole_auc = list()
    whole_aupr = list()
    whole_confusion_mat = list()
    for training_index, validation_index in skf.split(x_whole_data, y_whole_data):
        x_training_set = x_whole_data[training_index] # 0.9에 해당하는 부분
        y_training_set = y_whole_data[training_index]
        x_validation_set = x_whole_data[validation_index] # 0.1에 해당하는 부분
        y_validation_set = y_whole_data[validation_index]

        #classifier = LogisticRegression(penalty='l1', C=0.0001, n_jobs=-1) #n_jobs = -1이면 모든 node 쓰는것. 신경쓰이면 30개 정도.
        #classifier = RandomForestClassifier(n_estimators=120, n_jobs=-1, class_weight='balanced')
        classifier = LinearSVC(penalty='l2', C=user_c, class_weight='balanced')
        classifier.fit(x_training_set, y_training_set)
        #y_predicted_proba = classifier.predict_proba(x_validation_set) # return값이 probability 각각에 대한 확률 결과값 [[0.8(0에대한 확률),0.2(1에대한 확률)],[0.7,0.3],... ]
        y_predicted_label = classifier.predict(x_validation_set) # return이 label임. 위 확률 결과에서 확률이 높은거에 대한 label을 보여줌.
    
        current_accuracy = classifier.score(x_validation_set, y_validation_set) # accuracy score를 보여줌.
        fpr, tpr, thresholds = roc_curve(y_validation_set, y_predicted_label, pos_label=1) # powitive label만 본것.
        current_auc = auc(fpr, tpr)
        current_confusion_matrix = confusion_matrix(y_validation_set,
                                                    y_predicted_label)
        current_aupr = average_precision_score(y_validation_set, y_predicted_label)
    
        whole_accuracy.append(current_accuracy)
        whole_auc.append(current_auc)
        whole_aupr.append(current_aupr)
        whole_confusion_mat.append((current_confusion_matrix))
        
        print("Accuracy of this fold: {}".format(current_accuracy))
        print("AUC of this fold: {}".format(current_auc))
        print("AUPR of this fold: {}".format(current_aupr))
        print("Confustion matrix of this fold")
        print(current_confusion_matrix)
        print("\n")
    print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
    print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
    print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
    print("Confustion matrix")
    print(sum(whole_confusion_mat))
    
    
    return [whole_accuracy, whole_auc, whole_aupr, whole_confusion_mat]

# %%
results = list()
for user_c in [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]:
    results.append(libsvm_10_fold(x_whole_data, y_whole_data, user_c))
# Out:
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.777687443541
# AUC of this fold: 0.716055738605
# AUPR of this fold: 0.347409719856
# Confustion matrix of this fold
# [[8515 2411]
#  [  50   94]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.777938386485
# AUC of this fold: 0.699050661073
# AUPR of this fold: 0.329369336571
# Confustion matrix of this fold
# [[8522 2403]
#  [  55   89]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.774505375373
# AUC of this fold: 0.731576086957
# AUPR of this fold: 0.365194468654
# Confustion matrix of this fold
# [[8474 2451]
#  [  45   99]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.774505375373
# AUC of this fold: 0.66304697432
# AUPR of this fold: 0.292978735273
# Confustion matrix of this fold
# [[8494 2431]
#  [  65   79]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.785507770148
# AUC of this fold: 0.687756636956
# AUPR of this fold: 0.313878929938
# Confustion matrix of this fold
# [[8610 2315]
#  [  59   84]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.774123599566
# AUC of this fold: 0.699243731097
# AUPR of this fold: 0.331182516945
# Confustion matrix of this fold
# [[8479 2446]
#  [  54   89]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.784423563426
# AUC of this fold: 0.701010385496
# AUPR of this fold: 0.328366282533
# Confustion matrix of this fold
# [[8594 2331]
#  [  55   88]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.77620166245
# AUC of this fold: 0.665788993615
# AUPR of this fold: 0.294965716461
# Confustion matrix of this fold
# [[8512 2413]
#  [  64   79]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.779273581496
# AUC of this fold: 0.670795794594
# AUPR of this fold: 0.298826484967
# Confustion matrix of this fold
# [[8545 2380]
#  [  63   80]]
#
#
# 0.0001----------------------------------------------------
# Accuracy of this fold: 0.774756053488
# AUC of this fold: 0.696113360324
# AUPR of this fold: 0.327595792119
# Confustion matrix of this fold
# [[8487 2438]
#  [  55   88]]
#
#
# Accuracy avg : 0.777892281135
# AUC avg : 0.693043836304
# AUPR avg : 0.322976798332
# Confustion matrix
# [[85232 24019]
#  [  565   869]]
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.769467028004
# AUC of this fold: 0.725597199341
# AUPR of this fold: 0.361172669522
# Confustion matrix of this fold
# [[8420 2506]
#  [  46   98]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.772698527419
# AUC of this fold: 0.710102021358
# AUPR of this fold: 0.343398662077
# Confustion matrix of this fold
# [[8460 2465]
#  [  51   93]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.774415032975
# AUC of this fold: 0.690412852784
# AUPR of this fold: 0.321872179519
# Confustion matrix of this fold
# [[8485 2440]
#  [  57   87]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.764387026832
# AUC of this fold: 0.66477402746
# AUPR of this fold: 0.299518481643
# Confustion matrix of this fold
# [[8380 2545]
#  [  63   81]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.76563064691
# AUC of this fold: 0.694941671601
# AUPR of this fold: 0.33055486437
# Confustion matrix of this fold
# [[8385 2540]
#  [  54   89]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.759486808818
# AUC of this fold: 0.722886175609
# AUPR of this fold: 0.362738112398
# Confustion matrix of this fold
# [[8308 2617]
#  [  45   98]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.758312251536
# AUC of this fold: 0.711938999216
# AUPR of this fold: 0.351786649727
# Confustion matrix of this fold
# [[8298 2627]
#  [  48   95]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.764817491868
# AUC of this fold: 0.673825350851
# AUPR of this fold: 0.308723810442
# Confustion matrix of this fold
# [[8382 2543]
#  [  60   83]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.768160462595
# AUC of this fold: 0.737631979005
# AUPR of this fold: 0.374282310149
# Confustion matrix of this fold
# [[8401 2524]
#  [  42  101]]
#
#
# 0.001----------------------------------------------------
# Accuracy of this fold: 0.7708709794
# AUC of this fold: 0.701046870749
# AUPR of this fold: 0.334568916617
# Confustion matrix of this fold
# [[8442 2483]
#  [  53   90]]
#
#
# Accuracy avg : 0.766824625636
# AUC avg : 0.703315714797
# AUPR avg : 0.338861665646
# Confustion matrix
# [[83961 25290]
#  [  519   915]]
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.761427280939
# AUC of this fold: 0.670127448288
# AUPR of this fold: 0.306533566564
# Confustion matrix of this fold
# [[8346 2580]
#  [  61   83]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.756888607824
# AUC of this fold: 0.726078057462
# AUPR of this fold: 0.367411429525
# Confustion matrix of this fold
# [[8278 2647]
#  [  44  100]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.751829433553
# AUC of this fold: 0.672118293923
# AUPR of this fold: 0.313130350962
# Confustion matrix of this fold
# [[8237 2688]
#  [  59   85]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.75508175987
# AUC of this fold: 0.6977510806
# AUPR of this fold: 0.338514539078
# Confustion matrix of this fold
# [[8266 2659]
#  [  52   92]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.763823635707
# AUC of this fold: 0.683674129075
# AUPR of this fold: 0.319543682508
# Confustion matrix of this fold
# [[8368 2557]
#  [  57   86]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.761022768341
# AUC of this fold: 0.682255364773
# AUPR of this fold: 0.319355069525
# Confustion matrix of this fold
# [[8337 2588]
#  [  57   86]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.757860498735
# AUC of this fold: 0.691005744827
# AUPR of this fold: 0.330018699886
# Confustion matrix of this fold
# [[8299 2626]
#  [  54   89]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.757679797615
# AUC of this fold: 0.652956105679
# AUPR of this fold: 0.290134908976
# Confustion matrix of this fold
# [[8308 2617]
#  [  65   78]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.757499096494
# AUC of this fold: 0.701174889184
# AUPR of this fold: 0.340862994908
# Confustion matrix of this fold
# [[8292 2633]
#  [  51   92]]
#
#
# 0.01----------------------------------------------------
# Accuracy of this fold: 0.758131550416
# AUC of this fold: 0.701495255317
# AUPR of this fold: 0.34090646994
# Confustion matrix of this fold
# [[8299 2626]
#  [  51   92]]
#
#
# Accuracy avg : 0.758124442949
# AUC avg : 0.687863636913
# AUPR avg : 0.326641171187
# Confustion matrix
# [[83030 26221]
#  [  551   883]]
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.852935862692
# AUC of this fold: 0.665087863811
# AUPR of this fold: 0.260531466426
# Confustion matrix of this fold
# [[9374 1552]
#  [  76   68]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.846146896739
# AUC of this fold: 0.644516590389
# AUPR of this fold: 0.241103229124
# Confustion matrix of this fold
# [[9303 1622]
#  [  81   63]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.846146896739
# AUC of this fold: 0.675354691076
# AUPR of this fold: 0.274391492494
# Confustion matrix of this fold
# [[9294 1631]
#  [  72   72]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.850483331828
# AUC of this fold: 0.643286931096
# AUPR of this fold: 0.237942060731
# Confustion matrix of this fold
# [[9352 1573]
#  [  82   62]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.841976870257
# AUC of this fold: 0.674951913075
# AUPR of this fold: 0.275527125206
# Confustion matrix of this fold
# [[9247 1678]
#  [  71   72]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.84920491507
# AUC of this fold: 0.647556608152
# AUPR of this fold: 0.242961539297
# Confustion matrix of this fold
# [[9336 1589]
#  [  80   63]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.841796169136
# AUC of this fold: 0.640353010834
# AUPR of this fold: 0.238340797842
# Confustion matrix of this fold
# [[9255 1670]
#  [  81   62]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.84875316227
# AUC of this fold: 0.650778512106
# AUPR of this fold: 0.246633799053
# Confustion matrix of this fold
# [[9330 1595]
#  [  79   64]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.836284784966
# AUC of this fold: 0.627209038101
# AUPR of this fold: 0.226596543979
# Confustion matrix of this fold
# [[9197 1728]
#  [  84   59]]
#
#
# 0.1----------------------------------------------------
# Accuracy of this fold: 0.84378388146
# AUC of this fold: 0.644810612728
# AUPR of this fold: 0.242293275397
# Confustion matrix of this fold
# [[9276 1649]
#  [  80   63]]
#
#
# Accuracy avg : 0.845751277116
# AUC avg : 0.651390577137
# AUPR avg : 0.248632132955
# Confustion matrix
# [[92964 16287]
#  [  786   648]]
# 1----------------------------------------------------
# Accuracy of this fold: 0.975248419151
# AUC of this fold: 0.528315485997
# AUPR of this fold: 0.0741079494128
# Confustion matrix of this fold
# [[10786   140]
#  [  134    10]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.977233715783
# AUC of this fold: 0.519042397661
# AUPR of this fold: 0.0591825343873
# Confustion matrix of this fold
# [[10810   115]
#  [  137     7]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.980757069293
# AUC of this fold: 0.507121472159
# AUPR of this fold: 0.0367858057036
# Confustion matrix of this fold
# [[10853    72]
#  [  141     3]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.974071731864
# AUC of this fold: 0.510587655734
# AUPR of this fold: 0.0399797770314
# Confustion matrix of this fold
# [[10777   148]
#  [  139     5]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.972623780267
# AUC of this fold: 0.513381766974
# AUPR of this fold: 0.044609894816
# Confustion matrix of this fold
# [[10759   166]
#  [  137     6]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.972804481388
# AUC of this fold: 0.537628458498
# AUPR of this fold: 0.0866534188223
# Confustion matrix of this fold
# [[10754   171]
#  [  130    13]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.974882544272
# AUC of this fold: 0.51797666864
# AUPR of this fold: 0.0541092954532
# Confustion matrix of this fold
# [[10783   142]
#  [  136     7]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.974611492591
# AUC of this fold: 0.545445264118
# AUPR of this fold: 0.102872845442
# Confustion matrix of this fold
# [[10772   153]
#  [  128    15]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.981207083484
# AUC of this fold: 0.524631066874
# AUPR of this fold: 0.0834534068331
# Confustion matrix of this fold
# [[10852    73]
#  [  135     8]]
#
#
# 1----------------------------------------------------
# Accuracy of this fold: 0.978044813878
# AUC of this fold: 0.529930710022
# AUPR of this fold: 0.0826400138832
# Confustion matrix of this fold
# [[10815   110]
#  [  133    10]]
#
#
# Accuracy avg : 0.976148513197
# AUC avg : 0.523406094668
# AUPR avg : 0.0664394941785
# Confustion matrix
# [[107961   1290]
#  [  1350     84]]
# 10----------------------------------------------------
# Accuracy of this fold: 0.974796747967
# AUC of this fold: 0.528086673989
# AUPR of this fold: 0.0730326805956
# Confustion matrix of this fold
# [[10781   145]
#  [  134    10]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.981389466076
# AUC of this fold: 0.500588927028
# AUPR of this fold: 0.0177442036569
# Confustion matrix of this fold
# [[10862    63]
#  [  143     1]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.978227482157
# AUC of this fold: 0.498987096364
# AUPR of this fold: 0.0149822087074
# Confustion matrix of this fold
# [[10827    98]
#  [  143     1]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.984641792393
# AUC of this fold: 0.49881006865
# AUPR of this fold: 0.00650465263348
# Confustion matrix of this fold
# [[10899    26]
#  [  144     0]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.982562341887
# AUC of this fold: 0.508063881199
# AUPR of this fold: 0.0435997639874
# Confustion matrix of this fold
# [[10872    53]
#  [  140     3]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.97370798699
# AUC of this fold: 0.517381702965
# AUPR of this fold: 0.0522243008389
# Confustion matrix of this fold
# [[10770   155]
#  [  136     7]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.985092157571
# AUC of this fold: 0.498993135011
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10903    22]
#  [  143     0]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.980845681243
# AUC of this fold: 0.507194315982
# AUPR of this fold: 0.0368140497017
# Confustion matrix of this fold
# [[10853    72]
#  [  140     3]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.983104445248
# AUC of this fold: 0.504887743835
# AUPR of this fold: 0.0341960548186
# Confustion matrix of this fold
# [[10879    46]
#  [  141     2]]
#
#
# 10----------------------------------------------------
# Accuracy of this fold: 0.977683411637
# AUC of this fold: 0.51249395913
# AUPR of this fold: 0.0456465306959
# Confustion matrix of this fold
# [[10816   109]
#  [  138     5]]
#
#
# Accuracy avg : 0.980205151317
# AUC avg : 0.507548750415
# AUPR avg : 0.0331204510688
# Confustion matrix
# [[108462    789]
#  [  1402     32]]
# 100----------------------------------------------------
# Accuracy of this fold: 0.984643179765
# AUC of this fold: 0.498810177558
# AUPR of this fold: 0.00650406504065
# Confustion matrix of this fold
# [[10900    26]
#  [  144     0]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.980305357304
# AUC of this fold: 0.524024917366
# AUPR of this fold: 0.078365505265
# Confustion matrix of this fold
# [[10843    82]
#  [  136     8]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.97849850935
# AUC of this fold: 0.502550851767
# AUPR of this fold: 0.0235628363129
# Confustion matrix of this fold
# [[10829    96]
#  [  142     2]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.981118438883
# AUC of this fold: 0.503878082888
# AUPR of this fold: 0.0278515083034
# Confustion matrix of this fold
# [[10858    67]
#  [  142     2]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.979580773401
# AUC of this fold: 0.510004320622
# AUPR of this fold: 0.0422433998961
# Confustion matrix of this fold
# [[10838    87]
#  [  139     4]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.977322009396
# AUC of this fold: 0.495057208238
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10817   108]
#  [  143     0]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.985001807011
# AUC of this fold: 0.498947368421
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10902    23]
#  [  143     0]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.98436935309
# AUC of this fold: 0.505528476101
# AUPR of this fold: 0.0427744861911
# Confustion matrix of this fold
# [[10893    32]
#  [  141     2]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.98418865197
# AUC of this fold: 0.50543694292
# AUPR of this fold: 0.041140499263
# Confustion matrix of this fold
# [[10891    34]
#  [  141     2]]
#
#
# 100----------------------------------------------------
# Accuracy of this fold: 0.982291290206
# AUC of this fold: 0.497574370709
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10872    53]
#  [  143     0]]
#
#
# Accuracy avg : 0.981731937038
# AUC avg : 0.504181271659
# AUPR avg : 0.0281822495429
# Confustion matrix
# [[108643    608]
#  [  1414     20]]
# 1000----------------------------------------------------
# Accuracy of this fold: 0.978229448961
# AUC of this fold: 0.519546265788
# AUPR of this fold: 0.0620249822994
# Confustion matrix of this fold
# [[10822   104]
#  [  137     7]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.977053030987
# AUC of this fold: 0.505245041953
# AUPR of this fold: 0.0297168401864
# Confustion matrix of this fold
# [[10812   113]
#  [  141     3]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.98554521637
# AUC of this fold: 0.499267734554
# AUPR of this fold: 0.00650465263348
# Confustion matrix of this fold
# [[10909    16]
#  [  144     0]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.986177613154
# AUC of this fold: 0.499588100686
# AUPR of this fold: 0.00650465263348
# Confustion matrix of this fold
# [[10916     9]
#  [  144     0]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.984098301409
# AUC of this fold: 0.498489702517
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10892    33]
#  [  143     0]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.985092157571
# AUC of this fold: 0.502443871918
# AUPR of this fold: 0.0307447266022
# Confustion matrix of this fold
# [[10902    23]
#  [  142     1]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.98427900253
# AUC of this fold: 0.498581235698
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10894    31]
#  [  143     0]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.975334297073
# AUC of this fold: 0.535459186123
# AUPR of this fold: 0.0868370426104
# Confustion matrix of this fold
# [[10783   142]
#  [  131    12]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.974972894832
# AUC of this fold: 0.518022435231
# AUPR of this fold: 0.054268011216
# Confustion matrix of this fold
# [[10784   141]
#  [  136     7]]
#
#
# 1000----------------------------------------------------
# Accuracy of this fold: 0.977683411637
# AUC of this fold: 0.567705749628
# AUPR of this fold: 0.150855765816
# Confustion matrix of this fold
# [[10800   125]
#  [  122    21]]
#
#
# Accuracy avg : 0.980846537452
# AUC avg : 0.51443493241
# AUPR avg : 0.0440376804102
# Confustion matrix
# [[108514    737]
#  [  1383     51]]
# 10000----------------------------------------------------
# Accuracy of this fold: 0.975158084914
# AUC of this fold: 0.494005125389
# AUPR of this fold: 0.00650406504065
# Confustion matrix of this fold
# [[10795   131]
#  [  144     0]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.986810009938
# AUC of this fold: 0.499908466819
# AUPR of this fold: 0.00650465263348
# Confustion matrix of this fold
# [[10923     2]
#  [  144     0]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.97813713976
# AUC of this fold: 0.502367785406
# AUPR of this fold: 0.0231626762489
# Confustion matrix of this fold
# [[10825   100]
#  [  142     2]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.986177613154
# AUC of this fold: 0.499588100686
# AUPR of this fold: 0.00650465263348
# Confustion matrix of this fold
# [[10916     9]
#  [  144     0]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.976779906035
# AUC of this fold: 0.505134819414
# AUPR of this fold: 0.0293140497017
# Confustion matrix of this fold
# [[10808   117]
#  [  140     3]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.985092157571
# AUC of this fold: 0.498993135011
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10903    22]
#  [  143     0]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.985724611493
# AUC of this fold: 0.50276423805
# AUPR of this fold: 0.0393231579747
# Confustion matrix of this fold
# [[10909    16]
#  [  142     1]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.982381640766
# AUC of this fold: 0.4976201373
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10873    52]
#  [  143     0]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.981297434044
# AUC of this fold: 0.500521675121
# AUPR of this fold: 0.0174871508446
# Confustion matrix of this fold
# [[10860    65]
#  [  142     1]]
#
#
# 10000----------------------------------------------------
# Accuracy of this fold: 0.983104445248
# AUC of this fold: 0.497986270023
# AUPR of this fold: 0.0064600650524
# Confustion matrix of this fold
# [[10881    44]
#  [  143     0]]
#
#
# Accuracy avg : 0.982066304292
# AUC avg : 0.499888975322
# AUPR avg : 0.0148180600235
# Confustion matrix
# [[108693    558]
#  [  1427      7]]

# %%
indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

x_whole_data = descriptor_data.values
y_whole_data = association_data["association"].values
indep_x = indep.values[:, 3:].astype(float)
indep_y = indep.values[:,2].astype(int)

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
#classifier = RandomForestClassifier(n_estimators=800, n_jobs=-1, class_weight='balanced')
classifier = LinearSVC(penalty='l2', C=0.001, class_weight='balanced')
classifier.fit(x_whole_data, y_whole_data)
#indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-30-83bb2581d85d> in <module>()
#      12 classifier = LinearSVC(penalty='l2', C=0.001, class_weight='balanced')
#      13 classifier.fit(x_whole_data, y_whole_data)
# ---> 14 indep_y_predicted_proba = classifier.predict_proba(indep_x)
#      15 indep_y_predicted_label = classifier.predict(indep_x)
#      16
#
# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'

# %%
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_label, pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_label)

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# Independent Accuracy : 0.65988258317
# Independent AUC : 0.642453464707
# Independent AUPR : 0.35118848282
# Independent Confustion matrix
# [[1628  834]
#  [  35   58]]
