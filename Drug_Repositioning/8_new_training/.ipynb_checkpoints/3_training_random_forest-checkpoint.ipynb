# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold

# %%
#기존 데이터
#association_data = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/7_new_association/9_gold_learning_association.tsv")
#descriptor_data = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_1_descriptor_combined.tsv")
df = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_1_descriptor_combined.tsv")
x_whole_data = df[df.columns.values[3:].tolist()].values
y_whole_data = df["association"].values

# %%
# independent data
indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_2_indep_asso_descriptor.tsv")

# %%
# new descriptor - TN 구분한 data(2017.1.16.) 수정됨. 2017.1.23.
df = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/4_gold_descriptor_revised.tsv")
x_whole_data = df[df.columns.values[3:].tolist()].values
y_whole_data = df["association"].values

# %%
# new descriptor - TN 구분한 data(2017.1.16.) 수정됨. 2017.1.23. 추가됨 2017.2.1.
df = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/4_gold_descriptor_revised_0.5%.tsv")
x_whole_data_0_5 = df[df.columns.values[3:].tolist()].values
y_whole_data_0_5 = df["association"].values

df = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/4_gold_descriptor_revised_0.1%.tsv")
x_whole_data_0_1 = df[df.columns.values[3:].tolist()].values
y_whole_data_0_1 = df["association"].values

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

def Random_Forest_10_fold(x_whole_data, y_whole_data, user_estimators):
    print("{}----------------------------------------------------".format(user_estimators))
    skf = StratifiedKFold(n_splits=10, shuffle=True) # n_splits = 10 (10 fold라서.) data가 nega : pos = 76 : 1이기 때문에 validation 뽑을때 그 비율 지켜서 stratified로 한다.
    whole_accuracy = list()
    whole_auc = list()
    whole_aupr = list()
    whole_confusion_mat = list()
    for training_index, validation_index in skf.split(x_whole_data, y_whole_data):
        x_training_set = x_whole_data[training_index] # 0.9에 해당하는 부분
        y_training_set = y_whole_data[training_index]
        x_validation_set = x_whole_data[validation_index] # 0.1에 해당하는 부분
        y_validation_set = y_whole_data[validation_index]

        #classifier = LogisticRegression(penalty='l1', C=0.0001, n_jobs=-1) #n_jobs = -1이면 모든 node 쓰는것. 신경쓰이면 30개 정도.
        classifier = RandomForestClassifier(n_estimators=user_estimators, n_jobs=-1, class_weight='balanced')
        classifier.fit(x_training_set, y_training_set)
        y_predicted_proba = classifier.predict_proba(x_validation_set) # return값이 probability 각각에 대한 확률 결과값 [[0.8(0에대한 확률),0.2(1에대한 확률)],[0.7,0.3],... ]
        y_predicted_label = classifier.predict(x_validation_set) # return이 label임. 위 확률 결과에서 확률이 높은거에 대한 label을 보여줌.

        current_accuracy = classifier.score(x_validation_set, y_validation_set) # accuracy score를 보여줌.
        fpr, tpr, thresholds = roc_curve(y_validation_set, y_predicted_proba[:, 1], pos_label=1) # powitive label만 본것.
        current_auc = auc(fpr, tpr)
        current_confusion_matrix = confusion_matrix(y_validation_set,
                                                    y_predicted_label)
        current_aupr = average_precision_score(y_validation_set, y_predicted_proba[:, 1])
    
        whole_accuracy.append(current_accuracy)
        whole_auc.append(current_auc)
        whole_aupr.append(current_aupr)
        whole_confusion_mat.append((current_confusion_matrix))
        #print("Accuracy of this fold: {}".format(current_accuracy))
        #print("AUC of this fold: {}".format(current_auc))
        #print("AUPR of this fold: {}".format(current_aupr))
        #print("Confustion matrix of this fold")
        #print(current_confusion_matrix)
        #print("\n")
    print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
    print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
    print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
    print("Confustion matrix")
    print(sum(whole_confusion_mat))
    
    return [whole_accuracy, whole_auc, whole_aupr, whole_confusion_mat]

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

def Random_Forest_independent(x_whole_data, y_whole_data, indep_x, indep_y, user_estimators):
    #indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_2_indep_asso_descriptor.tsv")
    #indep_x = indep[indep.columns.values[3:].tolist()].values
    #indep_y = indep["association"].values

    #classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
    classifier = RandomForestClassifier(n_estimators=user_estimators, n_jobs=-1, class_weight='balanced')
    classifier.fit(x_whole_data, y_whole_data)
    indep_y_predicted_proba = classifier.predict_proba(indep_x)
    indep_y_predicted_label = classifier.predict(indep_x)

    indep_accuracy = classifier.score(indep_x, indep_y)
    indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
    indep_auc = auc(indep_fpr, indep_tpr)
    indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
    indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

    #print("{}----------------------------------------------------".format(user_estimators))
    #print("Independent Accuracy : {}".format(indep_accuracy))
    #print("Independent AUC : {}".format(indep_auc))
    #print("Independent AUPR : {}".format(indep_aupr))
    #print("Independent Confustion matrix")
    #print(indep_confusion_matirx)
    #print("\t")
    
    return [indep_accuracy, indep_auc, indep_aupr, indep_confusion_matirx]

# %%
# new descriptor(1%) 사용시 2017.1.16. 수정됨. 2017.1.23.
results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_whole_data, y_whole_data, user_estimators))
# Out:
# 120----------------------------------------------------
# Accuracy of this fold: 0.992877225867
# AUC of this fold: 0.948187568227
# AUPR of this fold: 0.870278193018
# Confustion matrix of this fold
# [[5188    3]
#  [  35  109]]
#
#
# Accuracy of this fold: 0.993439550141
# AUC of this fold: 0.936164221195
# AUPR of this fold: 0.867024719006
# Confustion matrix of this fold
# [[5189    2]
#  [  33  111]]
#
#
# Accuracy of this fold: 0.990627928772
# AUC of this fold: 0.935350178728
# AUPR of this fold: 0.808795786196
# Confustion matrix of this fold
# [[5188    3]
#  [  47   97]]
#
#
# Accuracy of this fold: 0.991190253046
# AUC of this fold: 0.929309408378
# AUPR of this fold: 0.827341288302
# Confustion matrix of this fold
# [[5191    0]
#  [  47   97]]
#
#
# Accuracy of this fold: 0.992499531221
# AUC of this fold: 0.934105393643
# AUPR of this fold: 0.834454716506
# Confustion matrix of this fold
# [[5189    1]
#  [  39  104]]
#
#
# Accuracy of this fold: 0.99287455466
# AUC of this fold: 0.97070684614
# AUPR of this fold: 0.869227052411
# Confustion matrix of this fold
# [[5187    3]
#  [  35  108]]
#
#
# Accuracy of this fold: 0.991749484343
# AUC of this fold: 0.941745826428
# AUPR of this fold: 0.832523936087
# Confustion matrix of this fold
# [[5186    4]
#  [  40  103]]
#
#
# Accuracy of this fold: 0.990999437465
# AUC of this fold: 0.911116725279
# AUPR of this fold: 0.802858667693
# Confustion matrix of this fold
# [[5190    0]
#  [  48   95]]
#
#
# Accuracy of this fold: 0.990624414026
# AUC of this fold: 0.930497055931
# AUPR of this fold: 0.823462901642
# Confustion matrix of this fold
# [[5188    2]
#  [  48   95]]
#
#
# Accuracy of this fold: 0.991186949184
# AUC of this fold: 0.903892639153
# AUPR of this fold: 0.802503537281
# Confustion matrix of this fold
# [[5188    2]
#  [  45   98]]
#
#
# Accuracy avg : 0.991806932872
# AUC avg : 0.93410758631
# AUPR avg : 0.833847079814
# Confustion matrix
# [[51884    20]
#  [  417  1017]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.991940018744
# AUC of this fold: 0.938701331364
# AUPR of this fold: 0.855132670404
# Confustion matrix of this fold
# [[5190    1]
#  [  42  102]]
#
#
# Accuracy of this fold: 0.989878163074
# AUC of this fold: 0.925241202723
# AUPR of this fold: 0.772739588096
# Confustion matrix of this fold
# [[5190    1]
#  [  53   91]]
#
#
# Accuracy of this fold: 0.992127460169
# AUC of this fold: 0.955476492433
# AUPR of this fold: 0.862784390809
# Confustion matrix of this fold
# [[5190    1]
#  [  41  103]]
#
#
# Accuracy of this fold: 0.992314901593
# AUC of this fold: 0.93590201524
# AUPR of this fold: 0.858823260207
# Confustion matrix of this fold
# [[5191    0]
#  [  41  103]]
#
#
# Accuracy of this fold: 0.991936996062
# AUC of this fold: 0.963102793161
# AUPR of this fold: 0.873990653328
# Confustion matrix of this fold
# [[5188    2]
#  [  41  102]]
#
#
# Accuracy of this fold: 0.992312019501
# AUC of this fold: 0.935307274614
# AUPR of this fold: 0.851326513968
# Confustion matrix of this fold
# [[5185    5]
#  [  36  107]]
#
#
# Accuracy of this fold: 0.991749484343
# AUC of this fold: 0.938776156406
# AUPR of this fold: 0.816111027334
# Confustion matrix of this fold
# [[5190    0]
#  [  44   99]]
#
#
# Accuracy of this fold: 0.992499531221
# AUC of this fold: 0.939909993667
# AUPR of this fold: 0.847605072948
# Confustion matrix of this fold
# [[5190    0]
#  [  40  103]]
#
#
# Accuracy of this fold: 0.993062066379
# AUC of this fold: 0.934362073379
# AUPR of this fold: 0.84491915647
# Confustion matrix of this fold
# [[5188    2]
#  [  35  108]]
#
#
# Accuracy of this fold: 0.99268704294
# AUC of this fold: 0.934542625005
# AUPR of this fold: 0.82423317717
# Confustion matrix of this fold
# [[5188    2]
#  [  37  106]]
#
#
# Accuracy avg : 0.992050768403
# AUC avg : 0.940132195799
# AUPR avg : 0.840766551074
# Confustion matrix
# [[51890    14]
#  [  410  1024]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.990815370197
# AUC of this fold: 0.936940805668
# AUPR of this fold: 0.824164358075
# Confustion matrix of this fold
# [[5188    3]
#  [  46   98]]
#
#
# Accuracy of this fold: 0.99175257732
# AUC of this fold: 0.943938761532
# AUPR of this fold: 0.85973017523
# Confustion matrix of this fold
# [[5190    1]
#  [  43  101]]
#
#
# Accuracy of this fold: 0.993626991565
# AUC of this fold: 0.939376913033
# AUPR of this fold: 0.869020149307
# Confustion matrix of this fold
# [[5190    1]
#  [  33  111]]
#
#
# Accuracy of this fold: 0.991565135895
# AUC of this fold: 0.938915377041
# AUPR of this fold: 0.81984214746
# Confustion matrix of this fold
# [[5190    1]
#  [  44  100]]
#
#
# Accuracy of this fold: 0.990061878867
# AUC of this fold: 0.910767074929
# AUPR of this fold: 0.76860696901
# Confustion matrix of this fold
# [[5190    0]
#  [  53   90]]
#
#
# Accuracy of this fold: 0.992312019501
# AUC of this fold: 0.949560747538
# AUPR of this fold: 0.862232649585
# Confustion matrix of this fold
# [[5185    5]
#  [  36  107]]
#
#
# Accuracy of this fold: 0.993062066379
# AUC of this fold: 0.95450772734
# AUPR of this fold: 0.863685543697
# Confustion matrix of this fold
# [[5189    1]
#  [  36  107]]
#
#
# Accuracy of this fold: 0.99287455466
# AUC of this fold: 0.971716722584
# AUPR of this fold: 0.881325788232
# Confustion matrix of this fold
# [[5189    1]
#  [  37  106]]
#
#
# Accuracy of this fold: 0.993249578099
# AUC of this fold: 0.938290418637
# AUPR of this fold: 0.855096641746
# Confustion matrix of this fold
# [[5190    0]
#  [  36  107]]
#
#
# Accuracy of this fold: 0.990999437465
# AUC of this fold: 0.935077542881
# AUPR of this fold: 0.823219678732
# Confustion matrix of this fold
# [[5186    4]
#  [  44   99]]
#
#
# Accuracy avg : 0.992031960995
# AUC avg : 0.941909209118
# AUPR avg : 0.842692410107
# Confustion matrix
# [[51887    17]
#  [  408  1026]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.991940018744
# AUC of this fold: 0.944978220852
# AUPR of this fold: 0.841587120893
# Confustion matrix of this fold
# [[5189    2]
#  [  41  103]]
#
#
# Accuracy of this fold: 0.992502343018
# AUC of this fold: 0.951683870588
# AUPR of this fold: 0.86834032289
# Confustion matrix of this fold
# [[5191    0]
#  [  40  104]]
#
#
# Accuracy of this fold: 0.991002811621
# AUC of this fold: 0.923554255228
# AUPR of this fold: 0.809841081974
# Confustion matrix of this fold
# [[5190    1]
#  [  47   97]]
#
#
# Accuracy of this fold: 0.991940018744
# AUC of this fold: 0.943641773154
# AUPR of this fold: 0.834642234056
# Confustion matrix of this fold
# [[5188    3]
#  [  40  104]]
#
#
# Accuracy of this fold: 0.990999437465
# AUC of this fold: 0.917196868642
# AUPR of this fold: 0.799412455942
# Confustion matrix of this fold
# [[5189    1]
#  [  47   96]]
#
#
# Accuracy of this fold: 0.99268704294
# AUC of this fold: 0.952179419809
# AUPR of this fold: 0.868074494205
# Confustion matrix of this fold
# [[5189    1]
#  [  38  105]]
#
#
# Accuracy of this fold: 0.991936996062
# AUC of this fold: 0.961710928763
# AUPR of this fold: 0.855768189271
# Confustion matrix of this fold
# [[5190    0]
#  [  43  100]]
#
#
# Accuracy of this fold: 0.99287455466
# AUC of this fold: 0.966511715645
# AUPR of this fold: 0.88211171414
# Confustion matrix of this fold
# [[5189    1]
#  [  37  106]]
#
#
# Accuracy of this fold: 0.992499531221
# AUC of this fold: 0.927841330153
# AUPR of this fold: 0.829663895259
# Confustion matrix of this fold
# [[5188    2]
#  [  38  105]]
#
#
# Accuracy of this fold: 0.992312019501
# AUC of this fold: 0.931467184068
# AUPR of this fold: 0.852671554898
# Confustion matrix of this fold
# [[5185    5]
#  [  36  107]]
#
#
# Accuracy avg : 0.992069477398
# AUC avg : 0.94207655669
# AUPR avg : 0.844211306353
# Confustion matrix
# [[51888    16]
#  [  407  1027]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.990440487348
# AUC of this fold: 0.946906638627
# AUPR of this fold: 0.850522408291
# Confustion matrix of this fold
# [[5189    2]
#  [  49   95]]
#
#
# Accuracy of this fold: 0.99137769447
# AUC of this fold: 0.945411663349
# AUPR of this fold: 0.834525364856
# Confustion matrix of this fold
# [[5187    4]
#  [  42  102]]
#
#
# Accuracy of this fold: 0.99175257732
# AUC of this fold: 0.941672552923
# AUPR of this fold: 0.858051219108
# Confustion matrix of this fold
# [[5187    4]
#  [  40  104]]
#
#
# Accuracy of this fold: 0.99175257732
# AUC of this fold: 0.928288009161
# AUPR of this fold: 0.82656828525
# Confustion matrix of this fold
# [[5191    0]
#  [  44  100]]
#
#
# Accuracy of this fold: 0.99287455466
# AUC of this fold: 0.953081504238
# AUPR of this fold: 0.850718677415
# Confustion matrix of this fold
# [[5189    1]
#  [  37  106]]
#
#
# Accuracy of this fold: 0.991561972623
# AUC of this fold: 0.926920382123
# AUPR of this fold: 0.823852611661
# Confustion matrix of this fold
# [[5189    1]
#  [  44   99]]
#
#
# Accuracy of this fold: 0.99268704294
# AUC of this fold: 0.948232210949
# AUPR of this fold: 0.852630445489
# Confustion matrix of this fold
# [[5189    1]
#  [  38  105]]
#
#
# Accuracy of this fold: 0.991561972623
# AUC of this fold: 0.935286389911
# AUPR of this fold: 0.826300017041
# Confustion matrix of this fold
# [[5189    1]
#  [  44   99]]
#
#
# Accuracy of this fold: 0.991936996062
# AUC of this fold: 0.940919870111
# AUPR of this fold: 0.815320124311
# Confustion matrix of this fold
# [[5187    3]
#  [  40  103]]
#
#
# Accuracy of this fold: 0.993249578099
# AUC of this fold: 0.963120983063
# AUPR of this fold: 0.877259805967
# Confustion matrix of this fold
# [[5188    2]
#  [  34  109]]
#
#
# Accuracy avg : 0.991919545346
# AUC avg : 0.942984020445
# AUPR avg : 0.841574895939
# Confustion matrix
# [[51885    19]
#  [  412  1022]]

# %%
#new descriptor(1%)의 independent test 2017.2.1. Random undersampling 추가. 2017.2.2.

from sklearn.metrics import roc_curve, auc, average_precision_score
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values
user_estimators = 800

print('Original dataset shape {}'.format(Counter(indep_y)))
indep_result=Random_Forest_independent(x_whole_data, y_whole_data, indep_x, indep_y, user_estimators)
print("{}----------------------------------------------------".format(user_estimators))
print("Independent Accuracy : {}".format(indep_result[0]))
print("Independent AUC : {}".format(indep_result[1]))
print("Independent AUPR : {}".format(indep_result[2]))
print("Independent Confustion matrix")
print(indep_result[3])

rus = RandomUnderSampler()
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for i in range(0, 10):
    x_resampled, y_resampled = rus.fit_sample(indep_x, indep_y)
    indep_result = Random_Forest_independent(x_whole_data, y_whole_data, x_resampled, y_resampled, user_estimators)
    whole_accuracy.append(indep_result[0])
    whole_auc.append(indep_result[1])
    whole_aupr.append(indep_result[2])
    whole_confusion_mat.append(indep_result[3])
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# Original dataset shape Counter({0: 2462, 1: 93})
# 800----------------------------------------------------
# Independent Accuracy : 0.553033268102
# Independent AUC : 0.719877623752
# Independent AUPR : 0.236637208478
# Independent Confustion matrix
# [[1341 1121]
#  [  21   72]]
# Accuracy avg : 0.654301075269
# AUC avg : 0.72488148919
# AUPR avg : 0.744254729322
# Confustion matrix
# [[497 433]
#  [210 720]]

# %%
# new descriptor(0.5%) 사용시 2017.1.16. 수정됨. 2017.1.23. 추가됨 2017.2.1.
results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_whole_data_0_5, y_whole_data_0_5, user_estimators))
# Out:
# 120----------------------------------------------------
# Accuracy of this fold: 0.991916310033
# AUC of this fold: 0.928362395242
# AUPR of this fold: 0.822635184279
# Confustion matrix of this fold
# [[6162    3]
#  [  48   96]]
#
#
# Accuracy of this fold: 0.990965287684
# AUC of this fold: 0.914655988105
# AUPR of this fold: 0.752347089351
# Confustion matrix of this fold
# [[6160    5]
#  [  52   92]]
#
#
# Accuracy of this fold: 0.992074813758
# AUC of this fold: 0.935135059025
# AUPR of this fold: 0.799808115459
# Confustion matrix of this fold
# [[6161    4]
#  [  46   98]]
#
#
# Accuracy of this fold: 0.992233317483
# AUC of this fold: 0.939443092728
# AUPR of this fold: 0.809900911342
# Confustion matrix of this fold
# [[6163    2]
#  [  47   97]]
#
#
# Accuracy of this fold: 0.990963855422
# AUC of this fold: 0.925894543413
# AUPR of this fold: 0.760447617707
# Confustion matrix of this fold
# [[6158    7]
#  [  50   93]]
#
#
# Accuracy of this fold: 0.991280913126
# AUC of this fold: 0.91625859947
# AUPR of this fold: 0.766581363969
# Confustion matrix of this fold
# [[6163    2]
#  [  53   90]]
#
#
# Accuracy of this fold: 0.99127953068
# AUC of this fold: 0.927296665048
# AUPR of this fold: 0.800997345724
# Confustion matrix of this fold
# [[6160    4]
#  [  51   92]]
#
#
# Accuracy of this fold: 0.990962422705
# AUC of this fold: 0.919704079178
# AUPR of this fold: 0.78753181743
# Confustion matrix of this fold
# [[6161    3]
#  [  54   89]]
#
#
# Accuracy of this fold: 0.992547962581
# AUC of this fold: 0.913094530388
# AUPR of this fold: 0.800529497666
# Confustion matrix of this fold
# [[6164    0]
#  [  47   96]]
#
#
# Accuracy of this fold: 0.990328206754
# AUC of this fold: 0.901319640775
# AUPR of this fold: 0.739870007955
# Confustion matrix of this fold
# [[6159    5]
#  [  56   87]]
#
#
# Accuracy avg : 0.991455262023
# AUC avg : 0.922116459337
# AUPR avg : 0.784064895088
# Confustion matrix
# [[61611    35]
#  [  504   930]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.991282295134
# AUC of this fold: 0.933379516987
# AUPR of this fold: 0.787011354349
# Confustion matrix of this fold
# [[6161    4]
#  [  51   93]]
#
#
# Accuracy of this fold: 0.990965287684
# AUC of this fold: 0.929478124718
# AUPR of this fold: 0.789602945688
# Confustion matrix of this fold
# [[6159    6]
#  [  51   93]]
#
#
# Accuracy of this fold: 0.992233317483
# AUC of this fold: 0.938710349644
# AUPR of this fold: 0.824514148129
# Confustion matrix of this fold
# [[6162    3]
#  [  46   98]]
#
#
# Accuracy of this fold: 0.991916310033
# AUC of this fold: 0.936940727224
# AUPR of this fold: 0.820903270864
# Confustion matrix of this fold
# [[6161    4]
#  [  47   97]]
#
#
# Accuracy of this fold: 0.992073557387
# AUC of this fold: 0.931123701927
# AUPR of this fold: 0.776442900096
# Confustion matrix of this fold
# [[6161    4]
#  [  46   97]]
#
#
# Accuracy of this fold: 0.991597970831
# AUC of this fold: 0.925145900328
# AUPR of this fold: 0.777510275616
# Confustion matrix of this fold
# [[6161    4]
#  [  49   94]]
#
#
# Accuracy of this fold: 0.992547962581
# AUC of this fold: 0.922143236387
# AUPR of this fold: 0.804959368055
# Confustion matrix of this fold
# [[6163    1]
#  [  46   97]]
#
#
# Accuracy of this fold: 0.991438084668
# AUC of this fold: 0.913776927161
# AUPR of this fold: 0.769531354998
# Confustion matrix of this fold
# [[6163    1]
#  [  53   90]]
#
#
# Accuracy of this fold: 0.992072300618
# AUC of this fold: 0.955858628717
# AUPR of this fold: 0.822199385127
# Confustion matrix of this fold
# [[6161    3]
#  [  47   96]]
#
#
# Accuracy of this fold: 0.990011098779
# AUC of this fold: 0.905677790736
# AUPR of this fold: 0.724620971862
# Confustion matrix of this fold
# [[6161    3]
#  [  60   83]]
#
#
# Accuracy avg : 0.99161381852
# AUC avg : 0.929223490383
# AUPR avg : 0.789729597478
# Confustion matrix
# [[61613    33]
#  [  496   938]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.991757806308
# AUC of this fold: 0.926416486438
# AUPR of this fold: 0.792067462536
# Confustion matrix of this fold
# [[6161    4]
#  [  48   96]]
#
#
# Accuracy of this fold: 0.991599302584
# AUC of this fold: 0.941614850861
# AUPR of this fold: 0.81528184714
# Confustion matrix of this fold
# [[6162    3]
#  [  50   94]]
#
#
# Accuracy of this fold: 0.990806783959
# AUC of this fold: 0.913298639272
# AUPR of this fold: 0.747572054297
# Confustion matrix of this fold
# [[6162    3]
#  [  55   89]]
#
#
# Accuracy of this fold: 0.992867332382
# AUC of this fold: 0.952625146436
# AUPR of this fold: 0.833635885439
# Confustion matrix of this fold
# [[6163    2]
#  [  43  101]]
#
#
# Accuracy of this fold: 0.991756499683
# AUC of this fold: 0.909650689943
# AUPR of this fold: 0.751419993191
# Confustion matrix of this fold
# [[6164    1]
#  [  51   92]]
#
#
# Accuracy of this fold: 0.991756499683
# AUC of this fold: 0.914611017531
# AUPR of this fold: 0.762409541672
# Confustion matrix of this fold
# [[6163    2]
#  [  50   93]]
#
#
# Accuracy of this fold: 0.992547962581
# AUC of this fold: 0.933202828969
# AUPR of this fold: 0.835019537018
# Confustion matrix of this fold
# [[6159    5]
#  [  42  101]]
#
#
# Accuracy of this fold: 0.991596638655
# AUC of this fold: 0.949883828047
# AUPR of this fold: 0.816890995604
# Confustion matrix of this fold
# [[6160    4]
#  [  49   94]]
#
#
# Accuracy of this fold: 0.99064531473
# AUC of this fold: 0.916486660646
# AUPR of this fold: 0.75298631834
# Confustion matrix of this fold
# [[6159    5]
#  [  54   89]]
#
#
# Accuracy of this fold: 0.990486760742
# AUC of this fold: 0.945620975391
# AUPR of this fold: 0.772482232605
# Confustion matrix of this fold
# [[6157    7]
#  [  53   90]]
#
#
# Accuracy avg : 0.991582090131
# AUC avg : 0.930341112353
# AUPR avg : 0.787976586784
# Confustion matrix
# [[61610    36]
#  [  495   939]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.991282295134
# AUC of this fold: 0.916270163107
# AUPR of this fold: 0.757568051514
# Confustion matrix of this fold
# [[6162    3]
#  [  52   92]]
#
#
# Accuracy of this fold: 0.992233317483
# AUC of this fold: 0.94664098405
# AUPR of this fold: 0.817918414851
# Confustion matrix of this fold
# [[6162    3]
#  [  46   98]]
#
#
# Accuracy of this fold: 0.992233317483
# AUC of this fold: 0.910208277012
# AUPR of this fold: 0.775226668927
# Confustion matrix of this fold
# [[6162    3]
#  [  46   98]]
#
#
# Accuracy of this fold: 0.992074813758
# AUC of this fold: 0.934906956835
# AUPR of this fold: 0.823138389768
# Confustion matrix of this fold
# [[6160    5]
#  [  45   99]]
#
#
# Accuracy of this fold: 0.992073557387
# AUC of this fold: 0.929935514607
# AUPR of this fold: 0.817068463732
# Confustion matrix of this fold
# [[6161    4]
#  [  46   97]]
#
#
# Accuracy of this fold: 0.990329740013
# AUC of this fold: 0.939963361861
# AUPR of this fold: 0.759294652285
# Confustion matrix of this fold
# [[6164    1]
#  [  60   83]]
#
#
# Accuracy of this fold: 0.992547962581
# AUC of this fold: 0.91760356775
# AUPR of this fold: 0.797298824913
# Confustion matrix of this fold
# [[6163    1]
#  [  46   97]]
#
#
# Accuracy of this fold: 0.990328206754
# AUC of this fold: 0.923150097793
# AUPR of this fold: 0.761542460486
# Confustion matrix of this fold
# [[6160    4]
#  [  57   86]]
#
#
# Accuracy of this fold: 0.992706516569
# AUC of this fold: 0.966430957103
# AUPR of this fold: 0.847470060678
# Confustion matrix of this fold
# [[6161    3]
#  [  43  100]]
#
#
# Accuracy of this fold: 0.990011098779
# AUC of this fold: 0.915898993933
# AUPR of this fold: 0.725868856686
# Confustion matrix of this fold
# [[6157    7]
#  [  56   87]]
#
#
# Accuracy avg : 0.991582082594
# AUC avg : 0.930100887405
# AUPR avg : 0.788239484384
# Confustion matrix
# [[61612    34]
#  [  497   937]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.992867332382
# AUC of this fold: 0.925654456159
# AUPR of this fold: 0.806276025402
# Confustion matrix of this fold
# [[6163    2]
#  [  43  101]]
#
#
# Accuracy of this fold: 0.991916310033
# AUC of this fold: 0.917615684419
# AUPR of this fold: 0.775209618029
# Confustion matrix of this fold
# [[6164    1]
#  [  50   94]]
#
#
# Accuracy of this fold: 0.990014265335
# AUC of this fold: 0.939239208795
# AUPR of this fold: 0.757181642649
# Confustion matrix of this fold
# [[6158    7]
#  [  56   88]]
#
#
# Accuracy of this fold: 0.991599302584
# AUC of this fold: 0.931822226728
# AUPR of this fold: 0.813031834674
# Confustion matrix of this fold
# [[6163    2]
#  [  51   93]]
#
#
# Accuracy of this fold: 0.990488268865
# AUC of this fold: 0.929200483215
# AUPR of this fold: 0.743162195996
# Confustion matrix of this fold
# [[6161    4]
#  [  56   87]]
#
#
# Accuracy of this fold: 0.991122384274
# AUC of this fold: 0.924921307403
# AUPR of this fold: 0.79192773705
# Confustion matrix of this fold
# [[6159    6]
#  [  50   93]]
#
#
# Accuracy of this fold: 0.992706516569
# AUC of this fold: 0.957188253019
# AUPR of this fold: 0.854377544075
# Confustion matrix of this fold
# [[6162    2]
#  [  44   99]]
#
#
# Accuracy of this fold: 0.991913746631
# AUC of this fold: 0.937872396909
# AUPR of this fold: 0.812203034738
# Confustion matrix of this fold
# [[6161    3]
#  [  48   95]]
#
#
# Accuracy of this fold: 0.990328206754
# AUC of this fold: 0.928950753983
# AUPR of this fold: 0.748677069147
# Confustion matrix of this fold
# [[6159    5]
#  [  56   87]]
#
#
# Accuracy of this fold: 0.990962422705
# AUC of this fold: 0.912638464715
# AUPR of this fold: 0.765132600478
# Confustion matrix of this fold
# [[6159    5]
#  [  52   91]]
#
#
# Accuracy avg : 0.991391875613
# AUC avg : 0.930510323535
# AUPR avg : 0.786717930224
# Confustion matrix
# [[61609    37]
#  [  506   928]]

# %%
#new descriptor(0.5%)의 independent test 2017.2.1. Random undersampling 추가. 2017.2.2.
from sklearn.metrics import roc_curve, auc, average_precision_score
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values
user_estimators = 300
print('highest AUPR-----------------------------------')
print('Original dataset shape {}'.format(Counter(indep_y)))
indep_result=Random_Forest_independent(x_whole_data_0_5, y_whole_data_0_5, indep_x, indep_y, user_estimators)
print("{}----------------------------------------------------".format(user_estimators))
print("Independent Accuracy : {}".format(indep_result[0]))
print("Independent AUC : {}".format(indep_result[1]))
print("Independent AUPR : {}".format(indep_result[2]))
print("Independent Confustion matrix")
print(indep_result[3])

print('\nResampled dataset')
rus = RandomUnderSampler()
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for i in range(0, 10):
    x_resampled, y_resampled = rus.fit_sample(indep_x, indep_y)
    indep_result = Random_Forest_independent(x_whole_data_0_5, y_whole_data_0_5, x_resampled, y_resampled, user_estimators)
    whole_accuracy.append(indep_result[0])
    whole_auc.append(indep_result[1])
    whole_aupr.append(indep_result[2])
    whole_confusion_mat.append(indep_result[3])
print('resampled dataset shape {}'.format(Counter(y_resampled)))
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat)) 

print('\nhighest AUC-----------------------------------')
user_estimators = 1200
indep_result=Random_Forest_independent(x_whole_data_0_5, y_whole_data_0_5, indep_x, indep_y, user_estimators)
print("{}----------------------------------------------------".format(user_estimators))
print("Independent Accuracy : {}".format(indep_result[0]))
print("Independent AUC : {}".format(indep_result[1]))
print("Independent AUPR : {}".format(indep_result[2]))
print("Independent Confustion matrix")
print(indep_result[3])

print('\nResampled dataset')
rus = RandomUnderSampler()
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for i in range(0, 10):
    x_resampled, y_resampled = rus.fit_sample(indep_x, indep_y)
    indep_result = Random_Forest_independent(x_whole_data_0_5, y_whole_data_0_5, x_resampled, y_resampled, user_estimators)
    whole_accuracy.append(indep_result[0])
    whole_auc.append(indep_result[1])
    whole_aupr.append(indep_result[2])
    whole_confusion_mat.append(indep_result[3])
print('resampled dataset shape {}'.format(Counter(y_resampled)))
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# highest AUPR-----------------------------------
# Original dataset shape Counter({0: 2462, 1: 93})
# 300----------------------------------------------------
# Independent Accuracy : 0.578082191781
# Independent AUC : 0.67306718028
# Independent AUPR : 0.142314761791
# Independent Confustion matrix
# [[1405 1057]
#  [  21   72]]
#
# Resampled dataset
# resampled dataset shape Counter({0: 93, 1: 93})
# Accuracy avg : 0.681720430108
# AUC avg : 0.676517516476
# AUPR avg : 0.673284456005
# Confustion matrix
# [[548 382]
#  [210 720]]
#
# highest AUC-----------------------------------
# 1200----------------------------------------------------
# Independent Accuracy : 0.578082191781
# Independent AUC : 0.665884891207
# Independent AUPR : 0.140541882556
# Independent Confustion matrix
# [[1405 1057]
#  [  21   72]]
#
# Resampled dataset
# Accuracy avg : 0.676344086022
# AUC avg : 0.675101167765
# AUPR avg : 0.663178694117
# Confustion matrix
# [[538 392]
#  [210 720]]

# %%
# new descriptor(0.1%) 사용시 2017.1.16. 수정됨. 2017.1.23. 추가됨 2017.2.1.
results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_whole_data_0_1, y_whole_data_0_1, user_estimators))
# Out:
# 120----------------------------------------------------
# Accuracy of this fold: 0.990631221455
# AUC of this fold: 0.867244474224
# AUPR of this fold: 0.633827461405
# Confustion matrix of this fold
# [[8385   10]
#  [  70   74]]
#
#
# Accuracy of this fold: 0.988991685209
# AUC of this fold: 0.895983058699
# AUPR of this fold: 0.63692067905
# Confustion matrix of this fold
# [[8374   21]
#  [  73   71]]
#
#
# Accuracy of this fold: 0.991802318773
# AUC of this fold: 0.910508487195
# AUPR of this fold: 0.729145137431
# Confustion matrix of this fold
# [[8379   16]
#  [  54   90]]
#
#
# Accuracy of this fold: 0.990865440918
# AUC of this fold: 0.898031235524
# AUPR of this fold: 0.706674321347
# Confustion matrix of this fold
# [[8380   15]
#  [  63   81]]
#
#
# Accuracy of this fold: 0.991215741391
# AUC of this fold: 0.885929853351
# AUPR of this fold: 0.676472431489
# Confustion matrix of this fold
# [[8382   13]
#  [  62   81]]
#
#
# Accuracy of this fold: 0.99133286484
# AUC of this fold: 0.88130338988
# AUPR of this fold: 0.690547878516
# Confustion matrix of this fold
# [[8385   10]
#  [  64   79]]
#
#
# Accuracy of this fold: 0.991097575261
# AUC of this fold: 0.92247667748
# AUPR of this fold: 0.712524208815
# Confustion matrix of this fold
# [[8377   17]
#  [  59   84]]
#
#
# Accuracy of this fold: 0.990043340752
# AUC of this fold: 0.893207935738
# AUPR of this fold: 0.652484590117
# Confustion matrix of this fold
# [[8378   16]
#  [  69   74]]
#
#
# Accuracy of this fold: 0.990394752255
# AUC of this fold: 0.885159396239
# AUPR of this fold: 0.623061598508
# Confustion matrix of this fold
# [[8386    8]
#  [  74   69]]
#
#
# Accuracy of this fold: 0.990043340752
# AUC of this fold: 0.895337745409
# AUPR of this fold: 0.681846910331
# Confustion matrix of this fold
# [[8377   17]
#  [  68   75]]
#
#
# Accuracy avg : 0.99064182816
# AUC avg : 0.893518225374
# AUPR avg : 0.674350521701
# Confustion matrix
# [[83803   143]
#  [  656   778]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.991919428505
# AUC of this fold: 0.950010753756
# AUPR of this fold: 0.793329903435
# Confustion matrix of this fold
# [[8378   17]
#  [  52   92]]
#
#
# Accuracy of this fold: 0.990865440918
# AUC of this fold: 0.923885331877
# AUPR of this fold: 0.690766401072
# Confustion matrix of this fold
# [[8380   15]
#  [  63   81]]
#
#
# Accuracy of this fold: 0.989811453332
# AUC of this fold: 0.908355668056
# AUPR of this fold: 0.64206474669
# Confustion matrix of this fold
# [[8380   15]
#  [  72   72]]
#
#
# Accuracy of this fold: 0.989928563064
# AUC of this fold: 0.892530275958
# AUPR of this fold: 0.687829812985
# Confustion matrix of this fold
# [[8377   18]
#  [  68   76]]
#
#
# Accuracy of this fold: 0.990278753807
# AUC of this fold: 0.913488298479
# AUPR of this fold: 0.665207216113
# Confustion matrix of this fold
# [[8382   13]
#  [  70   73]]
#
#
# Accuracy of this fold: 0.992035605528
# AUC of this fold: 0.896812538266
# AUPR of this fold: 0.735960843695
# Confustion matrix of this fold
# [[8387    8]
#  [  60   83]]
#
#
# Accuracy of this fold: 0.989574792082
# AUC of this fold: 0.896087115172
# AUPR of this fold: 0.659635380193
# Confustion matrix of this fold
# [[8376   18]
#  [  71   72]]
#
#
# Accuracy of this fold: 0.990511889423
# AUC of this fold: 0.897904930428
# AUPR of this fold: 0.667602287867
# Confustion matrix of this fold
# [[8382   12]
#  [  69   74]]
#
#
# Accuracy of this fold: 0.990746163758
# AUC of this fold: 0.886738529519
# AUPR of this fold: 0.646059094298
# Confustion matrix of this fold
# [[8377   17]
#  [  62   81]]
#
#
# Accuracy of this fold: 0.990043340752
# AUC of this fold: 0.899388674228
# AUPR of this fold: 0.643030882395
# Confustion matrix of this fold
# [[8383   11]
#  [  74   69]]
#
#
# Accuracy avg : 0.990571543117
# AUC avg : 0.906520211574
# AUPR avg : 0.683148656874
# Confustion matrix
# [[83802   144]
#  [  661   773]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.989928563064
# AUC of this fold: 0.911878763814
# AUPR of this fold: 0.665902922515
# Confustion matrix of this fold
# [[8382   13]
#  [  73   71]]
#
#
# Accuracy of this fold: 0.990865440918
# AUC of this fold: 0.923786480048
# AUPR of this fold: 0.713232586325
# Confustion matrix of this fold
# [[8379   16]
#  [  62   82]]
#
#
# Accuracy of this fold: 0.991216770114
# AUC of this fold: 0.906925004963
# AUPR of this fold: 0.703258920566
# Confustion matrix of this fold
# [[8382   13]
#  [  62   82]]
#
#
# Accuracy of this fold: 0.990162782527
# AUC of this fold: 0.889740917213
# AUPR of this fold: 0.680735984795
# Confustion matrix of this fold
# [[8377   18]
#  [  66   78]]
#
#
# Accuracy of this fold: 0.990630124151
# AUC of this fold: 0.930918337172
# AUPR of this fold: 0.706324611458
# Confustion matrix of this fold
# [[8377   18]
#  [  62   81]]
#
#
# Accuracy of this fold: 0.990513000703
# AUC of this fold: 0.917157648784
# AUPR of this fold: 0.723420962371
# Confustion matrix of this fold
# [[8385   10]
#  [  71   72]]
#
#
# Accuracy of this fold: 0.990746163758
# AUC of this fold: 0.922890309595
# AUPR of this fold: 0.716137023491
# Confustion matrix of this fold
# [[8380   14]
#  [  65   78]]
#
#
# Accuracy of this fold: 0.99016047792
# AUC of this fold: 0.869424713957
# AUPR of this fold: 0.610673554298
# Confustion matrix of this fold
# [[8382   12]
#  [  72   71]]
#
#
# Accuracy of this fold: 0.991097575261
# AUC of this fold: 0.902994313287
# AUPR of this fold: 0.681309985813
# Confustion matrix of this fold
# [[8380   14]
#  [  62   81]]
#
#
# Accuracy of this fold: 0.990746163758
# AUC of this fold: 0.901173998744
# AUPR of this fold: 0.654788111298
# Confustion matrix of this fold
# [[8383   11]
#  [  68   75]]
#
#
# Accuracy avg : 0.990606706217
# AUC avg : 0.907689048758
# AUPR avg : 0.685578466293
# Confustion matrix
# [[83807   139]
#  [  663   771]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.990748331186
# AUC of this fold: 0.921930216399
# AUPR of this fold: 0.696993975291
# Confustion matrix of this fold
# [[8382   13]
#  [  66   78]]
#
#
# Accuracy of this fold: 0.990397001991
# AUC of this fold: 0.912958689034
# AUPR of this fold: 0.723459641343
# Confustion matrix of this fold
# [[8377   18]
#  [  64   80]]
#
#
# Accuracy of this fold: 0.99098255065
# AUC of this fold: 0.894073439878
# AUPR of this fold: 0.693691947943
# Confustion matrix of this fold
# [[8382   13]
#  [  64   80]]
#
#
# Accuracy of this fold: 0.990279892259
# AUC of this fold: 0.908497948514
# AUPR of this fold: 0.657829753324
# Confustion matrix of this fold
# [[8382   13]
#  [  70   74]]
#
#
# Accuracy of this fold: 0.989927383462
# AUC of this fold: 0.927134033328
# AUPR of this fold: 0.665030293013
# Confustion matrix of this fold
# [[8379   16]
#  [  70   73]]
#
#
# Accuracy of this fold: 0.989576013118
# AUC of this fold: 0.881764453533
# AUPR of this fold: 0.623085538636
# Confustion matrix of this fold
# [[8378   17]
#  [  72   71]]
#
#
# Accuracy of this fold: 0.991448986764
# AUC of this fold: 0.924793100633
# AUPR of this fold: 0.722783241953
# Confustion matrix of this fold
# [[8381   13]
#  [  60   83]]
#
#
# Accuracy of this fold: 0.991331849596
# AUC of this fold: 0.926535104162
# AUPR of this fold: 0.719340244559
# Confustion matrix of this fold
# [[8381   13]
#  [  61   82]]
#
#
# Accuracy of this fold: 0.990277615087
# AUC of this fold: 0.892439821318
# AUPR of this fold: 0.635251405537
# Confustion matrix of this fold
# [[8384   10]
#  [  73   70]]
#
#
# Accuracy of this fold: 0.990277615087
# AUC of this fold: 0.920582633949
# AUPR of this fold: 0.68880260799
# Confustion matrix of this fold
# [[8377   17]
#  [  66   77]]
#
#
# Accuracy avg : 0.99052472392
# AUC avg : 0.911070944075
# AUPR avg : 0.682626864959
# Confustion matrix
# [[83803   143]
#  [  666   768]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.991099660382
# AUC of this fold: 0.928747270201
# AUPR of this fold: 0.689117380618
# Confustion matrix of this fold
# [[8379   16]
#  [  60   84]]
#
#
# Accuracy of this fold: 0.990397001991
# AUC of this fold: 0.904170802726
# AUPR of this fold: 0.683180492859
# Confustion matrix of this fold
# [[8380   15]
#  [  67   77]]
#
#
# Accuracy of this fold: 0.989577233868
# AUC of this fold: 0.881444394812
# AUPR of this fold: 0.630138666211
# Confustion matrix of this fold
# [[8384   11]
#  [  78   66]]
#
#
# Accuracy of this fold: 0.990397001991
# AUC of this fold: 0.887666269605
# AUPR of this fold: 0.632448070605
# Confustion matrix of this fold
# [[8385   10]
#  [  72   72]]
#
#
# Accuracy of this fold: 0.990630124151
# AUC of this fold: 0.925206895546
# AUPR of this fold: 0.667972656638
# Confustion matrix of this fold
# [[8381   14]
#  [  66   77]]
#
#
# Accuracy of this fold: 0.990630124151
# AUC of this fold: 0.932392324769
# AUPR of this fold: 0.707925442619
# Confustion matrix of this fold
# [[8377   18]
#  [  62   81]]
#
#
# Accuracy of this fold: 0.990746163758
# AUC of this fold: 0.919140961493
# AUPR of this fold: 0.726952646236
# Confustion matrix of this fold
# [[8380   14]
#  [  65   78]]
#
#
# Accuracy of this fold: 0.990043340752
# AUC of this fold: 0.919190530699
# AUPR of this fold: 0.687076157161
# Confustion matrix of this fold
# [[8374   20]
#  [  65   78]]
#
#
# Accuracy of this fold: 0.991331849596
# AUC of this fold: 0.917876738463
# AUPR of this fold: 0.734286557896
# Confustion matrix of this fold
# [[8378   16]
#  [  58   85]]
#
#
# Accuracy of this fold: 0.991331849596
# AUC of this fold: 0.915203333717
# AUPR of this fold: 0.704406013351
# Confustion matrix of this fold
# [[8383   11]
#  [  63   80]]
#
#
# Accuracy avg : 0.990618435023
# AUC avg : 0.913103952203
# AUPR avg : 0.686350408419
# Confustion matrix
# [[83801   145]
#  [  656   778]]

# %%
#new descriptor(0.1%)의 independent test 2017.2.1. Random undersampling 추가. 2017.2.2.

from sklearn.metrics import roc_curve, auc, average_precision_score
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values
user_estimators = 1200

print('Original dataset shape {}'.format(Counter(indep_y)))
indep_result=Random_Forest_independent(x_whole_data_0_1, y_whole_data_0_1, indep_x, indep_y, user_estimators)
print("{}----------------------------------------------------".format(user_estimators))
print("Independent Accuracy : {}".format(indep_result[0]))
print("Independent AUC : {}".format(indep_result[1]))
print("Independent AUPR : {}".format(indep_result[2]))
print("Independent Confustion matrix")
print(indep_result[3])

rus = RandomUnderSampler()
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for i in range(0, 10):
    x_resampled, y_resampled = rus.fit_sample(indep_x, indep_y)
    indep_result = Random_Forest_independent(x_whole_data_0_1, y_whole_data_0_1, x_resampled, y_resampled, user_estimators)
    whole_accuracy.append(indep_result[0])
    whole_auc.append(indep_result[1])
    whole_aupr.append(indep_result[2])
    whole_confusion_mat.append(indep_result[3])
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# Original dataset shape Counter({0: 2462, 1: 93})
# 1200----------------------------------------------------
# Independent Accuracy : 0.824657534247
# Independent AUC : 0.797502685988
# Independent AUPR : 0.13024938536
# Independent Confustion matrix
# [[2040  422]
#  [  26   67]]
# Accuracy avg : 0.765591397849
# AUC avg : 0.796097814776
# AUPR avg : 0.773235606268
# Confustion matrix
# [[754 176]
#  [260 670]]

# %%
#new descriptor(1%)의 independent test 2017.2.1.
indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

x_whole_data = df[df.columns.values[3:].tolist()].values
y_whole_data = df["association"].values
indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
classifier = RandomForestClassifier(n_estimators=800, n_jobs=-1, class_weight='balanced')
classifier.fit(x_whole_data, y_whole_data)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# Independent Accuracy : 0.552641878669
# Independent AUC : 0.714160617734
# Independent AUPR : 0.174402447238
# Independent Confustion matrix
# [[1340 1122]
#  [  21   72]]

# %%
#new descriptor(0.5%)의 independent test 2017.2.1.
indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
classifier = RandomForestClassifier(n_estimators=300, n_jobs=-1, class_weight='balanced')
classifier.fit(x_whole_data_0_5, y_whole_data_0_5)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("n_estimators = 300 : highest AUPR")
print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")

classifier = RandomForestClassifier(n_estimators=1200, n_jobs=-1, class_weight='balanced')
classifier.fit(x_whole_data_0_5, y_whole_data_0_5)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])
print("n_estimators = 1200 : highest AUC")
print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# n_estimators = 300 : highest AUPR
# Independent Accuracy : 0.578082191781
# Independent AUC : 0.666572766262
# Independent AUPR : 0.154087987825
# Independent Confustion matrix
# [[1405 1057]
#  [  21   72]]
#
# n_estimators = 1200 : highest AUC
# Independent Accuracy : 0.578082191781
# Independent AUC : 0.670475092372
# Independent AUPR : 0.138136779972
# Independent Confustion matrix
# [[1405 1057]
#  [  21   72]]

# %%
#new descriptor(0.1%)의 independent test 2017.2.1.
indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
classifier = RandomForestClassifier(n_estimators=1200, n_jobs=-1, class_weight='balanced')
classifier.fit(x_whole_data_0_1, y_whole_data_0_1)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# Independent Accuracy : 0.822309197652
# Independent AUC : 0.805250561219
# Independent AUPR : 0.12500479921
# Independent Confustion matrix
# [[2034  428]
#  [  26   67]]

# %%
#기존 descriptor 사용 2017.1.16.
original_df = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_1_descriptor_combined.tsv")
x_whole_data = original_df[original_df.columns.values[3:].tolist()].values
y_whole_data = original_df["association"].values
results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_whole_data, y_whole_data, user_estimators))
# Out:
# 120----------------------------------------------------
# Accuracy of this fold: 0.988888888889
# AUC of this fold: 0.867375157626
# AUPR of this fold: 0.418646630081
# Confustion matrix of this fold
# [[10902    24]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.988797542687
# AUC of this fold: 0.834445080092
# AUPR of this fold: 0.371158051324
# Confustion matrix of this fold
# [[10908    17]
#  [  107    37]]
#
#
# Accuracy of this fold: 0.990604390641
# AUC of this fold: 0.847984045258
# AUPR of this fold: 0.468445780731
# Confustion matrix of this fold
# [[10908    17]
#  [   87    57]]
#
#
# Accuracy of this fold: 0.990152678652
# AUC of this fold: 0.852038838037
# AUPR of this fold: 0.483074736231
# Confustion matrix of this fold
# [[10905    20]
#  [   89    55]]
#
#
# Accuracy of this fold: 0.988796530538
# AUC of this fold: 0.847329055384
# AUPR of this fold: 0.401878370227
# Confustion matrix of this fold
# [[10903    22]
#  [  102    41]]
#
#
# Accuracy of this fold: 0.989067582219
# AUC of this fold: 0.872083660047
# AUPR of this fold: 0.422936041769
# Confustion matrix of this fold
# [[10901    24]
#  [   97    46]]
#
#
# Accuracy of this fold: 0.9893386339
# AUC of this fold: 0.882545326527
# AUPR of this fold: 0.453060257475
# Confustion matrix of this fold
# [[10905    20]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.989971087821
# AUC of this fold: 0.882236162007
# AUPR of this fold: 0.444821506535
# Confustion matrix of this fold
# [[10911    14]
#  [   97    46]]
#
#
# Accuracy of this fold: 0.988886881099
# AUC of this fold: 0.82233569634
# AUPR of this fold: 0.338523595171
# Confustion matrix of this fold
# [[10901    24]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.989971087821
# AUC of this fold: 0.860151701845
# AUPR of this fold: 0.480393189691
# Confustion matrix of this fold
# [[10910    15]
#  [   96    47]]
#
#
# Accuracy avg : 0.989447530427
# AUC avg : 0.856852472316
# AUPR avg : 0.428293815923
# Confustion matrix
# [[109054    197]
#  [   971    463]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.989069557362
# AUC of this fold: 0.884093370553
# AUPR of this fold: 0.425532325875
# Confustion matrix of this fold
# [[10904    22]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.98906856988
# AUC of this fold: 0.843393719807
# AUPR of this fold: 0.397916115264
# Confustion matrix of this fold
# [[10908    17]
#  [  104    40]]
#
#
# Accuracy of this fold: 0.989520281868
# AUC of this fold: 0.841564009662
# AUPR of this fold: 0.405520720425
# Confustion matrix of this fold
# [[10909    16]
#  [  100    44]]
#
#
# Accuracy of this fold: 0.989158912278
# AUC of this fold: 0.858599987287
# AUPR of this fold: 0.424947779922
# Confustion matrix of this fold
# [[10901    24]
#  [   96    48]]
#
#
# Accuracy of this fold: 0.988254427177
# AUC of this fold: 0.855391976445
# AUPR of this fold: 0.347455808646
# Confustion matrix of this fold
# [[10901    24]
#  [  106    37]]
#
#
# Accuracy of this fold: 0.988796530538
# AUC of this fold: 0.853208622042
# AUPR of this fold: 0.40489039704
# Confustion matrix of this fold
# [[10904    21]
#  [  103    40]]
#
#
# Accuracy of this fold: 0.990693892302
# AUC of this fold: 0.879780448385
# AUPR of this fold: 0.516780854881
# Confustion matrix of this fold
# [[10911    14]
#  [   89    54]]
#
#
# Accuracy of this fold: 0.990332490061
# AUC of this fold: 0.875488630363
# AUPR of this fold: 0.490504824048
# Confustion matrix of this fold
# [[10908    17]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.988977231659
# AUC of this fold: 0.876882111024
# AUPR of this fold: 0.415551114163
# Confustion matrix of this fold
# [[10903    22]
#  [  100    43]]
#
#
# Accuracy of this fold: 0.990422840622
# AUC of this fold: 0.898667968187
# AUPR of this fold: 0.514647929399
# Confustion matrix of this fold
# [[10907    18]
#  [   88    55]]
#
#
# Accuracy avg : 0.989429473375
# AUC avg : 0.866707084375
# AUPR avg : 0.434374786966
# Confustion matrix
# [[109056    195]
#  [   975    459]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.988708220416
# AUC of this fold: 0.875051482702
# AUPR of this fold: 0.430313178324
# Confustion matrix of this fold
# [[10902    24]
#  [  101    43]]
#
#
# Accuracy of this fold: 0.989700966664
# AUC of this fold: 0.846795703026
# AUPR of this fold: 0.422111219613
# Confustion matrix of this fold
# [[10904    21]
#  [   93    51]]
#
#
# Accuracy of this fold: 0.989791309061
# AUC of this fold: 0.848477943046
# AUPR of this fold: 0.408347605154
# Confustion matrix of this fold
# [[10911    14]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.989249254675
# AUC of this fold: 0.856666666667
# AUPR of this fold: 0.430332960702
# Confustion matrix of this fold
# [[10910    15]
#  [  104    40]]
#
#
# Accuracy of this fold: 0.990061438381
# AUC of this fold: 0.863812068938
# AUPR of this fold: 0.474953201465
# Confustion matrix of this fold
# [[10906    19]
#  [   91    52]]
#
#
# Accuracy of this fold: 0.988615829418
# AUC of this fold: 0.893182058216
# AUPR of this fold: 0.390987361439
# Confustion matrix of this fold
# [[10903    22]
#  [  104    39]]
#
#
# Accuracy of this fold: 0.990061438381
# AUC of this fold: 0.857012689827
# AUPR of this fold: 0.442601898374
# Confustion matrix of this fold
# [[10908    17]
#  [   93    50]]
#
#
# Accuracy of this fold: 0.98942898446
# AUC of this fold: 0.896375798115
# AUPR of this fold: 0.484291608684
# Confustion matrix of this fold
# [[10898    27]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.98942898446
# AUC of this fold: 0.891213774784
# AUPR of this fold: 0.39593224924
# Confustion matrix of this fold
# [[10911    14]
#  [  103    40]]
#
#
# Accuracy of this fold: 0.989067582219
# AUC of this fold: 0.877337536605
# AUPR of this fold: 0.412542216862
# Confustion matrix of this fold
# [[10905    20]
#  [  101    42]]
#
#
# Accuracy avg : 0.989411400813
# AUC avg : 0.870592572193
# AUPR avg : 0.429241349986
# Confustion matrix
# [[109058    193]
#  [   979    455]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.990334236676
# AUC of this fold: 0.858870977993
# AUPR of this fold: 0.458154691036
# Confustion matrix of this fold
# [[10913    13]
#  [   94    50]]
#
#
# Accuracy of this fold: 0.989700966664
# AUC of this fold: 0.884530892449
# AUPR of this fold: 0.461787715847
# Confustion matrix of this fold
# [[10908    17]
#  [   97    47]]
#
#
# Accuracy of this fold: 0.989520281868
# AUC of this fold: 0.874162217137
# AUPR of this fold: 0.424138226701
# Confustion matrix of this fold
# [[10903    22]
#  [   94    50]]
#
#
# Accuracy of this fold: 0.989339597073
# AUC of this fold: 0.855125222476
# AUPR of this fold: 0.413106961342
# Confustion matrix of this fold
# [[10907    18]
#  [  100    44]]
#
#
# Accuracy of this fold: 0.990422840622
# AUC of this fold: 0.872056776176
# AUPR of this fold: 0.49876746521
# Confustion matrix of this fold
# [[10916     9]
#  [   97    46]]
#
#
# Accuracy of this fold: 0.990332490061
# AUC of this fold: 0.859137795843
# AUPR of this fold: 0.435323606093
# Confustion matrix of this fold
# [[10908    17]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.988977231659
# AUC of this fold: 0.882710150262
# AUPR of this fold: 0.46201466302
# Confustion matrix of this fold
# [[10897    28]
#  [   94    49]]
#
#
# Accuracy of this fold: 0.98960968558
# AUC of this fold: 0.893311676881
# AUPR of this fold: 0.435124365817
# Confustion matrix of this fold
# [[10907    18]
#  [   97    46]]
#
#
# Accuracy of this fold: 0.989067582219
# AUC of this fold: 0.890910051047
# AUPR of this fold: 0.470154390148
# Confustion matrix of this fold
# [[10900    25]
#  [   96    47]]
#
#
# Accuracy of this fold: 0.988254427177
# AUC of this fold: 0.857991710806
# AUPR of this fold: 0.357169949306
# Confustion matrix of this fold
# [[10905    20]
#  [  110    33]]
#
#
# Accuracy avg : 0.98955593396
# AUC avg : 0.872880747107
# AUPR avg : 0.441574203452
# Confustion matrix
# [[109064    187]
#  [   969    465]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.989972899729
# AUC of this fold: 0.901880961824
# AUPR of this fold: 0.494718975345
# Confustion matrix of this fold
# [[10909    17]
#  [   94    50]]
#
#
# Accuracy of this fold: 0.988887885084
# AUC of this fold: 0.879537248919
# AUPR of this fold: 0.42712893583
# Confustion matrix of this fold
# [[10900    25]
#  [   98    46]]
#
#
# Accuracy of this fold: 0.990152678652
# AUC of this fold: 0.880636600559
# AUPR of this fold: 0.490863001948
# Confustion matrix of this fold
# [[10910    15]
#  [   94    50]]
#
#
# Accuracy of this fold: 0.988255488301
# AUC of this fold: 0.842643020595
# AUPR of this fold: 0.366625666098
# Confustion matrix of this fold
# [[10903    22]
#  [  108    36]]
#
#
# Accuracy of this fold: 0.988796530538
# AUC of this fold: 0.876964362868
# AUPR of this fold: 0.422440596309
# Confustion matrix of this fold
# [[10900    25]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.9897903867
# AUC of this fold: 0.895693459858
# AUPR of this fold: 0.471254036502
# Confustion matrix of this fold
# [[10902    23]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.991145645103
# AUC of this fold: 0.866343953529
# AUPR of this fold: 0.52643231264
# Confustion matrix of this fold
# [[10915    10]
#  [   88    55]]
#
#
# Accuracy of this fold: 0.988344777738
# AUC of this fold: 0.850977260726
# AUPR of this fold: 0.368175840007
# Confustion matrix of this fold
# [[10901    24]
#  [  105    38]]
#
#
# Accuracy of this fold: 0.990332490061
# AUC of this fold: 0.913346241859
# AUPR of this fold: 0.488912865916
# Confustion matrix of this fold
# [[10908    17]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.988615829418
# AUC of this fold: 0.827606215295
# AUPR of this fold: 0.352814212402
# Confustion matrix of this fold
# [[10907    18]
#  [  108    35]]
#
#
# Accuracy avg : 0.989429461133
# AUC avg : 0.873562932603
# AUPR avg : 0.4409366443
# Confustion matrix
# [[109055    196]
#  [   974    460]]

# %%
#기존 descriptor의 independent test 2017.1.16. #2017.2.13. 수정
from sklearn.metrics import roc_curve, auc, average_precision_score

indep_x = indep.values[:, 3:].astype(float)
indep_y = indep.values[:,2].astype(int)
user_estimators = 800
print('Original dataset shape {}'.format(Counter(indep_y)))
indep_result = Random_Forest_independent(x_whole_data, y_whole_data, indep_x, indep_y, user_estimators)
print("{}----------------------------------------------------".format(user_estimators))
print("Independent Accuracy : {}".format(indep_result[0]))
print("Independent AUC : {}".format(indep_result[1]))
print("Independent AUPR : {}".format(indep_result[2]))
print("Independent Confustion matrix")
print(indep_result[3])

rus = RandomUnderSampler()
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for i in range(0, 10):
    x_resampled, y_resampled = rus.fit_sample(indep_x, indep_y)
    indep_result = Random_Forest_independent(x_whole_data, y_whole_data, x_resampled, y_resampled, user_estimators)
    whole_accuracy.append(indep_result[0])
    whole_auc.append(indep_result[1])
    whole_aupr.append(indep_result[2])
    whole_confusion_mat.append(indep_result[3])
print('\nResampled dataset shape {}'.format(Counter(y_resampled)))
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# Original dataset shape Counter({0: 2462, 1: 93})
# 800----------------------------------------------------
# Independent Accuracy : 0.979647749511
# Independent AUC : 0.903319706856
# Independent AUPR : 0.668596110169
# Independent Confustion matrix
# [[2439   23]
#  [  29   64]]
#
# Resampled dataset shape Counter({0: 93, 1: 93})
# Accuracy avg : 0.838709677419
# AUC avg : 0.879118973292
# AUPR avg : 0.914989381119
# Confustion matrix
# [[920  10]
#  [290 640]]

# %%
# imbalanced learn RandomUnderSampler사용(기존 descriptor) 2017.1.17.

from sklearn.metrics import roc_curve, auc, average_precision_score
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

print('Original dataset shape {}'.format(Counter(y_whole_data)))
rus = RandomUnderSampler()
x_resampled, y_resampled = rus.fit_sample(x_whole_data, y_whole_data)
print('Resampled dataset shape {}'.format(Counter(y_resampled)))

results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_resampled, y_resampled, user_estimators))
# Out:
# Original dataset shape Counter({0: 109251, 1: 1434})
# Resampled dataset shape Counter({0: 1434, 1: 1434})
# 120----------------------------------------------------
# Accuracy of this fold: 0.694444444444
# AUC of this fold: 0.773992091049
# AUPR of this fold: 0.797459860278
# Confustion matrix of this fold
# [[ 97  47]
#  [ 41 103]]
#
#
# Accuracy of this fold: 0.673611111111
# AUC of this fold: 0.747058256173
# AUPR of this fold: 0.74763650394
# Confustion matrix of this fold
# [[98 46]
#  [48 96]]
#
#
# Accuracy of this fold: 0.746527777778
# AUC of this fold: 0.824074074074
# AUPR of this fold: 0.845831813771
# Confustion matrix of this fold
# [[103  41]
#  [ 32 112]]
#
#
# Accuracy of this fold: 0.711805555556
# AUC of this fold: 0.770568094136
# AUPR of this fold: 0.792462629338
# Confustion matrix of this fold
# [[ 98  46]
#  [ 37 107]]
#
#
# Accuracy of this fold: 0.667832167832
# AUC of this fold: 0.729962345347
# AUPR of this fold: 0.712530871237
# Confustion matrix of this fold
# [[95 48]
#  [47 96]]
#
#
# Accuracy of this fold: 0.692307692308
# AUC of this fold: 0.754511223043
# AUPR of this fold: 0.743427822467
# Confustion matrix of this fold
# [[ 93  50]
#  [ 38 105]]
#
#
# Accuracy of this fold: 0.685314685315
# AUC of this fold: 0.768717296689
# AUPR of this fold: 0.792231762726
# Confustion matrix of this fold
# [[ 90  53]
#  [ 37 106]]
#
#
# Accuracy of this fold: 0.713286713287
# AUC of this fold: 0.795515673138
# AUPR of this fold: 0.820792978854
# Confustion matrix of this fold
# [[105  38]
#  [ 44  99]]
#
#
# Accuracy of this fold: 0.695804195804
# AUC of this fold: 0.774585554306
# AUPR of this fold: 0.7856793427
# Confustion matrix of this fold
# [[ 91  52]
#  [ 35 108]]
#
#
# Accuracy of this fold: 0.713286713287
# AUC of this fold: 0.755587070272
# AUPR of this fold: 0.783800822503
# Confustion matrix of this fold
# [[105  38]
#  [ 44  99]]
#
#
# Accuracy avg : 0.699422105672
# AUC avg : 0.769457167823
# AUPR avg : 0.782185440781
# Confustion matrix
# [[ 975  459]
#  [ 403 1031]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.715277777778
# AUC of this fold: 0.78923128858
# AUPR of this fold: 0.813993843819
# Confustion matrix of this fold
# [[100  44]
#  [ 38 106]]
#
#
# Accuracy of this fold: 0.736111111111
# AUC of this fold: 0.809220679012
# AUPR of this fold: 0.836134112129
# Confustion matrix of this fold
# [[105  39]
#  [ 37 107]]
#
#
# Accuracy of this fold: 0.6875
# AUC of this fold: 0.757740162037
# AUPR of this fold: 0.780081718237
# Confustion matrix of this fold
# [[102  42]
#  [ 48  96]]
#
#
# Accuracy of this fold: 0.673611111111
# AUC of this fold: 0.766203703704
# AUPR of this fold: 0.786814552009
# Confustion matrix of this fold
# [[ 89  55]
#  [ 39 105]]
#
#
# Accuracy of this fold: 0.660839160839
# AUC of this fold: 0.728446378796
# AUPR of this fold: 0.75189777387
# Confustion matrix of this fold
# [[99 44]
#  [53 90]]
#
#
# Accuracy of this fold: 0.702797202797
# AUC of this fold: 0.768203824148
# AUPR of this fold: 0.771656330626
# Confustion matrix of this fold
# [[100  43]
#  [ 42 101]]
#
#
# Accuracy of this fold: 0.699300699301
# AUC of this fold: 0.780551616216
# AUPR of this fold: 0.770173474951
# Confustion matrix of this fold
# [[ 95  48]
#  [ 38 105]]
#
#
# Accuracy of this fold: 0.699300699301
# AUC of this fold: 0.765612010367
# AUPR of this fold: 0.778662984074
# Confustion matrix of this fold
# [[ 94  49]
#  [ 37 106]]
#
#
# Accuracy of this fold: 0.730769230769
# AUC of this fold: 0.819868942247
# AUPR of this fold: 0.84213172167
# Confustion matrix of this fold
# [[103  40]
#  [ 37 106]]
#
#
# Accuracy of this fold: 0.716783216783
# AUC of this fold: 0.779329062546
# AUPR of this fold: 0.785497129315
# Confustion matrix of this fold
# [[102  41]
#  [ 40 103]]
#
#
# Accuracy avg : 0.702229020979
# AUC avg : 0.776440766765
# AUPR avg : 0.79170436407
# Confustion matrix
# [[ 989  445]
#  [ 409 1025]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.631944444444
# AUC of this fold: 0.748963155864
# AUPR of this fold: 0.782173669965
# Confustion matrix of this fold
# [[ 78  66]
#  [ 40 104]]
#
#
# Accuracy of this fold: 0.71875
# AUC of this fold: 0.789351851852
# AUPR of this fold: 0.802905337857
# Confustion matrix of this fold
# [[ 95  49]
#  [ 32 112]]
#
#
# Accuracy of this fold: 0.729166666667
# AUC of this fold: 0.823230131173
# AUPR of this fold: 0.861903338048
# Confustion matrix of this fold
# [[100  44]
#  [ 34 110]]
#
#
# Accuracy of this fold: 0.6875
# AUC of this fold: 0.75764371142
# AUPR of this fold: 0.784267378599
# Confustion matrix of this fold
# [[99 45]
#  [45 99]]
#
#
# Accuracy of this fold: 0.748251748252
# AUC of this fold: 0.791236735293
# AUPR of this fold: 0.807607556657
# Confustion matrix of this fold
# [[111  32]
#  [ 40 103]]
#
#
# Accuracy of this fold: 0.70979020979
# AUC of this fold: 0.804758178884
# AUPR of this fold: 0.818550610222
# Confustion matrix of this fold
# [[ 99  44]
#  [ 39 104]]
#
#
# Accuracy of this fold: 0.727272727273
# AUC of this fold: 0.812386913786
# AUPR of this fold: 0.805254778274
# Confustion matrix of this fold
# [[104  39]
#  [ 39 104]]
#
#
# Accuracy of this fold: 0.688811188811
# AUC of this fold: 0.743875006113
# AUPR of this fold: 0.741467791839
# Confustion matrix of this fold
# [[ 95  48]
#  [ 41 102]]
#
#
# Accuracy of this fold: 0.688811188811
# AUC of this fold: 0.764487260991
# AUPR of this fold: 0.780995036031
# Confustion matrix of this fold
# [[99 44]
#  [45 98]]
#
#
# Accuracy of this fold: 0.72027972028
# AUC of this fold: 0.77475671182
# AUPR of this fold: 0.781693314677
# Confustion matrix of this fold
# [[100  43]
#  [ 37 106]]
#
#
# Accuracy avg : 0.705057789433
# AUC avg : 0.781068965719
# AUPR avg : 0.796681881217
# Confustion matrix
# [[ 980  454]
#  [ 392 1042]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.756944444444
# AUC of this fold: 0.823760609568
# AUPR of this fold: 0.837007777795
# Confustion matrix of this fold
# [[106  38]
#  [ 32 112]]
#
#
# Accuracy of this fold: 0.729166666667
# AUC of this fold: 0.808810763889
# AUPR of this fold: 0.820888885952
# Confustion matrix of this fold
# [[101  43]
#  [ 35 109]]
#
#
# Accuracy of this fold: 0.690972222222
# AUC of this fold: 0.788459683642
# AUPR of this fold: 0.798407040276
# Confustion matrix of this fold
# [[ 88  56]
#  [ 33 111]]
#
#
# Accuracy of this fold: 0.645833333333
# AUC of this fold: 0.737147955247
# AUPR of this fold: 0.768703476851
# Confustion matrix of this fold
# [[94 50]
#  [52 92]]
#
#
# Accuracy of this fold: 0.664335664336
# AUC of this fold: 0.730060149641
# AUPR of this fold: 0.744080920056
# Confustion matrix of this fold
# [[93 50]
#  [46 97]]
#
#
# Accuracy of this fold: 0.692307692308
# AUC of this fold: 0.75463347841
# AUPR of this fold: 0.75559988706
# Confustion matrix of this fold
# [[ 97  46]
#  [ 42 101]]
#
#
# Accuracy of this fold: 0.713286713287
# AUC of this fold: 0.801970756516
# AUPR of this fold: 0.814480847958
# Confustion matrix of this fold
# [[105  38]
#  [ 44  99]]
#
#
# Accuracy of this fold: 0.744755244755
# AUC of this fold: 0.798645410534
# AUPR of this fold: 0.82667554676
# Confustion matrix of this fold
# [[107  36]
#  [ 37 106]]
#
#
# Accuracy of this fold: 0.63986013986
# AUC of this fold: 0.727443884787
# AUPR of this fold: 0.746070370903
# Confustion matrix of this fold
# [[86 57]
#  [46 97]]
#
#
# Accuracy of this fold: 0.699300699301
# AUC of this fold: 0.788302606484
# AUPR of this fold: 0.809497809935
# Confustion matrix of this fold
# [[102  41]
#  [ 45  98]]
#
#
# Accuracy avg : 0.697676282051
# AUC avg : 0.775923529872
# AUPR avg : 0.792141256354
# Confustion matrix
# [[ 979  455]
#  [ 412 1022]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.6875
# AUC of this fold: 0.763720100309
# AUPR of this fold: 0.814154621964
# Confustion matrix of this fold
# [[101  43]
#  [ 47  97]]
#
#
# Accuracy of this fold: 0.767361111111
# AUC of this fold: 0.84213445216
# AUPR of this fold: 0.852880877797
# Confustion matrix of this fold
# [[109  35]
#  [ 32 112]]
#
#
# Accuracy of this fold: 0.690972222222
# AUC of this fold: 0.779706790123
# AUPR of this fold: 0.779741686814
# Confustion matrix of this fold
# [[ 93  51]
#  [ 38 106]]
#
#
# Accuracy of this fold: 0.704861111111
# AUC of this fold: 0.776379243827
# AUPR of this fold: 0.786515084001
# Confustion matrix of this fold
# [[101  43]
#  [ 42 102]]
#
#
# Accuracy of this fold: 0.685314685315
# AUC of this fold: 0.744608538315
# AUPR of this fold: 0.785498246672
# Confustion matrix of this fold
# [[99 44]
#  [46 97]]
#
#
# Accuracy of this fold: 0.744755244755
# AUC of this fold: 0.818352975696
# AUPR of this fold: 0.800389984456
# Confustion matrix of this fold
# [[100  43]
#  [ 30 113]]
#
#
# Accuracy of this fold: 0.678321678322
# AUC of this fold: 0.763289158394
# AUPR of this fold: 0.801095081864
# Confustion matrix of this fold
# [[ 90  53]
#  [ 39 104]]
#
#
# Accuracy of this fold: 0.674825174825
# AUC of this fold: 0.767176879065
# AUPR of this fold: 0.784708541355
# Confustion matrix of this fold
# [[ 91  52]
#  [ 41 102]]
#
#
# Accuracy of this fold: 0.706293706294
# AUC of this fold: 0.767421389799
# AUPR of this fold: 0.792161393628
# Confustion matrix of this fold
# [[100  43]
#  [ 41 102]]
#
#
# Accuracy of this fold: 0.72027972028
# AUC of this fold: 0.783412391804
# AUPR of this fold: 0.796651270257
# Confustion matrix of this fold
# [[108  35]
#  [ 45  98]]
#
#
# Accuracy avg : 0.706048465423
# AUC avg : 0.780620191949
# AUPR avg : 0.799379678881
# Confustion matrix
# [[ 992  442]
#  [ 401 1033]]

# %%
# random undersampling (기존 descriptor) independent test 2017.1.17. - 

indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
classifier = RandomForestClassifier(n_estimators=1200, n_jobs=-1, class_weight='balanced')
classifier.fit(x_resampled, y_resampled)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# Independent Accuracy : 0.716634050881
# Independent AUC : 0.811644523641
# Independent AUPR : 0.250116984496
# Independent Confustion matrix
# [[1760  702]
#  [  22   71]]

# %%
# imbalanced learn 사용(기존 descriptor) 2017.1.17. - onsidedselection

from sklearn.metrics import roc_curve, auc, average_precision_score
from collections import Counter
from imblearn.under_sampling import OneSidedSelection

print('Original dataset shape {}'.format(Counter(y_whole_data)))
oss = OneSidedSelection()
x_resampled, y_resampled = oss.fit_sample(x_whole_data, y_whole_data)
print('Resampled dataset shape {}'.format(Counter(y_resampled)))

results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_resampled, y_resampled, user_estimators))
# Out:
# Original dataset shape Counter({0: 109251, 1: 1434})
# Resampled dataset shape Counter({0: 109107, 1: 1434})
# 120----------------------------------------------------
# Accuracy of this fold: 0.990411578471
# AUC of this fold: 0.878392982617
# AUPR of this fold: 0.488511294447
# Confustion matrix of this fold
# [[10895    16]
#  [   90    54]]
#
#
# Accuracy of this fold: 0.991044776119
# AUC of this fold: 0.863685284473
# AUPR of this fold: 0.505906895089
# Confustion matrix of this fold
# [[10903     8]
#  [   91    53]]
#
#
# Accuracy of this fold: 0.988692899141
# AUC of this fold: 0.828177985519
# AUPR of this fold: 0.371111925927
# Confustion matrix of this fold
# [[10893    18]
#  [  107    37]]
#
#
# Accuracy of this fold: 0.989959294437
# AUC of this fold: 0.86181503885
# AUPR of this fold: 0.501718742975
# Confustion matrix of this fold
# [[10892    19]
#  [   92    52]]
#
#
# Accuracy of this fold: 0.990953500995
# AUC of this fold: 0.878129340186
# AUPR of this fold: 0.523941507934
# Confustion matrix of this fold
# [[10901    10]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.989686991134
# AUC of this fold: 0.903454715938
# AUPR of this fold: 0.470781604807
# Confustion matrix of this fold
# [[10891    20]
#  [   94    49]]
#
#
# Accuracy of this fold: 0.988782341234
# AUC of this fold: 0.849230230863
# AUPR of this fold: 0.373035365847
# Confustion matrix of this fold
# [[10892    19]
#  [  105    38]]
#
#
# Accuracy of this fold: 0.989957477608
# AUC of this fold: 0.869806041804
# AUPR of this fold: 0.4671268454
# Confustion matrix of this fold
# [[10899    11]
#  [  100    43]]
#
#
# Accuracy of this fold: 0.98941463856
# AUC of this fold: 0.830305487363
# AUPR of this fold: 0.415945729906
# Confustion matrix of this fold
# [[10893    17]
#  [  100    43]]
#
#
# Accuracy of this fold: 0.990047950783
# AUC of this fold: 0.848272900335
# AUPR of this fold: 0.459055983828
# Confustion matrix of this fold
# [[10897    13]
#  [   97    46]]
#
#
# Accuracy avg : 0.989895144848
# AUC avg : 0.861127000795
# AUPR avg : 0.457713589616
# Confustion matrix
# [[108956    151]
#  [   966    468]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.990411578471
# AUC of this fold: 0.859312149309
# AUPR of this fold: 0.464150054736
# Confustion matrix of this fold
# [[10896    15]
#  [   91    53]]
#
#
# Accuracy of this fold: 0.989507010403
# AUC of this fold: 0.875422292997
# AUPR of this fold: 0.452558919586
# Confustion matrix of this fold
# [[10898    13]
#  [  103    41]]
#
#
# Accuracy of this fold: 0.990230664858
# AUC of this fold: 0.857358845304
# AUPR of this fold: 0.505170808629
# Confustion matrix of this fold
# [[10895    16]
#  [   92    52]]
#
#
# Accuracy of this fold: 0.990682948892
# AUC of this fold: 0.875954057577
# AUPR of this fold: 0.508660717303
# Confustion matrix of this fold
# [[10900    11]
#  [   92    52]]
#
#
# Accuracy of this fold: 0.990048851095
# AUC of this fold: 0.86310120088
# AUPR of this fold: 0.471636429382
# Confustion matrix of this fold
# [[10897    14]
#  [   96    47]]
#
#
# Accuracy of this fold: 0.990048851095
# AUC of this fold: 0.886740333262
# AUPR of this fold: 0.487991139692
# Confustion matrix of this fold
# [[10893    18]
#  [   92    51]]
#
#
# Accuracy of this fold: 0.988782341234
# AUC of this fold: 0.860444294043
# AUPR of this fold: 0.416659102967
# Confustion matrix of this fold
# [[10891    20]
#  [  104    39]]
#
#
# Accuracy of this fold: 0.990047950783
# AUC of this fold: 0.878205662349
# AUPR of this fold: 0.477523654898
# Confustion matrix of this fold
# [[10889    21]
#  [   89    54]]
#
#
# Accuracy of this fold: 0.98941463856
# AUC of this fold: 0.887912866236
# AUPR of this fold: 0.41458457156
# Confustion matrix of this fold
# [[10892    18]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.989595584909
# AUC of this fold: 0.860221263613
# AUPR of this fold: 0.408083322182
# Confustion matrix of this fold
# [[10897    13]
#  [  102    41]]
#
#
# Accuracy avg : 0.98987704203
# AUC avg : 0.870467296557
# AUPR avg : 0.460701872093
# Confustion matrix
# [[108948    159]
#  [   960    474]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.990502035278
# AUC of this fold: 0.877313541889
# AUPR of this fold: 0.521364370704
# Confustion matrix of this fold
# [[10898    13]
#  [   92    52]]
#
#
# Accuracy of this fold: 0.990049751244
# AUC of this fold: 0.895797373191
# AUPR of this fold: 0.517046519177
# Confustion matrix of this fold
# [[10898    13]
#  [   97    47]]
#
#
# Accuracy of this fold: 0.989778380823
# AUC of this fold: 0.878353203699
# AUPR of this fold: 0.481053290309
# Confustion matrix of this fold
# [[10886    25]
#  [   88    56]]
#
#
# Accuracy of this fold: 0.991044776119
# AUC of this fold: 0.877281400523
# AUPR of this fold: 0.536651723816
# Confustion matrix of this fold
# [[10894    17]
#  [   82    62]]
#
#
# Accuracy of this fold: 0.990048851095
# AUC of this fold: 0.881176242875
# AUPR of this fold: 0.460967089747
# Confustion matrix of this fold
# [[10900    11]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.988963271214
# AUC of this fold: 0.846269531037
# AUPR of this fold: 0.40125459352
# Confustion matrix of this fold
# [[10894    17]
#  [  105    38]]
#
#
# Accuracy of this fold: 0.988872806224
# AUC of this fold: 0.879324323372
# AUPR of this fold: 0.418743649218
# Confustion matrix of this fold
# [[10892    19]
#  [  104    39]]
#
#
# Accuracy of this fold: 0.989052745861
# AUC of this fold: 0.84462288399
# AUPR of this fold: 0.390481268458
# Confustion matrix of this fold
# [[10897    13]
#  [  108    35]]
#
#
# Accuracy of this fold: 0.98941463856
# AUC of this fold: 0.870306000141
# AUPR of this fold: 0.459318874679
# Confustion matrix of this fold
# [[10891    19]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.990409843481
# AUC of this fold: 0.878003435611
# AUPR of this fold: 0.457875142058
# Confustion matrix of this fold
# [[10898    12]
#  [   94    49]]
#
#
# Accuracy avg : 0.98981370999
# AUC avg : 0.872844793633
# AUPR avg : 0.464475652168
# Confustion matrix
# [[108948    159]
#  [   967    467]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.989778380823
# AUC of this fold: 0.864310927301
# AUPR of this fold: 0.447770397803
# Confustion matrix of this fold
# [[10893    18]
#  [   95    49]]
#
#
# Accuracy of this fold: 0.989597467209
# AUC of this fold: 0.845332246255
# AUPR of this fold: 0.416505897199
# Confustion matrix of this fold
# [[10895    16]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.989959294437
# AUC of this fold: 0.863371190134
# AUPR of this fold: 0.441189365318
# Confustion matrix of this fold
# [[10900    11]
#  [  100    44]]
#
#
# Accuracy of this fold: 0.989235639982
# AUC of this fold: 0.89048195501
# AUPR of this fold: 0.460872938642
# Confustion matrix of this fold
# [[10894    17]
#  [  102    42]]
#
#
# Accuracy of this fold: 0.990410711055
# AUC of this fold: 0.893792945209
# AUPR of this fold: 0.493373506976
# Confustion matrix of this fold
# [[10898    13]
#  [   93    50]]
#
#
# Accuracy of this fold: 0.989506061154
# AUC of this fold: 0.871197860887
# AUPR of this fold: 0.456747388843
# Confustion matrix of this fold
# [[10889    22]
#  [   94    49]]
#
#
# Accuracy of this fold: 0.990320246065
# AUC of this fold: 0.891993260154
# AUPR of this fold: 0.483626687005
# Confustion matrix of this fold
# [[10901    10]
#  [   97    46]]
#
#
# Accuracy of this fold: 0.989867004433
# AUC of this fold: 0.843214668008
# AUPR of this fold: 0.465165967209
# Confustion matrix of this fold
# [[10900    10]
#  [  102    41]]
#
#
# Accuracy of this fold: 0.98941463856
# AUC of this fold: 0.876086608167
# AUPR of this fold: 0.444473746826
# Confustion matrix of this fold
# [[10890    20]
#  [   97    46]]
#
#
# Accuracy of this fold: 0.989505111734
# AUC of this fold: 0.904787421561
# AUPR of this fold: 0.429073968353
# Confustion matrix of this fold
# [[10892    18]
#  [   98    45]]
#
#
# Accuracy avg : 0.989759455545
# AUC avg : 0.874456908269
# AUPR avg : 0.453879986418
# Confustion matrix
# [[108952    155]
#  [   977    457]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.990230664858
# AUC of this fold: 0.889903410422
# AUPR of this fold: 0.475008403764
# Confustion matrix of this fold
# [[10902     9]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.989597467209
# AUC of this fold: 0.87839361908
# AUPR of this fold: 0.429965632429
# Confustion matrix of this fold
# [[10897    14]
#  [  101    43]]
#
#
# Accuracy of this fold: 0.989597467209
# AUC of this fold: 0.88338507775
# AUPR of this fold: 0.486142170176
# Confustion matrix of this fold
# [[10894    17]
#  [   98    46]]
#
#
# Accuracy of this fold: 0.990411578471
# AUC of this fold: 0.895682491675
# AUPR of this fold: 0.493517263676
# Confustion matrix of this fold
# [[10898    13]
#  [   93    51]]
#
#
# Accuracy of this fold: 0.989325131174
# AUC of this fold: 0.87417073807
# AUPR of this fold: 0.452020226218
# Confustion matrix of this fold
# [[10892    19]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.989325131174
# AUC of this fold: 0.88758505723
# AUPR of this fold: 0.450712456176
# Confustion matrix of this fold
# [[10889    22]
#  [   96    47]]
#
#
# Accuracy of this fold: 0.990320246065
# AUC of this fold: 0.853811800884
# AUPR of this fold: 0.459640571466
# Confustion matrix of this fold
# [[10900    11]
#  [   96    47]]
#
#
# Accuracy of this fold: 0.990047950783
# AUC of this fold: 0.852795600367
# AUPR of this fold: 0.444569881065
# Confustion matrix of this fold
# [[10894    16]
#  [   94    49]]
#
#
# Accuracy of this fold: 0.990228897132
# AUC of this fold: 0.883770262735
# AUPR of this fold: 0.504504212116
# Confustion matrix of this fold
# [[10893    17]
#  [   91    52]]
#
#
# Accuracy of this fold: 0.989505111734
# AUC of this fold: 0.888421798183
# AUPR of this fold: 0.471438932284
# Confustion matrix of this fold
# [[10895    15]
#  [  101    42]]
#
#
# Accuracy avg : 0.989858964581
# AUC avg : 0.878791985639
# AUPR avg : 0.466751974937
# Confustion matrix
# [[108954    153]
#  [   968    466]]

# %%
# onesided selection under sampling undersampling (기존 descriptor) independent test 2017.1.18. - 

indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
classifier = RandomForestClassifier(n_estimators=1200, n_jobs=-1, class_weight='balanced')
classifier.fit(x_resampled, y_resampled)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# Independent Accuracy : 0.979256360078
# Independent AUC : 0.896912642052
# Independent AUPR : 0.659183060549
# Independent Confustion matrix
# [[2438   24]
#  [  29   64]]

# %%
# imbalanced learn 사용(기존 descriptor) 2017.1.18. - nearmiss

from sklearn.metrics import roc_curve, auc, average_precision_score
from collections import Counter
from imblearn.under_sampling import NearMiss

print('Original dataset shape {}'.format(Counter(y_whole_data)))
nm = NearMiss()
x_resampled, y_resampled = nm.fit_sample(x_whole_data, y_whole_data)
print('Resampled dataset shape {}'.format(Counter(y_resampled)))

results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_resampled, y_resampled, user_estimators))
# Out:
# Original dataset shape Counter({0: 109251, 1: 1434})
# Resampled dataset shape Counter({0: 1434, 1: 1434})
# 120----------------------------------------------------
# Accuracy of this fold: 0.947916666667
# AUC of this fold: 0.979552469136
# AUPR of this fold: 0.985241027579
# Confustion matrix of this fold
# [[143   1]
#  [ 14 130]]
#
#
# Accuracy of this fold: 0.958333333333
# AUC of this fold: 0.988498263889
# AUPR of this fold: 0.991789296001
# Confustion matrix of this fold
# [[144   0]
#  [ 12 132]]
#
#
# Accuracy of this fold: 0.96875
# AUC of this fold: 0.988522376543
# AUPR of this fold: 0.992561907261
# Confustion matrix of this fold
# [[143   1]
#  [  8 136]]
#
#
# Accuracy of this fold: 0.965277777778
# AUC of this fold: 0.980107060185
# AUPR of this fold: 0.985754725342
# Confustion matrix of this fold
# [[142   2]
#  [  8 136]]
#
#
# Accuracy of this fold: 0.961538461538
# AUC of this fold: 0.981857303536
# AUPR of this fold: 0.98813419351
# Confustion matrix of this fold
# [[143   0]
#  [ 11 132]]
#
#
# Accuracy of this fold: 0.972027972028
# AUC of this fold: 0.993227052668
# AUPR of this fold: 0.994749412476
# Confustion matrix of this fold
# [[143   0]
#  [  8 135]]
#
#
# Accuracy of this fold: 0.958041958042
# AUC of this fold: 0.988263484767
# AUPR of this fold: 0.990775674426
# Confustion matrix of this fold
# [[141   2]
#  [ 10 133]]
#
#
# Accuracy of this fold: 0.958041958042
# AUC of this fold: 0.983593329747
# AUPR of this fold: 0.987553870514
# Confustion matrix of this fold
# [[142   1]
#  [ 11 132]]
#
#
# Accuracy of this fold: 0.968531468531
# AUC of this fold: 0.995647708934
# AUPR of this fold: 0.996895506064
# Confustion matrix of this fold
# [[143   0]
#  [  9 134]]
#
#
# Accuracy of this fold: 0.961538461538
# AUC of this fold: 0.982297422857
# AUPR of this fold: 0.988813956054
# Confustion matrix of this fold
# [[142   1]
#  [ 10 133]]
#
#
# Accuracy avg : 0.96199980575
# AUC avg : 0.986156647226
# AUPR avg : 0.990226956923
# Confustion matrix
# [[1426    8]
#  [ 101 1333]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.965277777778
# AUC of this fold: 0.989125192901
# AUPR of this fold: 0.993135988475
# Confustion matrix of this fold
# [[142   2]
#  [  8 136]]
#
#
# Accuracy of this fold: 0.954861111111
# AUC of this fold: 0.989318094136
# AUPR of this fold: 0.99270848666
# Confustion matrix of this fold
# [[144   0]
#  [ 13 131]]
#
#
# Accuracy of this fold: 0.961805555556
# AUC of this fold: 0.986207561728
# AUPR of this fold: 0.990775248702
# Confustion matrix of this fold
# [[144   0]
#  [ 11 133]]
#
#
# Accuracy of this fold: 0.9375
# AUC of this fold: 0.981047453704
# AUPR of this fold: 0.984842681159
# Confustion matrix of this fold
# [[143   1]
#  [ 17 127]]
#
#
# Accuracy of this fold: 0.951048951049
# AUC of this fold: 0.97765171891
# AUPR of this fold: 0.984786253787
# Confustion matrix of this fold
# [[143   0]
#  [ 14 129]]
#
#
# Accuracy of this fold: 0.979020979021
# AUC of this fold: 0.994914176732
# AUPR of this fold: 0.995928034729
# Confustion matrix of this fold
# [[142   1]
#  [  5 138]]
#
#
# Accuracy of this fold: 0.958041958042
# AUC of this fold: 0.983177661499
# AUPR of this fold: 0.988413435621
# Confustion matrix of this fold
# [[142   1]
#  [ 11 132]]
#
#
# Accuracy of this fold: 0.975524475524
# AUC of this fold: 0.990121766346
# AUPR of this fold: 0.992942716351
# Confustion matrix of this fold
# [[142   1]
#  [  6 137]]
#
#
# Accuracy of this fold: 0.965034965035
# AUC of this fold: 0.980781456306
# AUPR of this fold: 0.988030014463
# Confustion matrix of this fold
# [[143   0]
#  [ 10 133]]
#
#
# Accuracy of this fold: 0.965034965035
# AUC of this fold: 0.988556897648
# AUPR of this fold: 0.992157354773
# Confustion matrix of this fold
# [[143   0]
#  [ 10 133]]
#
#
# Accuracy avg : 0.961315073815
# AUC avg : 0.986090197991
# AUPR avg : 0.990372021472
# Confustion matrix
# [[1428    6]
#  [ 105 1329]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.947916666667
# AUC of this fold: 0.973283179012
# AUPR of this fold: 0.981856202802
# Confustion matrix of this fold
# [[144   0]
#  [ 15 129]]
#
#
# Accuracy of this fold: 0.954861111111
# AUC of this fold: 0.989655671296
# AUPR of this fold: 0.992445275336
# Confustion matrix of this fold
# [[142   2]
#  [ 11 133]]
#
#
# Accuracy of this fold: 0.972222222222
# AUC of this fold: 0.986038773148
# AUPR of this fold: 0.990043629751
# Confustion matrix of this fold
# [[144   0]
#  [  8 136]]
#
#
# Accuracy of this fold: 0.975694444444
# AUC of this fold: 0.987871334877
# AUPR of this fold: 0.992779606185
# Confustion matrix of this fold
# [[144   0]
#  [  7 137]]
#
#
# Accuracy of this fold: 0.961538461538
# AUC of this fold: 0.994376253118
# AUPR of this fold: 0.995357357592
# Confustion matrix of this fold
# [[143   0]
#  [ 11 132]]
#
#
# Accuracy of this fold: 0.961538461538
# AUC of this fold: 0.976624773828
# AUPR of this fold: 0.985178590238
# Confustion matrix of this fold
# [[143   0]
#  [ 11 132]]
#
#
# Accuracy of this fold: 0.940559440559
# AUC of this fold: 0.975548926598
# AUPR of this fold: 0.983176303511
# Confustion matrix of this fold
# [[141   2]
#  [ 15 128]]
#
#
# Accuracy of this fold: 0.972027972028
# AUC of this fold: 0.995060883173
# AUPR of this fold: 0.994764240433
# Confustion matrix of this fold
# [[142   1]
#  [  7 136]]
#
#
# Accuracy of this fold: 0.965034965035
# AUC of this fold: 0.991002004988
# AUPR of this fold: 0.993528854599
# Confustion matrix of this fold
# [[143   0]
#  [ 10 133]]
#
#
# Accuracy of this fold: 0.958041958042
# AUC of this fold: 0.992053401144
# AUPR of this fold: 0.994291101377
# Confustion matrix of this fold
# [[142   1]
#  [ 11 132]]
#
#
# Accuracy avg : 0.960943570319
# AUC avg : 0.986151520118
# AUPR avg : 0.990342116182
# Confustion matrix
# [[1428    6]
#  [ 106 1328]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.972222222222
# AUC of this fold: 0.992597415123
# AUPR of this fold: 0.994390392553
# Confustion matrix of this fold
# [[143   1]
#  [  7 137]]
#
#
# Accuracy of this fold: 0.947916666667
# AUC of this fold: 0.97957658179
# AUPR of this fold: 0.985283431364
# Confustion matrix of this fold
# [[142   2]
#  [ 13 131]]
#
#
# Accuracy of this fold: 0.986111111111
# AUC of this fold: 0.993851273148
# AUPR of this fold: 0.996075075166
# Confustion matrix of this fold
# [[144   0]
#  [  4 140]]
#
#
# Accuracy of this fold: 0.958333333333
# AUC of this fold: 0.987123842593
# AUPR of this fold: 0.990899288878
# Confustion matrix of this fold
# [[144   0]
#  [ 12 132]]
#
#
# Accuracy of this fold: 0.947552447552
# AUC of this fold: 0.979485549416
# AUPR of this fold: 0.986100892499
# Confustion matrix of this fold
# [[142   1]
#  [ 14 129]]
#
#
# Accuracy of this fold: 0.954545454545
# AUC of this fold: 0.981881754609
# AUPR of this fold: 0.987493879135
# Confustion matrix of this fold
# [[143   0]
#  [ 13 130]]
#
#
# Accuracy of this fold: 0.982517482517
# AUC of this fold: 0.990292923859
# AUPR of this fold: 0.99315791262
# Confustion matrix of this fold
# [[143   0]
#  [  5 138]]
#
#
# Accuracy of this fold: 0.954545454545
# AUC of this fold: 0.985476062399
# AUPR of this fold: 0.990794531122
# Confustion matrix of this fold
# [[143   0]
#  [ 13 130]]
#
#
# Accuracy of this fold: 0.958041958042
# AUC of this fold: 0.987823365446
# AUPR of this fold: 0.99059685314
# Confustion matrix of this fold
# [[141   2]
#  [ 10 133]]
#
#
# Accuracy of this fold: 0.965034965035
# AUC of this fold: 0.996136730402
# AUPR of this fold: 0.996465397119
# Confustion matrix of this fold
# [[143   0]
#  [ 10 133]]
#
#
# Accuracy avg : 0.962682109557
# AUC avg : 0.987424549879
# AUPR avg : 0.99112576536
# Confustion matrix
# [[1428    6]
#  [ 101 1333]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.961805555556
# AUC of this fold: 0.992332175926
# AUPR of this fold: 0.994530269503
# Confustion matrix of this fold
# [[143   1]
#  [ 10 134]]
#
#
# Accuracy of this fold: 0.961805555556
# AUC of this fold: 0.97745466821
# AUPR of this fold: 0.985384191663
# Confustion matrix of this fold
# [[142   2]
#  [  9 135]]
#
#
# Accuracy of this fold: 0.965277777778
# AUC of this fold: 0.989969135802
# AUPR of this fold: 0.992639030849
# Confustion matrix of this fold
# [[144   0]
#  [ 10 134]]
#
#
# Accuracy of this fold: 0.951388888889
# AUC of this fold: 0.977647569444
# AUPR of this fold: 0.985066987239
# Confustion matrix of this fold
# [[142   2]
#  [ 12 132]]
#
#
# Accuracy of this fold: 0.968531468531
# AUC of this fold: 0.976233556653
# AUPR of this fold: 0.984359958252
# Confustion matrix of this fold
# [[143   0]
#  [  9 134]]
#
#
# Accuracy of this fold: 0.965034965035
# AUC of this fold: 0.995134236393
# AUPR of this fold: 0.995923983747
# Confustion matrix of this fold
# [[142   1]
#  [  9 134]]
#
#
# Accuracy of this fold: 0.958041958042
# AUC of this fold: 0.983886742628
# AUPR of this fold: 0.989672097733
# Confustion matrix of this fold
# [[143   0]
#  [ 12 131]]
#
#
# Accuracy of this fold: 0.968531468531
# AUC of this fold: 0.997579343733
# AUPR of this fold: 0.998012454584
# Confustion matrix of this fold
# [[143   0]
#  [  9 134]]
#
#
# Accuracy of this fold: 0.954545454545
# AUC of this fold: 0.982541933591
# AUPR of this fold: 0.98910093369
# Confustion matrix of this fold
# [[143   0]
#  [ 13 130]]
#
#
# Accuracy of this fold: 0.968531468531
# AUC of this fold: 0.98699202895
# AUPR of this fold: 0.990766909465
# Confustion matrix of this fold
# [[142   1]
#  [  8 135]]
#
#
# Accuracy avg : 0.962349456099
# AUC avg : 0.985977139133
# AUPR avg : 0.990545681672
# Confustion matrix
# [[1427    7]
#  [ 101 1333]]

# %%
# nearmiss under sampling undersampling (기존 descriptor) independent test 2017.1.17. - 

indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

indep_x = indep[indep.columns.values[3:].tolist()].values
indep_y = indep["association"].values

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
classifier = RandomForestClassifier(n_estimators=300, n_jobs=-1, class_weight='balanced')
classifier.fit(x_resampled, y_resampled)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# Independent Accuracy : 0.06614481409
# Independent AUC : 0.702259287405
# Independent AUPR : 0.212383359166
# Independent Confustion matrix
# [[  79 2383]
#  [   3   90]]

# %%
# imbalanced learn 사용(기존 descriptor) 2017.1.18. - tomelinks

from sklearn.metrics import roc_curve, auc, average_precision_score
from collections import Counter
from imblearn.under_sampling import TomekLinks

print('Original dataset shape {}'.format(Counter(y_whole_data)))
tl = TomekLinks()
x_resampled, y_resampled = tl.fit_sample(x_whole_data, y_whole_data)
print('Resampled dataset shape {}'.format(Counter(y_resampled)))

results = list()
for user_estimators in [120,300,500,800,1200]:
    results.append(Random_Forest_10_fold(x_resampled, y_resampled, user_estimators))
# Out:
# Original dataset shape Counter({0: 109251, 1: 1434})
# Resampled dataset shape Counter({0: 109152, 1: 1434})
# 120----------------------------------------------------
# Accuracy of this fold: 0.989963833635
# AUC of this fold: 0.831143950267
# AUPR of this fold: 0.451402116108
# Confustion matrix of this fold
# [[10898    18]
#  [   93    51]]
#
#
# Accuracy of this fold: 0.989059674503
# AUC of this fold: 0.856215455906
# AUPR of this fold: 0.456391545023
# Confustion matrix of this fold
# [[10899    17]
#  [  104    40]]
#
#
# Accuracy of this fold: 0.990505470657
# AUC of this fold: 0.877790820481
# AUPR of this fold: 0.48879491156
# Confustion matrix of this fold
# [[10905    10]
#  [   95    49]]
#
#
# Accuracy of this fold: 0.988787412967
# AUC of this fold: 0.874766503792
# AUPR of this fold: 0.371034868318
# Confustion matrix of this fold
# [[10900    15]
#  [  109    35]]
#
#
# Accuracy of this fold: 0.990775908844
# AUC of this fold: 0.893746976798
# AUPR of this fold: 0.500509836427
# Confustion matrix of this fold
# [[10902    13]
#  [   89    54]]
#
#
# Accuracy of this fold: 0.990052450714
# AUC of this fold: 0.821901918512
# AUPR of this fold: 0.436753526138
# Confustion matrix of this fold
# [[10899    16]
#  [   94    49]]
#
#
# Accuracy of this fold: 0.990685476578
# AUC of this fold: 0.868610592339
# AUPR of this fold: 0.490771562286
# Confustion matrix of this fold
# [[10901    14]
#  [   89    54]]
#
#
# Accuracy of this fold: 0.989600289383
# AUC of this fold: 0.832584273262
# AUPR of this fold: 0.417460290168
# Confustion matrix of this fold
# [[10903    12]
#  [  103    40]]
#
#
# Accuracy of this fold: 0.988515102188
# AUC of this fold: 0.862688479638
# AUPR of this fold: 0.385431987912
# Confustion matrix of this fold
# [[10897    18]
#  [  109    34]]
#
#
# Accuracy of this fold: 0.990414179779
# AUC of this fold: 0.868234834337
# AUPR of this fold: 0.520404359159
# Confustion matrix of this fold
# [[10900    15]
#  [   91    52]]
#
#
# Accuracy avg : 0.989835979925
# AUC avg : 0.858768380533
# AUPR avg : 0.45189550031
# Confustion matrix
# [[109004    148]
#  [   976    458]]
# 300----------------------------------------------------
# Accuracy of this fold: 0.989511754069
# AUC of this fold: 0.885332055902
# AUPR of this fold: 0.445413205687
# Confustion matrix of this fold
# [[10898    18]
#  [   98    46]]
#
#
# Accuracy of this fold: 0.989873417722
# AUC of this fold: 0.84921566457
# AUPR of this fold: 0.452460345679
# Confustion matrix of this fold
# [[10903    13]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.98942038159
# AUC of this fold: 0.872411818598
# AUPR of this fold: 0.414989999563
# Confustion matrix of this fold
# [[10901    14]
#  [  103    41]]
#
#
# Accuracy of this fold: 0.990415046568
# AUC of this fold: 0.880395861964
# AUPR of this fold: 0.498523647905
# Confustion matrix of this fold
# [[10902    13]
#  [   93    51]]
#
#
# Accuracy of this fold: 0.989328992585
# AUC of this fold: 0.864950715798
# AUPR of this fold: 0.418613648451
# Confustion matrix of this fold
# [[10896    19]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.990233315247
# AUC of this fold: 0.87583904872
# AUPR of this fold: 0.47575337143
# Confustion matrix of this fold
# [[10905    10]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.990052450714
# AUC of this fold: 0.860329821347
# AUPR of this fold: 0.422282667084
# Confustion matrix of this fold
# [[10901    14]
#  [   96    47]]
#
#
# Accuracy of this fold: 0.989600289383
# AUC of this fold: 0.868548126175
# AUPR of this fold: 0.438525162896
# Confustion matrix of this fold
# [[10904    11]
#  [  104    39]]
#
#
# Accuracy of this fold: 0.990233315247
# AUC of this fold: 0.883573641201
# AUPR of this fold: 0.484538994025
# Confustion matrix of this fold
# [[10895    20]
#  [   88    55]]
#
#
# Accuracy of this fold: 0.989781153916
# AUC of this fold: 0.884423501373
# AUPR of this fold: 0.454009232607
# Confustion matrix of this fold
# [[10904    11]
#  [  102    41]]
#
#
# Accuracy avg : 0.989845011704
# AUC avg : 0.872502025565
# AUPR avg : 0.450511027533
# Confustion matrix
# [[109009    143]
#  [   980    454]]
# 500----------------------------------------------------
# Accuracy of this fold: 0.990144665461
# AUC of this fold: 0.868196785554
# AUPR of this fold: 0.462880645965
# Confustion matrix of this fold
# [[10904    12]
#  [   97    47]]
#
#
# Accuracy of this fold: 0.989421338156
# AUC of this fold: 0.870749104271
# AUPR of this fold: 0.431357371276
# Confustion matrix of this fold
# [[10898    18]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.989510805679
# AUC of this fold: 0.889597648496
# AUPR of this fold: 0.515400748935
# Confustion matrix of this fold
# [[10896    19]
#  [   97    47]]
#
#
# Accuracy of this fold: 0.989691653857
# AUC of this fold: 0.858134193516
# AUPR of this fold: 0.435328432729
# Confustion matrix of this fold
# [[10899    16]
#  [   98    46]]
#
#
# Accuracy of this fold: 0.989057695786
# AUC of this fold: 0.893869026072
# AUPR of this fold: 0.42634144243
# Confustion matrix of this fold
# [[10896    19]
#  [  102    41]]
#
#
# Accuracy of this fold: 0.990052450714
# AUC of this fold: 0.840482879466
# AUPR of this fold: 0.417672533347
# Confustion matrix of this fold
# [[10909     6]
#  [  104    39]]
#
#
# Accuracy of this fold: 0.990866341111
# AUC of this fold: 0.893722631011
# AUPR of this fold: 0.510599229835
# Confustion matrix of this fold
# [[10904    11]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.989871586182
# AUC of this fold: 0.884074011193
# AUPR of this fold: 0.469193221439
# Confustion matrix of this fold
# [[10897    18]
#  [   94    49]]
#
#
# Accuracy of this fold: 0.989238560318
# AUC of this fold: 0.877048970269
# AUPR of this fold: 0.426857592671
# Confustion matrix of this fold
# [[10895    20]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.989419424851
# AUC of this fold: 0.843576396119
# AUPR of this fold: 0.431686976963
# Confustion matrix of this fold
# [[10898    17]
#  [  100    43]]
#
#
# Accuracy avg : 0.989727452211
# AUC avg : 0.871945164597
# AUPR avg : 0.452731819559
# Confustion matrix
# [[108996    156]
#  [   980    454]]
# 800----------------------------------------------------
# Accuracy of this fold: 0.989059674503
# AUC of this fold: 0.879810408269
# AUPR of this fold: 0.417956300944
# Confustion matrix of this fold
# [[10902    14]
#  [  107    37]]
#
#
# Accuracy of this fold: 0.989602169982
# AUC of this fold: 0.890919229164
# AUPR of this fold: 0.481570302199
# Confustion matrix of this fold
# [[10904    12]
#  [  103    41]]
#
#
# Accuracy of this fold: 0.99113843928
# AUC of this fold: 0.868378442001
# AUPR of this fold: 0.506517498395
# Confustion matrix of this fold
# [[10904    11]
#  [   87    57]]
#
#
# Accuracy of this fold: 0.990143774301
# AUC of this fold: 0.876675192141
# AUPR of this fold: 0.446960783337
# Confustion matrix of this fold
# [[10903    12]
#  [   97    47]]
#
#
# Accuracy of this fold: 0.989781153916
# AUC of this fold: 0.87830886475
# AUPR of this fold: 0.441732965909
# Confustion matrix of this fold
# [[10900    15]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.989419424851
# AUC of this fold: 0.880706604435
# AUPR of this fold: 0.452354796925
# Confustion matrix of this fold
# [[10899    16]
#  [  101    42]]
#
#
# Accuracy of this fold: 0.989600289383
# AUC of this fold: 0.831965377728
# AUPR of this fold: 0.422023715358
# Confustion matrix of this fold
# [[10902    13]
#  [  102    41]]
#
#
# Accuracy of this fold: 0.989328992585
# AUC of this fold: 0.88285223709
# AUPR of this fold: 0.454476231869
# Confustion matrix of this fold
# [[10897    18]
#  [  100    43]]
#
#
# Accuracy of this fold: 0.989419424851
# AUC of this fold: 0.885214419113
# AUPR of this fold: 0.450025131154
# Confustion matrix of this fold
# [[10899    16]
#  [  101    42]]
#
#
# Accuracy of this fold: 0.989419424851
# AUC of this fold: 0.895842636521
# AUPR of this fold: 0.47540864095
# Confustion matrix of this fold
# [[10888    27]
#  [   90    53]]
#
#
# Accuracy avg : 0.98969127685
# AUC avg : 0.877067341121
# AUPR avg : 0.454902636704
# Confustion matrix
# [[108998    154]
#  [   986    448]]
# 1200----------------------------------------------------
# Accuracy of this fold: 0.990415913201
# AUC of this fold: 0.898154721917
# AUPR of this fold: 0.505209997374
# Confustion matrix of this fold
# [[10901    15]
#  [   91    53]]
#
#
# Accuracy of this fold: 0.990415913201
# AUC of this fold: 0.869651072839
# AUPR of this fold: 0.488716219904
# Confustion matrix of this fold
# [[10907     9]
#  [   97    47]]
#
#
# Accuracy of this fold: 0.990324622479
# AUC of this fold: 0.85321486741
# AUPR of this fold: 0.458901544124
# Confustion matrix of this fold
# [[10902    13]
#  [   94    50]]
#
#
# Accuracy of this fold: 0.990053350212
# AUC of this fold: 0.891041571232
# AUPR of this fold: 0.481926693873
# Confustion matrix of this fold
# [[10897    18]
#  [   92    52]]
#
#
# Accuracy of this fold: 0.989509857117
# AUC of this fold: 0.857629361019
# AUPR of this fold: 0.389959896546
# Confustion matrix of this fold
# [[10900    15]
#  [  101    42]]
#
#
# Accuracy of this fold: 0.990685476578
# AUC of this fold: 0.870211327838
# AUPR of this fold: 0.487109935034
# Confustion matrix of this fold
# [[10898    17]
#  [   86    57]]
#
#
# Accuracy of this fold: 0.989871586182
# AUC of this fold: 0.87351690911
# AUPR of this fold: 0.470269481989
# Confustion matrix of this fold
# [[10901    14]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.989057695786
# AUC of this fold: 0.876675774981
# AUPR of this fold: 0.436215692919
# Confustion matrix of this fold
# [[10898    17]
#  [  104    39]]
#
#
# Accuracy of this fold: 0.990142882981
# AUC of this fold: 0.857953544394
# AUPR of this fold: 0.488328835398
# Confustion matrix of this fold
# [[10905    10]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.988515102188
# AUC of this fold: 0.907542388898
# AUPR of this fold: 0.399543918726
# Confustion matrix of this fold
# [[10893    22]
#  [  105    38]]
#
#
# Accuracy avg : 0.989899239993
# AUC avg : 0.875559153964
# AUPR avg : 0.460618221589
# Confustion matrix
# [[109002    150]
#  [   967    467]]

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

skf = StratifiedKFold(n_splits=10, shuffle=True) # n_splits = 10 (10 fold라서.) data가 nega : pos = 76 : 1이기 때문에 validation 뽑을때 그 비율 지켜서 stratified로 한다.
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for training_index, validation_index in skf.split(x_whole_data, y_whole_data):
    x_training_set = x_whole_data[training_index] # 0.9에 해당하는 부분
    y_training_set = y_whole_data[training_index]
    x_validation_set = x_whole_data[validation_index] # 0.1에 해당하는 부분
    y_validation_set = y_whole_data[validation_index]

    #classifier = LogisticRegression(penalty='l1', C=0.0001, n_jobs=-1) #n_jobs = -1이면 모든 node 쓰는것. 신경쓰이면 30개 정도.
    classifier = RandomForestClassifier(n_estimators=120, n_jobs=-1, class_weight='balanced')
    classifier.fit(x_training_set, y_training_set)
    y_predicted_proba = classifier.predict_proba(x_validation_set) # return값이 probability 각각에 대한 확률 결과값 [[0.8(0에대한 확률),0.2(1에대한 확률)],[0.7,0.3],... ]
    y_predicted_label = classifier.predict(x_validation_set) # return이 label임. 위 확률 결과에서 확률이 높은거에 대한 label을 보여줌.

    current_accuracy = classifier.score(x_validation_set, y_validation_set) # accuracy score를 보여줌.
    fpr, tpr, thresholds = roc_curve(y_validation_set, y_predicted_proba[:, 1], pos_label=1) # powitive label만 본것.
    current_auc = auc(fpr, tpr)
    current_confusion_matrix = confusion_matrix(y_validation_set,
                                                y_predicted_label)
    current_aupr = average_precision_score(y_validation_set, y_predicted_proba[:, 1])
    
    whole_accuracy.append(current_accuracy)
    whole_auc.append(current_auc)
    whole_aupr.append(current_aupr)
    whole_confusion_mat.append((current_confusion_matrix))
    print("Accuracy of this fold: {}".format(current_accuracy))
    print("AUC of this fold: {}".format(current_auc))
    print("AUPR of this fold: {}".format(current_aupr))
    print("Confustion matrix of this fold")
    print(current_confusion_matrix)
    print("\n")
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

skf = StratifiedKFold(n_splits=10, shuffle=True) # n_splits = 10 (10 fold라서.) data가 nega : pos = 76 : 1이기 때문에 validation 뽑을때 그 비율 지켜서 stratified로 한다.
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for training_index, validation_index in skf.split(x_whole_data, y_whole_data):
    x_training_set = x_whole_data[training_index] # 0.9에 해당하는 부분
    y_training_set = y_whole_data[training_index]
    x_validation_set = x_whole_data[validation_index] # 0.1에 해당하는 부분
    y_validation_set = y_whole_data[validation_index]

    #classifier = LogisticRegression(penalty='l1', C=0.001, n_jobs=-1) #n_jobs = -1이면 모든 node 쓰는것. 신경쓰이면 30개 정도.
    classifier = RandomForestClassifier(n_estimators=300, n_jobs=-1, class_weight='balanced')
    classifier.fit(x_training_set, y_training_set)
    y_predicted_proba = classifier.predict_proba(x_validation_set) # return값이 probability 각각에 대한 확률 결과값 [[0.8(0에대한 확률),0.2(1에대한 확률)],[0.7,0.3],... ]
    y_predicted_label = classifier.predict(x_validation_set) # return이 label임. 위 확률 결과에서 확률이 높은거에 대한 label을 보여줌.

    current_accuracy = classifier.score(x_validation_set, y_validation_set) # accuracy score를 보여줌.
    fpr, tpr, thresholds = roc_curve(y_validation_set, y_predicted_proba[:, 1], pos_label=1) # powitive label만 본것.
    current_auc = auc(fpr, tpr)
    current_confusion_matrix = confusion_matrix(y_validation_set,
                                                y_predicted_label)
    current_aupr = average_precision_score(y_validation_set, y_predicted_proba[:, 1])
    
    whole_accuracy.append(current_accuracy)
    whole_auc.append(current_auc)
    whole_aupr.append(current_aupr)
    whole_confusion_mat.append((current_confusion_matrix))
    print("Accuracy of this fold: {}".format(current_accuracy))
    print("AUC of this fold: {}".format(current_auc))
    print("AUPR of this fold: {}".format(current_aupr))
    print("Confustion matrix of this fold")
    print(current_confusion_matrix)
    print("\n")
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# Accuracy of this fold: 0.989882565492
# AUC of this fold: 0.876410689589
# AUPR of this fold: 0.472315142024
# Confustion matrix of this fold
# [[10907    19]
#  [   93    51]]
#
#
# Accuracy of this fold: 0.989520281868
# AUC of this fold: 0.839363081617
# AUPR of this fold: 0.414750941914
# Confustion matrix of this fold
# [[10904    21]
#  [   95    49]]
#
#
# Accuracy of this fold: 0.988797542687
# AUC of this fold: 0.851094584287
# AUPR of this fold: 0.395496562733
# Confustion matrix of this fold
# [[10910    15]
#  [  109    35]]
#
#
# Accuracy of this fold: 0.988616857891
# AUC of this fold: 0.882013729977
# AUPR of this fold: 0.433313248148
# Confustion matrix of this fold
# [[10898    27]
#  [   99    45]]
#
#
# Accuracy of this fold: 0.989971087821
# AUC of this fold: 0.874251652238
# AUPR of this fold: 0.451735127441
# Confustion matrix of this fold
# [[10907    18]
#  [   93    50]]
#
#
# Accuracy of this fold: 0.98942898446
# AUC of this fold: 0.881530460386
# AUPR of this fold: 0.414880862552
# Confustion matrix of this fold
# [[10907    18]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.990151788941
# AUC of this fold: 0.860353650926
# AUPR of this fold: 0.458165812502
# Confustion matrix of this fold
# [[10911    14]
#  [   95    48]]
#
#
# Accuracy of this fold: 0.988525478858
# AUC of this fold: 0.878904802292
# AUPR of this fold: 0.379831779962
# Confustion matrix of this fold
# [[10901    24]
#  [  103    40]]
#
#
# Accuracy of this fold: 0.988977231659
# AUC of this fold: 0.858915043766
# AUPR of this fold: 0.416715564707
# Confustion matrix of this fold
# [[10908    17]
#  [  105    38]]
#
#
# Accuracy of this fold: 0.98970003614
# AUC of this fold: 0.849355267158
# AUPR of this fold: 0.433775725946
# Confustion matrix of this fold
# [[10907    18]
#  [   96    47]]
#
#
# Accuracy avg : 0.989357185582
# AUC avg : 0.865219296224
# AUPR avg : 0.427098076793
# Confustion matrix
# [[109060    191]
#  [   987    447]]

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

skf = StratifiedKFold(n_splits=10, shuffle=True) # n_splits = 10 (10 fold라서.) data가 nega : pos = 76 : 1이기 때문에 validation 뽑을때 그 비율 지켜서 stratified로 한다.
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for training_index, validation_index in skf.split(x_whole_data, y_whole_data):
    x_training_set = x_whole_data[training_index] # 0.9에 해당하는 부분
    y_training_set = y_whole_data[training_index]
    x_validation_set = x_whole_data[validation_index] # 0.1에 해당하는 부분
    y_validation_set = y_whole_data[validation_index]

    #classifier = LogisticRegression(penalty='l1', C=0.01, n_jobs=-1) #n_jobs = -1이면 모든 node 쓰는것. 신경쓰이면 30개 정도.
    classifier = RandomForestClassifier(n_estimators=500, n_jobs=-1, class_weight='balanced')
    classifier.fit(x_training_set, y_training_set)
    y_predicted_proba = classifier.predict_proba(x_validation_set) # return값이 probability 각각에 대한 확률 결과값 [[0.8(0에대한 확률),0.2(1에대한 확률)],[0.7,0.3],... ]
    y_predicted_label = classifier.predict(x_validation_set) # return이 label임. 위 확률 결과에서 확률이 높은거에 대한 label을 보여줌.

    current_accuracy = classifier.score(x_validation_set, y_validation_set) # accuracy score를 보여줌.
    fpr, tpr, thresholds = roc_curve(y_validation_set, y_predicted_proba[:, 1], pos_label=1) # powitive label만 본것.
    current_auc = auc(fpr, tpr)
    current_confusion_matrix = confusion_matrix(y_validation_set,
                                                y_predicted_label)
    current_aupr = average_precision_score(y_validation_set, y_predicted_proba[:, 1])
    
    whole_accuracy.append(current_accuracy)
    whole_auc.append(current_auc)
    whole_aupr.append(current_aupr)
    whole_confusion_mat.append((current_confusion_matrix))
    print("Accuracy of this fold: {}".format(current_accuracy))
    print("AUC of this fold: {}".format(current_auc))
    print("AUPR of this fold: {}".format(current_aupr))
    print("Confustion matrix of this fold")
    print(current_confusion_matrix)
    print("\n")
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# Accuracy of this fold: 0.989430894309
# AUC of this fold: 0.868545276812
# AUPR of this fold: 0.435892977198
# Confustion matrix of this fold
# [[10903    23]
#  [   94    50]]
#
#
# Accuracy of this fold: 0.989429939471
# AUC of this fold: 0.856746122553
# AUPR of this fold: 0.426079076119
# Confustion matrix of this fold
# [[10910    15]
#  [  102    42]]
#
#
# Accuracy of this fold: 0.988887885084
# AUC of this fold: 0.874398677854
# AUPR of this fold: 0.407779820746
# Confustion matrix of this fold
# [[10902    23]
#  [  100    44]]
#
#
# Accuracy of this fold: 0.989791309061
# AUC of this fold: 0.878923531655
# AUPR of this fold: 0.433465872316
# Confustion matrix of this fold
# [[10912    13]
#  [  100    44]]
#
#
# Accuracy of this fold: 0.988796530538
# AUC of this fold: 0.859357667504
# AUPR of this fold: 0.37558570886
# Confustion matrix of this fold
# [[10906    19]
#  [  105    38]]
#
#
# Accuracy of this fold: 0.990513191182
# AUC of this fold: 0.894507369061
# AUPR of this fold: 0.507700094844
# Confustion matrix of this fold
# [[10910    15]
#  [   90    53]]
#
#
# Accuracy of this fold: 0.988525478858
# AUC of this fold: 0.874499367909
# AUPR of this fold: 0.388464091234
# Confustion matrix of this fold
# [[10902    23]
#  [  104    39]]
#
#
# Accuracy of this fold: 0.989248283339
# AUC of this fold: 0.864974796371
# AUPR of this fold: 0.429095304243
# Confustion matrix of this fold
# [[10906    19]
#  [  100    43]]
#
#
# Accuracy of this fold: 0.988706179978
# AUC of this fold: 0.858971691924
# AUPR of this fold: 0.433777008384
# Confustion matrix of this fold
# [[10900    25]
#  [  100    43]]
#
#
# Accuracy of this fold: 0.989067582219
# AUC of this fold: 0.867180233954
# AUPR of this fold: 0.432173646712
# Confustion matrix of this fold
# [[10904    21]
#  [  100    43]]
#
#
# Accuracy avg : 0.989239727404
# AUC avg : 0.86981047356
# AUPR avg : 0.427001360066
# Confustion matrix
# [[109055    196]
#  [   995    439]]

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

skf = StratifiedKFold(n_splits=10, shuffle=True) # n_splits = 10 (10 fold라서.) data가 nega : pos = 76 : 1이기 때문에 validation 뽑을때 그 비율 지켜서 stratified로 한다.
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for training_index, validation_index in skf.split(x_whole_data, y_whole_data):
    x_training_set = x_whole_data[training_index] # 0.9에 해당하는 부분
    y_training_set = y_whole_data[training_index]
    x_validation_set = x_whole_data[validation_index] # 0.1에 해당하는 부분
    y_validation_set = y_whole_data[validation_index]

    #classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs=-1) #n_jobs = -1이면 모든 node 쓰는것. 신경쓰이면 30개 정도.
    classifier = RandomForestClassifier(n_estimators=800, n_jobs=-1, class_weight='balanced')
    classifier.fit(x_training_set, y_training_set)
    y_predicted_proba = classifier.predict_proba(x_validation_set) # return값이 probability 각각에 대한 확률 결과값 [[0.8(0에대한 확률),0.2(1에대한 확률)],[0.7,0.3],... ]
    y_predicted_label = classifier.predict(x_validation_set) # return이 label임. 위 확률 결과에서 확률이 높은거에 대한 label을 보여줌.

    current_accuracy = classifier.score(x_validation_set, y_validation_set) # accuracy score를 보여줌.
    fpr, tpr, thresholds = roc_curve(y_validation_set, y_predicted_proba[:, 1], pos_label=1) # powitive label만 본것.
    current_auc = auc(fpr, tpr)
    current_confusion_matrix = confusion_matrix(y_validation_set,
                                                y_predicted_label)
    current_aupr = average_precision_score(y_validation_set, y_predicted_proba[:, 1])
    
    whole_accuracy.append(current_accuracy)
    whole_auc.append(current_auc)
    whole_aupr.append(current_aupr)
    whole_confusion_mat.append((current_confusion_matrix))
    print("Accuracy of this fold: {}".format(current_accuracy))
    print("AUC of this fold: {}".format(current_auc))
    print("AUPR of this fold: {}".format(current_aupr))
    print("Confustion matrix of this fold")
    print(current_confusion_matrix)
    print("\n")
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# Accuracy of this fold: 0.987895212285
# AUC of this fold: 0.84438908465
# AUPR of this fold: 0.326368214106
# Confustion matrix of this fold
# [[10904    22]
#  [  112    32]]
#
#
# Accuracy of this fold: 0.989971993857
# AUC of this fold: 0.864346872616
# AUPR of this fold: 0.469312991303
# Confustion matrix of this fold
# [[10910    15]
#  [   96    48]]
#
#
# Accuracy of this fold: 0.99024302105
# AUC of this fold: 0.903686753115
# AUPR of this fold: 0.504502370249
# Confustion matrix of this fold
# [[10908    17]
#  [   91    53]]
#
#
# Accuracy of this fold: 0.989158912278
# AUC of this fold: 0.893111174676
# AUPR of this fold: 0.453194611269
# Confustion matrix of this fold
# [[10905    20]
#  [  100    44]]
#
#
# Accuracy of this fold: 0.990332490061
# AUC of this fold: 0.890560240675
# AUPR of this fold: 0.493945091931
# Confustion matrix of this fold
# [[10905    20]
#  [   87    56]]
#
#
# Accuracy of this fold: 0.98960968558
# AUC of this fold: 0.853993375046
# AUPR of this fold: 0.415113333015
# Confustion matrix of this fold
# [[10908    17]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.989248283339
# AUC of this fold: 0.894854619065
# AUPR of this fold: 0.434455097791
# Confustion matrix of this fold
# [[10907    18]
#  [  101    42]]
#
#
# Accuracy of this fold: 0.988886881099
# AUC of this fold: 0.861486934119
# AUPR of this fold: 0.397415687179
# Confustion matrix of this fold
# [[10901    24]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.98970003614
# AUC of this fold: 0.820721063833
# AUPR of this fold: 0.414485060729
# Confustion matrix of this fold
# [[10908    17]
#  [   97    46]]
#
#
# Accuracy of this fold: 0.98942898446
# AUC of this fold: 0.892286889312
# AUPR of this fold: 0.436537690361
# Confustion matrix of this fold
# [[10906    19]
#  [   98    45]]
#
#
# Accuracy avg : 0.989447550015
# AUC avg : 0.871943700711
# AUPR avg : 0.434533014793
# Confustion matrix
# [[109062    189]
#  [   979    455]]

# %%
from sklearn.metrics import roc_curve, auc, average_precision_score

skf = StratifiedKFold(n_splits=10, shuffle=True) # n_splits = 10 (10 fold라서.) data가 nega : pos = 76 : 1이기 때문에 validation 뽑을때 그 비율 지켜서 stratified로 한다.
whole_accuracy = list()
whole_auc = list()
whole_aupr = list()
whole_confusion_mat = list()
for training_index, validation_index in skf.split(x_whole_data, y_whole_data):
    x_training_set = x_whole_data[training_index] # 0.9에 해당하는 부분
    y_training_set = y_whole_data[training_index]
    x_validation_set = x_whole_data[validation_index] # 0.1에 해당하는 부분
    y_validation_set = y_whole_data[validation_index]

    #classifier = LogisticRegression(penalty='l1', C=1, n_jobs=-1) #n_jobs = -1이면 모든 node 쓰는것. 신경쓰이면 30개 정도.
    classifier = RandomForestClassifier(n_estimators=1200, n_jobs=-1, class_weight='balanced')
    classifier.fit(x_training_set, y_training_set)
    y_predicted_proba = classifier.predict_proba(x_validation_set) # return값이 probability 각각에 대한 확률 결과값 [[0.8(0에대한 확률),0.2(1에대한 확률)],[0.7,0.3],... ]
    y_predicted_label = classifier.predict(x_validation_set) # return이 label임. 위 확률 결과에서 확률이 높은거에 대한 label을 보여줌.

    current_accuracy = classifier.score(x_validation_set, y_validation_set) # accuracy score를 보여줌.
    fpr, tpr, thresholds = roc_curve(y_validation_set, y_predicted_proba[:, 1], pos_label=1) # powitive label만 본것.
    current_auc = auc(fpr, tpr)
    current_confusion_matrix = confusion_matrix(y_validation_set,
                                                y_predicted_label)
    current_aupr = average_precision_score(y_validation_set, y_predicted_proba[:, 1])
    
    whole_accuracy.append(current_accuracy)
    whole_auc.append(current_auc)
    whole_aupr.append(current_aupr)
    whole_confusion_mat.append((current_confusion_matrix))
    print("Accuracy of this fold: {}".format(current_accuracy))
    print("AUC of this fold: {}".format(current_auc))
    print("AUPR of this fold: {}".format(current_aupr))
    print("Confustion matrix of this fold")
    print(current_confusion_matrix)
    print("\n")
print("Accuracy avg : {}").format(sum(whole_accuracy)/len(whole_accuracy))
print("AUC avg : {}").format(sum(whole_auc)/len(whole_auc))
print("AUPR avg : {}").format(sum(whole_aupr)/len(whole_aupr))
print("Confustion matrix")
print(sum(whole_confusion_mat))
# Out:
# Accuracy of this fold: 0.989972899729
# AUC of this fold: 0.891333681636
# AUPR of this fold: 0.499149559686
# Confustion matrix of this fold
# [[10901    25]
#  [   86    58]]
#
#
# Accuracy of this fold: 0.988165145903
# AUC of this fold: 0.854820429697
# AUPR of this fold: 0.378107366953
# Confustion matrix of this fold
# [[10897    28]
#  [  103    41]]
#
#
# Accuracy of this fold: 0.989429939471
# AUC of this fold: 0.8595032418
# AUPR of this fold: 0.415617917788
# Confustion matrix of this fold
# [[10904    21]
#  [   96    48]]
#
#
# Accuracy of this fold: 0.989971993857
# AUC of this fold: 0.871734998729
# AUPR of this fold: 0.436236638907
# Confustion matrix of this fold
# [[10907    18]
#  [   93    51]]
#
#
# Accuracy of this fold: 0.990061438381
# AUC of this fold: 0.848808948489
# AUPR of this fold: 0.429378993302
# Confustion matrix of this fold
# [[10913    12]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.988796530538
# AUC of this fold: 0.884777007889
# AUPR of this fold: 0.430413585412
# Confustion matrix of this fold
# [[10903    22]
#  [  102    41]]
#
#
# Accuracy of this fold: 0.989248283339
# AUC of this fold: 0.858899681554
# AUPR of this fold: 0.4314413253
# Confustion matrix of this fold
# [[10905    20]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.98960968558
# AUC of this fold: 0.887985469908
# AUPR of this fold: 0.464644014643
# Confustion matrix of this fold
# [[10909    16]
#  [   99    44]]
#
#
# Accuracy of this fold: 0.988977231659
# AUC of this fold: 0.885846601911
# AUPR of this fold: 0.42001018285
# Confustion matrix of this fold
# [[10901    24]
#  [   98    45]]
#
#
# Accuracy of this fold: 0.990061438381
# AUC of this fold: 0.855875566082
# AUPR of this fold: 0.454943793296
# Confustion matrix of this fold
# [[10910    15]
#  [   95    48]]
#
#
# Accuracy avg : 0.989429458684
# AUC avg : 0.869958562769
# AUPR avg : 0.435994337814
# Confustion matrix
# [[109050    201]
#  [   969    465]]

# %%
indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/2_indep_asso_descriptor.tsv")

from sklearn.metrics import roc_curve, auc, average_precision_score

x_whole_data = descriptor_data.values
y_whole_data = association_data["association"].values
indep_x = indep.values[:, 3:].astype(float)
indep_y = indep.values[:,2].astype(int)

#classifier = LogisticRegression(penalty='l1', C=0.1, n_jobs = -1)
classifier = RandomForestClassifier(n_estimators=800, n_jobs=-1, class_weight='balanced')
classifier.fit(x_whole_data, y_whole_data)
indep_y_predicted_proba = classifier.predict_proba(indep_x)
indep_y_predicted_label = classifier.predict(indep_x)

indep_accuracy = classifier.score(indep_x, indep_y)
indep_fpr, indep_tpr, indep_thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label = 1)
indep_auc = auc(indep_fpr, indep_tpr)
indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:, 1])

print("Independent Accuracy : {}".format(indep_accuracy))
print("Independent AUC : {}".format(indep_auc))
print("Independent AUPR : {}".format(indep_aupr))
print("Independent Confustion matrix")
print(indep_confusion_matirx)
print("\t")
# Out:
# Independent Accuracy : 0.979647749511
# Independent AUC : 0.874295746967
# Independent AUPR : 0.649091752381
# Independent Confustion matrix
# [[2439   23]
#  [  29   64]]
