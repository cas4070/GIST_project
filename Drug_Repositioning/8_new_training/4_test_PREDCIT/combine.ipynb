# %%
import numpy as np
import os
import pandas as pd
import time
from itertools import product
import math

# %%
# positive
pos1 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_0_249999.tsv")
pos2 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_250000_499999.tsv")
pos3 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_500000_749999.tsv")
pos4 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_750000_999999.tsv")
pos5 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_1000000_1249999.tsv")
pos6 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_1250000_1499999.tsv")
pos7 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_1500000_1749999.tsv")
pos8 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_bef_descriptor_1750000_1951608.tsv")

# %%
frames = [pos1, pos2, pos3, pos4, pos5, pos6, pos7, pos8]
pos = pd.concat(frames, axis=0)
print len(pos)
# Out:
# 1950212

# %%
desc_pos = pos.groupby(['drug', 'disease']).max()

desc_pos.to_csv("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_descriptor.tsv",
                  sep = '\t')
desc_pos.to_csv("/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_pos_descriptor.tsv",
                  sep = '\t')

# %%
# negative
neg1 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_0_249999.tsv")
neg2 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_250000_499999.tsv")
neg3 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_500000_749999.tsv")
neg4 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_750000_999999.tsv")
neg5 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_1000000_1249999.tsv")
neg6 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_1250000_1499999.tsv")
neg7 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_1500000_1749999.tsv")
neg8 = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_bef_descriptor_1750000_1951608.tsv")

# %%
frames = [neg1, neg2, neg3, neg4, neg5, neg6, neg7, neg8]
neg = pd.concat(frames, axis=0)
print len(neg)
# Out:
# 1951609

# %%
desc_neg = neg.groupby(['drug', 'disease']).max()

# %%
desc_neg
# Out:
#                  association  DrChe_DiGe  DrChe_DiPhe  DrPhe_DiGe  DrPhe_DiPhe
# drug    disease
# DB00126 109800             0    0.982523     0.375628    0.982523     0.951135
#         182830             0    0.997156     0.367351    0.997156     0.941617
#         191390             0    0.985553     0.572218    0.985553     0.965121
# DB00136 109800             0    0.982234     0.481862    0.982234     0.947432
# DB00153 137580             0    0.999148     0.497587    0.999148     0.992060
#         259050             0    0.998010     0.584497    0.998010     0.924192
#         601665             0    0.956747     0.427065    0.992281     0.992281
# DB00162 154276             0    0.999005     0.424247    0.999005     0.967622
#         157700             0    0.998579     0.551677    0.998579     0.983386
#         161900             0    0.971038     0.581774    0.998681     0.998681
#         165150             0    0.999005     0.507580    0.999005     0.924192
# ...

# %%
desc_neg = neg.groupby(['drug', 'disease']).max()

desc_neg.to_csv("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_descriptor.tsv",
                  sep = '\t')
desc_neg.to_csv("/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_neg_descriptor.tsv",
                  sep = '\t')

# %%
# whole
frames = [desc_pos, desc_neg]
whole_desc = pd.concat(frames, axis=0)
print len(whole_dec)

# %%
whole_desc.to_csv("/DAS_Storage1/aschoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_whole_descriptor.tsv",
                  sep = '\t')
whole_desc.to_csv("/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/5_PREDICT_descriptor/test_whole_descriptor.tsv",
                  sep = '\t')
