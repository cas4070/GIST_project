# %%
import numpy as np
import pandas as pd
from datetime import datetime
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score # AUC score
from sklearn.metrics import average_precision_score # AUPR score
from sklearn.metrics import precision_recall_fscore_support # precision, recall
from imblearn.metrics import sensitivity_specificity_support # sensitivity, specificity
from sklearn.metrics import roc_curve # to draw auc curve
from sklearn.metrics import precision_recall_curve # to draw aupr curve
from imblearn.under_sampling import RandomUnderSampler
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %%
gold_pos = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/data/desc_12/gold_pos_desc12.tsv")
gold_neg = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/data/desc_12/gold_neg_desc12.tsv")
gold = pd.concat([gold_pos, gold_neg])
x_whole_data = gold[gold.columns.values[3:].tolist()].values
y_whole_data = gold["association"].values

# %%
indep = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/data/desc_12/indep_desc12.tsv")
indep_x = indep.values[:, 3:].astype(float)
indep_y = indep.values[:,2].astype(int)

# %%
# undersampler
rus = RandomUnderSampler(ratio=0.5)

# %%
#x_resampled, y_resampled = rus.fit_sample(x_whole_data, y_whole_data)
x_rs = list()
y_rs = list()
for i in range(30):
    x_resampled, y_resampled = rus.fit_sample(x_whole_data, y_whole_data)
    x_rs.append(x_resampled)
    y_rs.append(y_resampled)

# %%
# Random forest 2017.6.4. # 2017.6.11.
print datetime.now().strftime('%Y-%m-%d %H:%M:%S')
path = '/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/7_non/'
user_estimator = 1200
classifier = RandomForestClassifier(n_estimators=user_estimator, n_jobs=-1, class_weight='balanced')
trials = dict()
print "start " + datetime.now().strftime('%Y-%m-%d %H:%M:%S')
for x_resampled, y_resampled, i in zip(x_rs, y_rs, range(30)):
    if i% 10 == 0:
        print "   start : {} trials ".format(i) + datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    classifier.fit(x_resampled, y_resampled)
    indep_y_predicted_proba = classifier.predict_proba(indep_x)
    indep_y_predicted_label = classifier.predict(indep_x)
    fp_results = dict()
    fp_results['predicted_proba'] = indep_y_predicted_proba
    fp_results['Predicted_label'] = indep_y_predicted_label
    fp_results['y_true'] = indep_y
    trials[i] = fp_results
print "end : " + datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# 2017-06-11 15:49:37
# start 2017-06-11 15:49:37
#    start : 0 trials 2017-06-11 15:49:37
#    start : 10 trials 2017-06-11 15:50:31
#    start : 20 trials 2017-06-11 15:51:26
# end : 2017-06-11 15:52:21

# %%
###### 회수별로 공통적으로 1이라고 판명된 drug를 찾는다.

# %%
def predicted_results(fp_results):
    df_predicted_result = pd.DataFrame({'Drug_id':indep['drug_id'],'Disease_id':indep['disease_id'],
                                    'Predicted_label' : fp_results['Predicted_label'],
                                    'Predicted_proba' : fp_results['predicted_proba'][:,1], 
                                    'y_true':fp_results['y_true']})
    df_predicted_result= df_predicted_result[['Drug_id', 'Disease_id', 'y_true', 'Predicted_label', 'Predicted_proba']]
    return df_predicted_result

# %%
df_dic = dict()
for i in range(30):
    df_dic[i] = predicted_results(trials[i])

# %%
fp_dic = dict()
fp_lst = list()
for i in range(30):
    fp_dic[i] = df_dic[i][(df_dic[i].Predicted_label == 1)&(df_dic[i].y_true == 0)]
    fp_lst.append(df_dic[i][(df_dic[i].Predicted_label == 1)&(df_dic[i].y_true == 0)])

# %%
fp_final = reduce(lambda left, right: pd.merge(left, right, on=['Disease_id', 'Drug_id', 'y_true', 'Predicted_label']), fp_lst)

# %%
fp_final.head(1)
# Out:
#    Drug_id  Disease_id  y_true  Predicted_label  Predicted_proba_x  \
# 0  DB00176      103780       0                1           0.755833
#
#    Predicted_proba_y  Predicted_proba_x  Predicted_proba_y  Predicted_proba_x  \
# 0           0.729167             0.6575             0.7025           0.798333
#
#    Predicted_proba_y        ...          Predicted_proba_x  Predicted_proba_y  \
# 0              0.835        ...                     0.7225             0.7325
#
#    Predicted_proba_x  Predicted_proba_y  Predicted_proba_x  Predicted_proba_y  \
# 0              0.815             0.5725           0.679167             0.5825
#
#    Predicted_proba_x  Predicted_proba_y  Predicted_proba_x  Predicted_proba_y
# 0           0.664167           0.660833           0.720833           0.708333
#
# [1 rows x 34 columns]

# %%
columns_names = ['Drug_id','Disease_id','y_true', 'Predicted_label' ] + ['trial'+str(i) for i in range(30)]

# %%
fp_final.columns = columns_names

# %%
fp_final.head(2)
# Out:
#    Drug_id  Disease_id  y_true  Predicted_label    trial0    trial1  trial2  \
# 0  DB00176      103780       0                1  0.755833  0.729167  0.6575
# 1  DB00193      103780       0                1  0.780833  0.667500  0.7900
#
#    trial3    trial4  trial5    ...     trial20   trial21   trial22  trial23  \
# 0  0.7025  0.798333   0.835    ...      0.7225  0.732500  0.815000   0.5725
# 1  0.6950  0.801667   0.675    ...      0.7025  0.728333  0.584167   0.6600
#
#     trial24   trial25   trial26   trial27   trial28   trial29
# 0  0.679167  0.582500  0.664167  0.660833  0.720833  0.708333
# 1  0.809167  0.754167  0.575833  0.745833  0.737500  0.722500
#
# [2 rows x 34 columns]

# %%
fp_final['avg'] = fp_final[fp_final.columns.values.tolist()[4:]].mean(axis=1)

# %%
fp_final = fp_final[['Drug_id','Disease_id','y_true', 'Predicted_label', 'avg' ] + ['trial'+str(i) for i in range(30)]]

# %%
sorted_fp = fp_final.sort_values(by='avg', ascending=False)

# %%
print len(sorted_fp.Drug_id.drop_duplicates()), len(sorted_fp.Disease_id.drop_duplicates()), len(sorted_fp), len(sorted_fp.drop_duplicates())
# Out:
# 20 18 37 37

# %%
sorted_fp.to_csv("/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/7_non/100_indep_predicted_results_30_times.tsv", sep='\t', index=False)

# %%
##########이름 매칭

# %%
omim = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/6_new_disease/1_omim_umls_mapping_association.tsv")
drugbank = pd.read_csv("/DAS_Storage1/aschoi/data/Drug_Repositioning/7_new_association/drugbank vocabulary.csv")
drugbank_part = drugbank[['DrugBank ID', 'Common name', 'Synonyms']]
drugbank_part = drugbank_part.rename(columns={'DrugBank ID' : 'DrugBank_ID', 'Common name':'Common_name'})

# %%
fp_omim = pd.merge(right = sorted_fp, left = omim, right_on = 'Disease_id', left_on = 'OMIM_ID')
fp_omim.head(1)
# Out:
#    OMIM_ID                                  OMIM_disease_name UMLS_concept_ID  \
# 0   102300  Restless Legs Syndrome, Susceptibility To, 1; ...        C0035258
#
#         UMLS_concept_name  Drug_id  Disease_id  y_true  Predicted_label  \
# 0  Restless Legs Syndrome  DB01182      102300       0                1
#
#         avg    trial0   ...      trial20   trial21   trial22  trial23  \
# 0  0.781472  0.861667   ...     0.664167  0.674167  0.759167   0.8225
#
#    trial24   trial25  trial26  trial27   trial28  trial29
# 0     0.92  0.751667     0.85   0.8625  0.885833     0.83
#
# [1 rows x 39 columns]

# %%
fp_omim2 = fp_omim[['Drug_id','Disease_id','OMIM_disease_name', 'avg']]
print len(sorted_fp), len(fp_omim2), len(fp_omim2.drop_duplicates())
fp_omim2.head(2)
# Out:
# 37 54 37
#    Drug_id  Disease_id                                  OMIM_disease_name  \
# 0  DB01182      102300  Restless Legs Syndrome, Susceptibility To, 1; ...
# 1  DB00376      102300  Restless Legs Syndrome, Susceptibility To, 1; ...
#
#         avg
# 0  0.781472
# 1  0.778250

# %%
fp_omim_drug = pd.merge(right = fp_omim2, left = drugbank_part, right_on = 'Drug_id', left_on = 'DrugBank_ID')
fp_omim_drug.head(1)
# Out:
#   DrugBank_ID  Common_name                                  Synonyms  Drug_id  \
# 0     DB00176  Fluvoxamine  Fluvoxamina | Fluvoxamine | Fluvoxaminum  DB00176
#
#    Disease_id   OMIM_disease_name       avg
# 0      103780  Alcohol Dependence  0.713056

# %%
fp_omim_drug2 = fp_omim_drug[['Drug_id','Common_name','Synonyms','Disease_id','OMIM_disease_name', 'avg']]
print len(fp_omim2), len(fp_omim_drug2), len(fp_omim_drug2.drop_duplicates())
fp_omim_drug2.head(2)
# Out:
# 54 54 37
#    Drug_id  Common_name                                           Synonyms  \
# 0  DB00176  Fluvoxamine           Fluvoxamina | Fluvoxamine | Fluvoxaminum
# 1  DB00193     Tramadol  (+)-Tramadol | (+)-trans-2-(Dimethylaminomethy...
#
#    Disease_id   OMIM_disease_name       avg
# 0      103780  Alcohol Dependence  0.713056
# 1      103780  Alcohol Dependence  0.700222

# %%
fp_omim_drug2.sort_values('avg', ascending=False).drop_duplicates().to_csv(
    "/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/7_non/100_indep_predicted_results_30times_name.tsv",
    sep='\t', index=False)

# %%
fp_omim_drug2.sort_values('avg', ascending=False).drop_duplicates().head()
# Out:
#     Drug_id         Common_name  \
# 50  DB01200       Bromocriptine
# 22  DB00810           Biperiden
# 25  DB00860        Prednisolone
# 14  DB00620       Triamcinolone
# 38  DB00959  Methylprednisolone
#
#                                              Synonyms  Disease_id  \
# 50  (5'alpha)-2-bromo-12'-hydroxy-2'-(1-methylethy...      168600
# 22  1-Bicyclo[2.2.1]hept-5-en-2-yl-1-phenyl-3-pipe...      104300
# 25  (11beta)-11,17,21-Trihydroxypregna-1,4-diene-3...      140600
# 14  11β,16α,17α,21-tetrahydroxy-9α-fluoro-1,4-preg...      212050
# 38  (6alpha,11beta)-11,17,21-Trihydroxy-6-methylpr...      607850
#
#                        OMIM_disease_name       avg
# 50                 Parkinson Disease; Pd  0.987917
# 22                 Alzheimer Disease; Ad  0.959000
# 25  Osteoarthritis Susceptibility 2; Os2  0.947500
# 14      Candidiasis, Familial, 2; Candf2  0.947500
# 38  Osteoarthritis Susceptibility 3; Os3  0.940333

# %%
# Match omim id to umls id : to search in PubMed

# %%
mim_umls = pd.read_table("/DAS_Storage1/aschoi/data/Drug_Repositioning/6_new_disease/1_omim_umls_mapping_association.tsv", sep='\t')

# %%
raw = pd.merge(fp_omim_drug2, mim_umls, left_on = 'Disease_id', right_on = 'OMIM_ID', how='inner')

# %%
raw.head(1)
# Out:
#    Drug_id  Common_name                                  Synonyms  Disease_id  \
# 0  DB00176  Fluvoxamine  Fluvoxamina | Fluvoxamine | Fluvoxaminum      103780
#
#   OMIM_disease_name_x       avg  OMIM_ID OMIM_disease_name_y UMLS_concept_ID  \
# 0  Alcohol Dependence  0.713056   103780  Alcohol Dependence        C0001973
#
#                                    UMLS_concept_name
# 0  Alcohol Dependence (Alcoholic Intoxication, Ch...

# %%
raw.rename(columns = {'Drug_id':'drugID', 'Disease_id' : 'diseaseID', 'OMIM_ID':'mimID', 'OMIM_disease_name_x' : 'omim_disease_name', 'UMLS_concept_ID' : 'umls_id', 'UMLS_concept_name' :'umls_name'}, inplace=True)

# %%
raw.head(1)
# Out:
#     drugID  Common_name                                  Synonyms  diseaseID  \
# 0  DB00176  Fluvoxamine  Fluvoxamina | Fluvoxamine | Fluvoxaminum     103780
#
#     omim_disease_name       avg   mimID OMIM_disease_name_y   umls_id  \
# 0  Alcohol Dependence  0.713056  103780  Alcohol Dependence  C0001973
#
#                                            umls_name
# 0  Alcohol Dependence (Alcoholic Intoxication, Ch...

# %%
print len(raw), len(raw.drugID.drop_duplicates()), len(raw.diseaseID)
# Out:
# 92 20 92

# %%
df = raw[['drugID','Common_name','Synonyms','diseaseID', 'omim_disease_name', 'umls_id', 'umls_name', 'avg']].sort_values(by='avg', ascending=False)

# %%
print len(df), len(df.drop_duplicates())
# Out:
# 92 54

# %%
print len(dr_umls), len(dr_umls.drop_duplicates('drugID')), len(dr_umls.drop_duplicates('diseaseID')), len(dr_umls.drop_duplicates(['drugID', 'diseaseID']))
print len(dr_umls.drop_duplicates(['drugID', 'umls_id'])),len(dr_umls.drop_duplicates('umls_id')), len(dr_umls.drop_duplicates('umls_name'))
# Out:
# 90 20 18 37
# 41 22 35

# %%
df.drop_duplicates().to_csv("/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/7_non/100_indep_predicted_results_30times_name_umls.tsv",sep='\t', index=False)

# %%
# searched in PubMed

# %%
import urllib
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime

# %%
dr_umls = df.drop_duplicates()
#dr_umls = pd.read_table("/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/7_non/100_indep_predicted_results_30times_name_umls.tsv"

# %%
print len(dr_umls)
dr_umls.head(1)
# Out:
# 54
#      drugID    Common_name                                           Synonyms  \
# 89  DB01200  Bromocriptine  (5'alpha)-2-bromo-12'-hydroxy-2'-(1-methylethy...
#
#     diseaseID      omim_disease_name   umls_id               umls_name  \
# 89     168600  Parkinson Disease; Pd  C0030567  PD (Parkinson Disease)
#
#          avg
# 89  0.987917

# %%
# umls_name to multiple rows
s = dr_umls['umls_name'].str.split('\(').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'umls_name'
del dr_umls['umls_name']
dr_umls = dr_umls.join(s)
dr_umls.umls_name = dr_umls.umls_name.str.rstrip('\)')

# %%
dr_umls.index = range(len(dr_umls))

# %%
row
# Out:
# drugID                                                         DB01586
# Common_name                                       Ursodeoxycholic acid
# Synonyms             (3alpha,5beta,7beta)-3,7-dihydroxycholan-24-oi...
# diseaseID                                                       152700
# omim_disease_name                    Systemic Lupus Erythematosus; Sle
# umls_id                                                       C0024141
# avg                                                           0.747722
# umls_name                                Lupus Erythematosus, Systemic
# Name: 89, dtype: object

# %%
df = pd.DataFrame()
print len(dr_umls)
cnt = 0
print "start : " + datetime.now().strftime('%Y-%m-%d %H:%M:%S')
for index, row in dr_umls.iterrows():
    dr = row['Common_name']
    di = row['umls_name']
    addr = 'https://www.ncbi.nlm.nih.gov/pubmed?term=(' + dr +'%5BTitle%2FAbstract%5D)%20AND%20' + di + '%5BTitle%2FAbstract%5D'
    
    html = urllib.urlopen(addr)
    soup = BeautifulSoup(html)
    
    a = soup.find_all("h3",attrs={'class':'result_count left'})

    if len(a) == 0: # 딱 하나만 검색 됐을 때
        searched = 1
    else :
        searched = int(a[0].text.split(" ")[-1])
    
    temp_df = pd.DataFrame({'drugID': row['drugID'], 'Common_name' : dr,
                            'diseaseID':row['diseaseID'], 'omim_disease_name' : row['omim_disease_name'],
                            'umls_id' : row['umls_id'],'umls_name' : di,
                            'searched_count' : searched, 'avg' : row['avg']}, index=[cnt])
    df = df.append(temp_df)
    
    cnt = cnt + 1
    if cnt % 100 ==0 :
        print "cnt : {} ".format(cnt) + datetime.now().strftime('%Y-%m-%d %H:%M:%S')
print "end : " + datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# 90
# start : 2017-06-11 16:47:53
# end : 2017-06-11 16:50:38

# %%
df = df.drop_duplicates()

# %%
print len(df), len(df.drop_duplicates(['Common_name', 'umls_id'])), len(df.drop_duplicates(['Common_name', 'umls_name']))
# Out:
# 81 41 72

# %%
df_gr = df[df['searched_count'] == df.groupby(['drugID','Common_name','diseaseID','umls_id'])['searched_count'].transform(max)]
#df_gr = df.groupby(['drugID','Common_name','diseaseID','umls_id'])['avg', 'umls_name'].max()

# %%
a = df_gr.reset_index(level=['drugID', 'Common_name', 'diseaseID', 'umls_id'])

# %%
df[df.searched_count != 0].sort_values(['Common_name', 'umls_name', 'searched_count'], ascending=False)
# Out:
#              Common_name       avg  diseaseID   drugID  \
# 89  Ursodeoxycholic acid  0.747722     152700  DB01586
# 19       Trihexyphenidyl  0.923972     104300  DB00376
# 35         Triamcinolone  0.842056     140600  DB00620
# 43         Triamcinolone  0.891389     601626  DB00620
# 41         Triamcinolone  0.947500     212050  DB00620
# 2               Tramadol  0.700222     103780  DB00193
# 88             Salsalate  0.760222     152700  DB01399
# 37            Prednisone  0.929500     140600  DB00635
# 58            Prednisone  0.809389     607850  DB00635
# 47            Prednisone  0.899194     601626  DB00635
# 46            Prednisone  0.899194     601626  DB00635
# 48            Prednisone  0.899194     601626  DB00635
# 39          Prednisolone  0.947500     140600  DB00860
# 60          Prednisolone  0.905528     607850  DB00860
# 71          Prednisolone  0.893278     165720  DB00860
# 51          Prednisolone  0.789444     601626  DB00860
# 50          Prednisolone  0.789444     601626  DB00860
# 52          Prednisolone  0.789444     601626  DB00860
# 62    Methylprednisolone  0.940333     607850  DB00959
# 73    Methylprednisolone  0.914333     165720  DB00959
# 55    Methylprednisolone  0.821389     601626  DB00959
# 67    Methylprednisolone  0.932778     205700  DB00959
# 66    Methylprednisolone  0.932778     205700  DB00959
# 54    Methylprednisolone  0.821389     601626  DB00959
# 56    Methylprednisolone  0.821389     601626  DB00959
# 0            Fluvoxamine  0.713056     103780  DB00176
# 75        Etidronic acid  0.802222     166710  DB01077
# 78        Etidronic acid  0.802222     166710  DB01077
# 77        Etidronic acid  0.802222     166710  DB01077
# 30        Cyproheptadine  0.659111     143100  DB00434
# 85         Bromocriptine  0.987917     168600  DB01200
# 86         Bromocriptine  0.987917     168600  DB01200
# 33         Bromocriptine  0.821556     607501  DB01200
# 20             Biperiden  0.959000     104300  DB00810
# 13            Amantadine  0.739306     102300  DB00915
# 28            Amantadine  0.757306     137580  DB00915
#
#                                     omim_disease_name  searched_count  \
# 89                  Systemic Lupus Erythematosus; Sle               9
# 19                              Alzheimer Disease; Ad               8
# 35               Osteoarthritis Susceptibility 2; Os2             115
# 43                       Leukemia, Acute Myeloid; Aml               4
# 41                   Candidiasis, Familial, 2; Candf2              25
# 2                                  Alcohol Dependence               2
# 88                  Systemic Lupus Erythematosus; Sle               1
# 37               Osteoarthritis Susceptibility 2; Os2              47
# 58               Osteoarthritis Susceptibility 3; Os3              47
# 47                       Leukemia, Acute Myeloid; Aml             334
# 46                       Leukemia, Acute Myeloid; Aml              22
# 48                       Leukemia, Acute Myeloid; Aml             119
# 39               Osteoarthritis Susceptibility 2; Os2              62
# 60               Osteoarthritis Susceptibility 3; Os3              62
# 71               Osteoarthritis Susceptibility 1; Os1              62
# 51                       Leukemia, Acute Myeloid; Aml             297
# 50                       Leukemia, Acute Myeloid; Aml              27
# 52                       Leukemia, Acute Myeloid; Aml             103
# 62               Osteoarthritis Susceptibility 3; Os3              71
# 73               Osteoarthritis Susceptibility 1; Os1              71
# 55                       Leukemia, Acute Myeloid; Aml             131
# 67                       Anemia, Autoimmune Hemolytic              41
# 66                       Anemia, Autoimmune Hemolytic               1
# 54                       Leukemia, Acute Myeloid; Aml               7
# 56                       Leukemia, Acute Myeloid; Aml              56
# 0                                  Alcohol Dependence               7
# 75                                       Osteoporosis              15
# 78                                       Osteoporosis              15
# 77                                       Osteoporosis              15
# 30                             Huntington Disease; Hd               1
# 85                              Parkinson Disease; Pd              57
# 86                              Parkinson Disease; Pd             159
# 33        Migraine Without Aura, Susceptibility To, 4               1
# 20                              Alzheimer Disease; Ad               8
# 13  Restless Legs Syndrome, Susceptibility To, 1; ...               6
# 28                Gilles De La Tourette Syndrome; Gts               1
#
#      umls_id                       umls_name
# 89  C0024141   Lupus Erythematosus, Systemic
# 19  C0002395             Alzheimer's Disease
# 35  C0029408                 Osteoarthritis
# 43  C0023467     Leukemia, Myelocytic, Acute
# 41  C0006840                     Candidiasis
# 2   C0001973             Alcohol Dependence
# 88  C0024141   Lupus Erythematosus, Systemic
# 37  C0029408                 Osteoarthritis
# 58  C0029408                 Osteoarthritis
# 47  C0023467     Leukemia, Myelocytic, Acute
# 46  C0023467        Acute myeloid leukaemia
# 48  C0023467                            AML
# 39  C0029408                 Osteoarthritis
# 60  C0029408                 Osteoarthritis
# 71  C0029408                 Osteoarthritis
# 51  C0023467     Leukemia, Myelocytic, Acute
# 50  C0023467        Acute myeloid leukaemia
# 52  C0023467                            AML
# 62  C0029408                 Osteoarthritis
# 73  C0029408                 Osteoarthritis
# 55  C0023467     Leukemia, Myelocytic, Acute
# 67  C0002880     Autoimmune hemolytic anemia
# 66  C0002880  Autoimmune haemolytic anaemia
# 54  C0023467        Acute myeloid leukaemia
# 56  C0023467                            AML
# 0   C0001973             Alcohol Dependence
# 75  C1563292                   Osteoporosis
# 78  C1962963                   Osteoporosis
# 77  C0029456                    Osteoporosis
# 30  C0020179              Huntington Disease
# 85  C0030567               Parkinson Disease
# 86  C0030567                             PD
# 33  C0338480          Migraine without Aura
# 20  C0002395             Alzheimer's Disease
# 13  C0035258          Restless Legs Syndrome
# 28  C0040517  Gilles de la Tourette syndrome

# %%
print len(df_gr.drop_duplicates(['drugID', 'umls_name'])), len(df_gr.drop_duplicates()), len(df_gr)
df_gr.drop_duplicates(['drugID', 'umls_name']).sort_values('searched_count', ascending=False)
# Out:
# 52 57 57
#              Common_name       avg  diseaseID   drugID  \
# 47            Prednisone  0.899194     601626  DB00635
# 51          Prednisolone  0.789444     601626  DB00860
# 86         Bromocriptine  0.987917     168600  DB01200
# 55    Methylprednisolone  0.821389     601626  DB00959
# 35         Triamcinolone  0.842056     140600  DB00620
# 62    Methylprednisolone  0.940333     607850  DB00959
# 39          Prednisolone  0.947500     140600  DB00860
# 37            Prednisone  0.929500     140600  DB00635
# 67    Methylprednisolone  0.932778     205700  DB00959
# 41         Triamcinolone  0.947500     212050  DB00620
# 77        Etidronic acid  0.802222     166710  DB01077
# 75        Etidronic acid  0.802222     166710  DB01077
# 89  Ursodeoxycholic acid  0.747722     152700  DB01586
# 19       Trihexyphenidyl  0.923972     104300  DB00376
# 20             Biperiden  0.959000     104300  DB00810
# 0            Fluvoxamine  0.713056     103780  DB00176
# 13            Amantadine  0.739306     102300  DB00915
# 43         Triamcinolone  0.891389     601626  DB00620
# 2               Tramadol  0.700222     103780  DB00193
# 88             Salsalate  0.760222     152700  DB01399
# 28            Amantadine  0.757306     137580  DB00915
# 30        Cyproheptadine  0.659111     143100  DB00434
# 33         Bromocriptine  0.821556     607501  DB01200
# 5       Diphenylpyraline  0.706806     103780  DB01146
# 7           Orphenadrine  0.800444     103780  DB01173
# 68       Pseudoephedrine  0.874778     137760  DB00852
# 69       Pseudoephedrine  0.874778     137760  DB00852
# 6           Orphenadrine  0.800444     103780  DB01173
# 18           Propafenone  0.781472     102300  DB01182
# 80           Propafenone  0.744528     115195  DB01182
# 64            Mometasone  0.816083     205700  DB00764
# 81           Propafenone  0.744528     115195  DB01182
# 82           Propafenone  0.744528     115195  DB01182
# 83           Propafenone  0.744528     115195  DB01182
# 84           Propafenone  0.744528     115195  DB01182
# 4       Diphenylpyraline  0.706806     103780  DB01146
# 65            Mometasone  0.816083     205700  DB00764
# 10       Trihexyphenidyl  0.778250     102300  DB00376
# 8               Tramadol  0.822278     607499  DB00193
# 9               Tramadol  0.822278     607499  DB00193
# 17           Propafenone  0.781472     102300  DB01182
# 11       Trihexyphenidyl  0.778250     102300  DB00376
# 12       Trihexyphenidyl  0.778250     102300  DB00376
# 14            Amantadine  0.739306     102300  DB00915
# 15            Amantadine  0.739306     102300  DB00915
# 31              Lisuride  0.741667     607501  DB00589
# 25        Cyproheptadine  0.655694     137580  DB00434
# 24        Cyproheptadine  0.655694     137580  DB00434
# 22       Trihexyphenidyl  0.840333     137580  DB00376
# 21       Trihexyphenidyl  0.840333     137580  DB00376
# 16           Propafenone  0.781472     102300  DB01182
# 32              Lisuride  0.741667     607501  DB00589
#
#                                     omim_disease_name  searched_count  \
# 47                       Leukemia, Acute Myeloid; Aml             334
# 51                       Leukemia, Acute Myeloid; Aml             297
# 86                              Parkinson Disease; Pd             159
# 55                       Leukemia, Acute Myeloid; Aml             131
# 35               Osteoarthritis Susceptibility 2; Os2             115
# 62               Osteoarthritis Susceptibility 3; Os3              71
# 39               Osteoarthritis Susceptibility 2; Os2              62
# 37               Osteoarthritis Susceptibility 2; Os2              47
# 67                       Anemia, Autoimmune Hemolytic              41
# 41                   Candidiasis, Familial, 2; Candf2              25
# 77                                       Osteoporosis              15
# 75                                       Osteoporosis              15
# 89                  Systemic Lupus Erythematosus; Sle               9
# 19                              Alzheimer Disease; Ad               8
# 20                              Alzheimer Disease; Ad               8
# 0                                  Alcohol Dependence               7
# 13  Restless Legs Syndrome, Susceptibility To, 1; ...               6
# 43                       Leukemia, Acute Myeloid; Aml               4
# 2                                  Alcohol Dependence               2
# 88                  Systemic Lupus Erythematosus; Sle               1
# 28                Gilles De La Tourette Syndrome; Gts               1
# 30                             Huntington Disease; Hd               1
# 33        Migraine Without Aura, Susceptibility To, 4               1
# 5                                  Alcohol Dependence               0
# 7                                  Alcohol Dependence               0
# 68                 Glaucoma, Primary Open Angle; Poag               0
# 69                 Glaucoma, Primary Open Angle; Poag               0
# 6                                  Alcohol Dependence               0
# 18  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 80     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 64                       Anemia, Autoimmune Hemolytic               0
# 81     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 82     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 83     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 84     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 4                                  Alcohol Dependence               0
# 65                       Anemia, Autoimmune Hemolytic               0
# 10  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 8        Bulimia Nervosa, Susceptibility To, 1; Buln1               0
# 9        Bulimia Nervosa, Susceptibility To, 1; Buln1               0
# 17  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 11  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 12  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 14  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 15  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 31        Migraine Without Aura, Susceptibility To, 4               0
# 25                Gilles De La Tourette Syndrome; Gts               0
# 24                Gilles De La Tourette Syndrome; Gts               0
# 22                Gilles De La Tourette Syndrome; Gts               0
# 21                Gilles De La Tourette Syndrome; Gts               0
# 16  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 32        Migraine Without Aura, Susceptibility To, 4               0
#
#      umls_id                                 umls_name
# 47  C0023467               Leukemia, Myelocytic, Acute
# 51  C0023467               Leukemia, Myelocytic, Acute
# 86  C0030567                                       PD
# 55  C0023467               Leukemia, Myelocytic, Acute
# 35  C0029408                           Osteoarthritis
# 62  C0029408                           Osteoarthritis
# 39  C0029408                           Osteoarthritis
# 37  C0029408                           Osteoarthritis
# 67  C0002880               Autoimmune hemolytic anemia
# 41  C0006840                               Candidiasis
# 77  C0029456                              Osteoporosis
# 75  C1563292                             Osteoporosis
# 89  C0024141             Lupus Erythematosus, Systemic
# 19  C0002395                       Alzheimer's Disease
# 20  C0002395                       Alzheimer's Disease
# 0   C0001973                       Alcohol Dependence
# 13  C0035258                    Restless Legs Syndrome
# 43  C0023467               Leukemia, Myelocytic, Acute
# 2   C0001973                       Alcohol Dependence
# 88  C0024141             Lupus Erythematosus, Systemic
# 28  C0040517            Gilles de la Tourette syndrome
# 30  C0020179                        Huntington Disease
# 33  C0338480                    Migraine without Aura
# 5   C0001973           Alcoholic Intoxication, Chronic
# 7   C0001973           Alcoholic Intoxication, Chronic
# 68  C0339573               Primary open angle glaucoma
# 69  C0339573                                     POAG
# 6   C0001973                       Alcohol Dependence
# 18  C1876177                            Ekbom Syndrome
# 80  C0205700    CARDIOMYOPATHY, FAMILIAL HYPERTROPHIC
# 64  C0002880            Autoimmune haemolytic anaemia
# 81  C0205700             Asymmetric Septal Hypertrophy
# 82  C0949658    Cardiomyopathy, Hypertrophic, Familial
# 83  C1861864                                     CMH2
# 84  C1861864  CARDIOMYOPATHY, FAMILIAL HYPERTROPHIC, 2
# 4   C0001973                       Alcohol Dependence
# 65  C0002880               Autoimmune hemolytic anemia
# 10  C0035258                    Restless Legs Syndrome
# 8   C2267227                           Bulimia Nervosa
# 9   C1843776                                     BULN1
# 17  C1876177                                     RLS1
# 11  C1876177                                     RLS1
# 12  C1876177                            Ekbom Syndrome
# 14  C1876177                                     RLS1
# 15  C1876177                            Ekbom Syndrome
# 31  C0338480                    Migraine without Aura
# 25  C0040517                                      GTS
# 24  C0040517            Gilles de la Tourette syndrome
# 22  C0040517                                      GTS
# 21  C0040517            Gilles de la Tourette syndrome
# 16  C0035258                    Restless Legs Syndrome
# 32  C0338480                           Common Migraine

# %%
print len(a.drop_duplicates(['drugID', 'umls_name'])), len(a.drop_duplicates()), len(a)
a.sort_values('searched_count', ascending=False)
# Out:
# 52 57 57
#     index           Common_name       avg  diseaseID   drugID  \
# 33     47            Prednisone  0.899194     601626  DB00635
# 34     51          Prednisolone  0.789444     601626  DB00860
# 54     86         Bromocriptine  0.987917     168600  DB01200
# 35     55    Methylprednisolone  0.821389     601626  DB00959
# 28     35         Triamcinolone  0.842056     140600  DB00620
# 38     62    Methylprednisolone  0.940333     607850  DB00959
# 45     73    Methylprednisolone  0.914333     165720  DB00959
# 37     60          Prednisolone  0.905528     607850  DB00860
# 30     39          Prednisolone  0.947500     140600  DB00860
# 44     71          Prednisolone  0.893278     165720  DB00860
# 29     37            Prednisone  0.929500     140600  DB00635
# 36     58            Prednisone  0.809389     607850  DB00635
# 41     67    Methylprednisolone  0.932778     205700  DB00959
# 31     41         Triamcinolone  0.947500     212050  DB00620
# 46     75        Etidronic acid  0.802222     166710  DB01077
# 47     77        Etidronic acid  0.802222     166710  DB01077
# 48     78        Etidronic acid  0.802222     166710  DB01077
# 56     89  Ursodeoxycholic acid  0.747722     152700  DB01586
# 18     20             Biperiden  0.959000     104300  DB00810
# 17     19       Trihexyphenidyl  0.923972     104300  DB00376
# 0       0           Fluvoxamine  0.713056     103780  DB00176
# 11     13            Amantadine  0.739306     102300  DB00915
# 32     43         Triamcinolone  0.891389     601626  DB00620
# 1       2              Tramadol  0.700222     103780  DB00193
# 23     28            Amantadine  0.757306     137580  DB00915
# 24     30        Cyproheptadine  0.659111     143100  DB00434
# 55     88             Salsalate  0.760222     152700  DB01399
# 27     33         Bromocriptine  0.821556     607501  DB01200
# 21     24        Cyproheptadine  0.655694     137580  DB00434
# 3       5      Diphenylpyraline  0.706806     103780  DB01146
# 7       9              Tramadol  0.822278     607499  DB00193
# 6       8              Tramadol  0.822278     607499  DB00193
# 5       7          Orphenadrine  0.800444     103780  DB01173
# 4       6          Orphenadrine  0.800444     103780  DB01173
# 51     82           Propafenone  0.744528     115195  DB01182
# 49     80           Propafenone  0.744528     115195  DB01182
# 50     81           Propafenone  0.744528     115195  DB01182
# 42     68       Pseudoephedrine  0.874778     137760  DB00852
# 52     83           Propafenone  0.744528     115195  DB01182
# 53     84           Propafenone  0.744528     115195  DB01182
# 2       4      Diphenylpyraline  0.706806     103780  DB01146
# 43     69       Pseudoephedrine  0.874778     137760  DB00852
# 39     64            Mometasone  0.816083     205700  DB00764
# 8      10       Trihexyphenidyl  0.778250     102300  DB00376
# 40     65            Mometasone  0.816083     205700  DB00764
# 22     25        Cyproheptadine  0.655694     137580  DB00434
# 9      11       Trihexyphenidyl  0.778250     102300  DB00376
# 19     21       Trihexyphenidyl  0.840333     137580  DB00376
# 12     14            Amantadine  0.739306     102300  DB00915
# 13     15            Amantadine  0.739306     102300  DB00915
# 14     16           Propafenone  0.781472     102300  DB01182
# 15     17           Propafenone  0.781472     102300  DB01182
# 16     18           Propafenone  0.781472     102300  DB01182
# 20     22       Trihexyphenidyl  0.840333     137580  DB00376
# 26     32              Lisuride  0.741667     607501  DB00589
# 25     31              Lisuride  0.741667     607501  DB00589
# 10     12       Trihexyphenidyl  0.778250     102300  DB00376
#
#                                     omim_disease_name  searched_count  \
# 33                       Leukemia, Acute Myeloid; Aml             334
# 34                       Leukemia, Acute Myeloid; Aml             297
# 54                              Parkinson Disease; Pd             159
# 35                       Leukemia, Acute Myeloid; Aml             131
# 28               Osteoarthritis Susceptibility 2; Os2             115
# 38               Osteoarthritis Susceptibility 3; Os3              71
# 45               Osteoarthritis Susceptibility 1; Os1              71
# 37               Osteoarthritis Susceptibility 3; Os3              62
# 30               Osteoarthritis Susceptibility 2; Os2              62
# 44               Osteoarthritis Susceptibility 1; Os1              62
# 29               Osteoarthritis Susceptibility 2; Os2              47
# 36               Osteoarthritis Susceptibility 3; Os3              47
# 41                       Anemia, Autoimmune Hemolytic              41
# 31                   Candidiasis, Familial, 2; Candf2              25
# 46                                       Osteoporosis              15
# 47                                       Osteoporosis              15
# 48                                       Osteoporosis              15
# 56                  Systemic Lupus Erythematosus; Sle               9
# 18                              Alzheimer Disease; Ad               8
# 17                              Alzheimer Disease; Ad               8
# 0                                  Alcohol Dependence               7
# 11  Restless Legs Syndrome, Susceptibility To, 1; ...               6
# 32                       Leukemia, Acute Myeloid; Aml               4
# 1                                  Alcohol Dependence               2
# 23                Gilles De La Tourette Syndrome; Gts               1
# 24                             Huntington Disease; Hd               1
# 55                  Systemic Lupus Erythematosus; Sle               1
# 27        Migraine Without Aura, Susceptibility To, 4               1
# 21                Gilles De La Tourette Syndrome; Gts               0
# 3                                  Alcohol Dependence               0
# 7        Bulimia Nervosa, Susceptibility To, 1; Buln1               0
# 6        Bulimia Nervosa, Susceptibility To, 1; Buln1               0
# 5                                  Alcohol Dependence               0
# 4                                  Alcohol Dependence               0
# 51     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 49     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 50     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 42                 Glaucoma, Primary Open Angle; Poag               0
# 52     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 53     Cardiomyopathy, Familial Hypertrophic, 2; Cmh2               0
# 2                                  Alcohol Dependence               0
# 43                 Glaucoma, Primary Open Angle; Poag               0
# 39                       Anemia, Autoimmune Hemolytic               0
# 8   Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 40                       Anemia, Autoimmune Hemolytic               0
# 22                Gilles De La Tourette Syndrome; Gts               0
# 9   Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 19                Gilles De La Tourette Syndrome; Gts               0
# 12  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 13  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 14  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 15  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 16  Restless Legs Syndrome, Susceptibility To, 1; ...               0
# 20                Gilles De La Tourette Syndrome; Gts               0
# 26        Migraine Without Aura, Susceptibility To, 4               0
# 25        Migraine Without Aura, Susceptibility To, 4               0
# 10  Restless Legs Syndrome, Susceptibility To, 1; ...               0
#
#      umls_id                                 umls_name
# 33  C0023467               Leukemia, Myelocytic, Acute
# 34  C0023467               Leukemia, Myelocytic, Acute
# 54  C0030567                                       PD
# 35  C0023467               Leukemia, Myelocytic, Acute
# 28  C0029408                           Osteoarthritis
# 38  C0029408                           Osteoarthritis
# 45  C0029408                           Osteoarthritis
# 37  C0029408                           Osteoarthritis
# 30  C0029408                           Osteoarthritis
# 44  C0029408                           Osteoarthritis
# 29  C0029408                           Osteoarthritis
# 36  C0029408                           Osteoarthritis
# 41  C0002880               Autoimmune hemolytic anemia
# 31  C0006840                               Candidiasis
# 46  C1563292                             Osteoporosis
# 47  C0029456                              Osteoporosis
# 48  C1962963                             Osteoporosis
# 56  C0024141             Lupus Erythematosus, Systemic
# 18  C0002395                       Alzheimer's Disease
# 17  C0002395                       Alzheimer's Disease
# 0   C0001973                       Alcohol Dependence
# 11  C0035258                    Restless Legs Syndrome
# 32  C0023467               Leukemia, Myelocytic, Acute
# 1   C0001973                       Alcohol Dependence
# 23  C0040517            Gilles de la Tourette syndrome
# 24  C0020179                        Huntington Disease
# 55  C0024141             Lupus Erythematosus, Systemic
# 27  C0338480                    Migraine without Aura
# 21  C0040517            Gilles de la Tourette syndrome
# 3   C0001973           Alcoholic Intoxication, Chronic
# 7   C1843776                                     BULN1
# 6   C2267227                           Bulimia Nervosa
# 5   C0001973           Alcoholic Intoxication, Chronic
# 4   C0001973                       Alcohol Dependence
# 51  C0949658    Cardiomyopathy, Hypertrophic, Familial
# 49  C0205700    CARDIOMYOPATHY, FAMILIAL HYPERTROPHIC
# 50  C0205700             Asymmetric Septal Hypertrophy
# 42  C0339573               Primary open angle glaucoma
# 52  C1861864                                     CMH2
# 53  C1861864  CARDIOMYOPATHY, FAMILIAL HYPERTROPHIC, 2
# 2   C0001973                       Alcohol Dependence
# 43  C0339573                                     POAG
# 39  C0002880            Autoimmune haemolytic anaemia
# 8   C0035258                    Restless Legs Syndrome
# 40  C0002880               Autoimmune hemolytic anemia
# 22  C0040517                                      GTS
# 9   C1876177                                     RLS1
# 19  C0040517            Gilles de la Tourette syndrome
# 12  C1876177                                     RLS1
# 13  C1876177                            Ekbom Syndrome
# 14  C0035258                    Restless Legs Syndrome
# 15  C1876177                                     RLS1
# 16  C1876177                            Ekbom Syndrome
# 20  C0040517                                      GTS
# 26  C0338480                           Common Migraine
# 25  C0338480                    Migraine without Aura
# 10  C1876177                            Ekbom Syndrome

# %%
df_gr.drop_duplicates(['drugID', 'umls_name']).to_csv("/home/share/aschoi/nas/users/asolchoi/data/Drug_Repositioning/8_new_training/7_non/100_indep_predicted_results_30times_name_umls_tidy.tsv"
                                                 , sep='\t', index=False)

# %%
a[a.searched_count != 0].Common_name.drop_duplicates()
# Out:
# 0              Fluvoxamine
# 1                 Tramadol
# 11              Amantadine
# 17         Trihexyphenidyl
# 18               Biperiden
# 24          Cyproheptadine
# 27           Bromocriptine
# 28           Triamcinolone
# 29              Prednisone
# 30            Prednisolone
# 35      Methylprednisolone
# 46          Etidronic acid
# 55               Salsalate
# 56    Ursodeoxycholic acid
# Name: Common_name, dtype: object

# %%
a[a.searched_count != 0].Common_name.drop_duplicates()
# Out:
# 6          Trihexyphenidyl
# 9           Cyproheptadine
# 12           Triamcinolone
# 14              Prednisone
# 18               Biperiden
# 20            Prednisolone
# 24              Amantadine
# 27      Methylprednisolone
# 31          Etidronic acid
# 41           Bromocriptine
# 43               Salsalate
# 44    Ursodeoxycholic acid
# Name: Common_name, dtype: object

# %%
a[a.Common_name == 'Fluvoxamine']
# Out:
#     drugID  Common_name  diseaseID   umls_id       avg   omim_disease_name  \
# 0  DB00176  Fluvoxamine     103780  C0001973  0.713056  Alcohol Dependence
#
#    searched_count            umls_name
# 0               7  Alcohol Dependence

# %%
df_gr.reset_index(level=['drugID', 'umls_id'], inplace=True)

# %%
umls에 여러개의 umls name이 있을 경우, cnt가 큰 것을 기준으로 한다.

# %%
df_gr[(df_gr.Common_name == "Pyridoxal")&(df_gr.umls_id == 'C0085681')]

# %%
print len(a.drop_duplicates()), len(a), len(df_gr)

# %%
def Random_Forest_independent_graph(X, y, indep_X, indep_y, user_estimator):

    folds_results = dict()
    draw_results = {'fpr':[], 'tpr':[], 'precision_vec':[], 'recall_vec':[]}
    fp_results = dict()
    
    classifier = RandomForestClassifier(n_estimators=user_estimator, n_jobs=-1, class_weight='balanced')
    classifier.fit(X, y)
    indep_y_predicted_proba = classifier.predict_proba(indep_X)
    indep_y_predicted_label = classifier.predict(indep_X)
    fp_results['predicted_proba'] = indep_y_predicted_proba
    fp_results['Predicted_label'] = indep_y_predicted_label
    fp_results['y_true'] = indep_y

    # Accuracy
    indep_acc = classifier.score(indep_X, indep_y)
    folds_results['acc']=indep_acc
    
    # AUC
    indep_auc = roc_auc_score(indep_y, indep_y_predicted_proba[:,1])
    folds_results['auc']=indep_auc
    
    # Sensitivity, Specificity
    indep_sn, indep_sp, support = sensitivity_specificity_support(indep_y, indep_y_predicted_label)
    folds_results['sn']=indep_sn
    folds_results['sp']=indep_sp
    
    # AUPR
    indep_aupr = average_precision_score(indep_y, indep_y_predicted_proba[:,1])
    folds_results['aupr']=indep_aupr
    
    # Precision, Recall
    indep_precision, indep_recall, _, _ = precision_recall_fscore_support(indep_y, indep_y_predicted_label, average = 'binary')
    folds_results['precision']=indep_precision
    folds_results['recall']=indep_recall
    
    # Confusion Matirx
    indep_confusion_matirx = confusion_matrix(indep_y, indep_y_predicted_label)
    folds_results['confusion_matrix']=indep_confusion_matirx
    
    # draw graph
    indep_fpr, indep_tpr, thresholds = roc_curve(indep_y, indep_y_predicted_proba[:, 1], pos_label=1)
    draw_results['fpr'].append(indep_fpr)
    draw_results['tpr'].append(indep_tpr)
        
    indep_precision_vec, indep_recall_vec, _ = precision_recall_curve(indep_y, indep_y_predicted_proba[:, 1])
    draw_results['precision_vec'].append(indep_precision_vec)
    draw_results['recall_vec'].append(indep_recall_vec)

    return folds_results, draw_results, fp_results
